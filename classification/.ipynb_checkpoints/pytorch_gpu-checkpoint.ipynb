# %% [markdown]
#  If you use Google Colab, PyTorch and SciPy are already installed, so you probably just want to install PyTorch Lightning.
#   - [PyTorch](https://pytorch.org/get-started/locally/) (tested with 1.10.1 and with 1.10.0)
#   - [PyTorch Lightning](https://pypi.org/project/pytorch-lightning/) (test with 1.5.8)
#   - [SciPy](https://scipy.org/install/) (tested with 1.7.3 and with 1.4.1)

# %%
# !pip install pytorch-lightning==1.5.8

# %%
# !pip install gdown
# !gdown --id 1thWkUj7uGOApr_dXRvMr9TsEHpo_H_2q -O sst2.zip
# !mkdir -p data
# !unzip sst2.zip -d data
# !rm sst2.zip

# %%
def print_important_weights(weights, words):
    """
    Print importtatn pairs of weights and words.
    # Parameters
    weights : `Iterable`, required.
        Weights from a learned model.
    words : `Iterable`, required.
        Word types of the vocabulary.  
        It must be true that `len(weights) == len(words)`.
    # Returns
        `None`
    """

    def print_pairs(pairs):
        for weight, word in pairs:
            print("{: .4f} | {}".format(weight, word))

    assert len(weights) == len(words)
    pairs = list(zip(weights, words))
    pairs = sorted(pairs, key=lambda x: x[0], reverse=True)
    print("Most positive words:")
    print_pairs(pairs[:10])
    print("\nMost negative words:")
    print_pairs(reversed(pairs[-10:]))

    pairs = list(zip(abs(weights), words))
    pairs = sorted(pairs, key=lambda x: x[0], reverse=False)
    print("\nMost neutral words:")
    print_pairs(pairs[:10])

# %% [markdown]
#  ## Torch Logistic Regression Model

# %%
import argparse
from argparse import ArgumentParser
from datetime import datetime
import json
import logging
from pathlib import Path
import shutil
from typing import Dict, List, Tuple, Type

import numpy as np
import pytorch_lightning as pl
from pytorch_lightning import loggers as pl_loggers
from scipy import sparse
import torch
from torch import nn
from torch.utils.data.dataloader import DataLoader
from torch.utils.data.dataset import Dataset
from torchmetrics import Accuracy

class LogisticRegressionModel(nn.Module):
    """
    Logistic regression binary classification model
    """

    def __init__(self, num_features):
        """
        # Parameters
        num_features : `int`, required.
            Number of the features.
        # Returns
            `None`
        """
        super().__init__()
        self.linear = nn.Linear(num_features, 1)
        
    def forward(self, features):
        """
        Returns the logits of the model given features. 
        Note that model predictions should be either 0 or 1 based on a threshold.
        # Parameters
        features : `torch.FloatTensor`, required.
            The tensor of features with the shape (batch_size, num_of_features)
        # Returns
        probs : `torch.FloatTensor`, required.
            The tensor of probabilities with the shape (batch_size, 1) or (batch_size,)
        """
        probs = torch.sigmoid(self.linear(features))
        
        return probs

# %% [markdown]
#  ## Binary classifier as a Pytorch lightning module

# %%
class BinaryClassificationLModule(pl.LightningModule):

    def __init__(self, **kwargs):
        super().__init__()

        self.save_hyperparameters()
        data_dir = Path(self.hparams.data_dir)
        
        self.hparams.vocab = json.load(
            open(data_dir.joinpath(self.hparams.vocab_filename)))
        self.hparams.vocab_size = len(self.hparams.vocab)

        self.model = self.get_model()
        self.step_count = 0
        self.accuracy = Accuracy()

    def forward(self, *args, **kwargs):
        return self.model(*args, **kwargs)

    def training_step(self, batch, batch_idx):
        input = self.batch2input(batch)
        labels = self.batch2labels(batch)
        probs = self(**input)
        probs = probs.squeeze()
        
        criterion = torch.nn.BCEWithLogitsLoss()
        loss = criterion(probs, labels)

        self.log('train_loss', loss, prog_bar=True)
        self.log('train_acc', self.accuracy(probs, labels.int()), prog_bar=True)
        output_dict = {'loss': loss}
        return output_dict

    def validation_step(self, batch, batch_idx):
        input = self.batch2input(batch)
        labels = self.batch2labels(batch)
        probs = self(**input)
        probs = probs.squeeze()

        criterion = torch.nn.BCEWithLogitsLoss()
        loss = criterion(probs, labels)

        self.log('val_loss', loss)
        self.log('val_acc', self.accuracy(probs, labels.int()))

    def test_step(self, batch, batch_idx):
        input = self.batch2input(batch)
        labels = self.batch2labels(batch)
        probs = self(**input)
        probs = probs.squeeze()

        criterion = torch.nn.BCEWithLogitsLoss()
        loss = criterion(probs, labels)

        self.log('test_loss', loss)
        self.log('test_acc', self.accuracy(probs, labels.int()))

    def configure_optimizers(self):
        if self.hparams.optimizer == 'sgd':
            optimizer = torch.optim.SGD(self.model.parameters(),
                                        lr=self.hparams.learning_rate)
        elif self.hparams.optimizer == 'adam':
            optimizer = torch.optim.Adam(self.model.parameters(),
                                         lr=self.hparams.learning_rate)
        elif self.hparams.optimizer == 'adagrad':
            optimizer = torch.optim.Adagrad(self.model.parameters(), 
                                          lr=0.01)
        elif self.hparams.optimizer == 'rprop':
            optimizer = torch.optim.Rprop(self.model.parameters(), 
                                          lr=0.01)
        else:
            raise NotImplementedError
        return optimizer

    def train_dataloader(self):
        return self.get_dataloader('train', self.hparams.train_batch_size, shuffle=True)

    def val_dataloader(self):
        return self.get_dataloader('dev', self.hparams.eval_batch_size, shuffle=False)

    def test_dataloader(self):
        return self.get_dataloader('test', self.hparams.eval_batch_size, shuffle=False)

    def get_model(self) -> nn.Module:
        raise NotImplementedError

    def batch2input(self, batch: Tuple[torch.Tensor]) -> Dict[str, torch.Tensor]:
        raise NotImplementedError

    def batch2labels(self, batch: Tuple[torch.Tensor]) -> torch.Tensor:
        raise NotImplementedError

    def get_dataloader(self,
                       split: str,
                       batch_size: int,
                       shuffle: bool = False) -> DataLoader:
        raise NotImplementedError

    @classmethod
    def add_model_specific_args(cls, parser: ArgumentParser) -> ArgumentParser:
        """
        Add arguments to the parser and return the parser.
        See (https://pytorch-lightning.readthedocs.io/en/stable/common/hyperparameters.html)
        for usage of this method.
        """
        parser.add_argument('--vocab_filename',
                            default=None,
                            type=str,
                            required=True,
                            help="File name of the feature.")
        parser.add_argument('--optimizer',
                            default='adam',
                            type=str,
                            help="The optimizer to use, such as sgd or adam.")
        parser.add_argument('--learning_rate',
                            #default=1,
                            default=1e-3,
                            type=float,
                            help="The initial learning rate for training.")
        parser.add_argument('--max_epochs',
                            default=10,
                            type=int,
                            help="The number of epochs to train your model.")
        parser.add_argument('--train_batch_size', default=32, type=int)
        parser.add_argument('--eval_batch_size', default=32, type=int)
        parser.add_argument('--seed',
                            type=int,
                            default=42,
                            help="The random seed for initialization")
        parser.add_argument('--do_train',
                            action="store_true",
                            default=True,
                            help="Whether to run training.")
        parser.add_argument('--do_predict',
                            action="store_true",
                            help="Whether to run predictions on the test set.")
        parser.add_argument('--data_dir',
                            default="sst2",
                            type=str,
                            help="The input data dir. Should contain the training files.")
        parser.add_argument('--output_dir',
                            type=str,
                            help=("The output directory where the model predictions "
                                  "and checkpoints will be written."))
        parser.add_argument('--gpus',
                            default=0,
                            type=int,
                            help="The number of GPUs allocated for this, 0 meaning none")
        parser.add_argument('--num_workers',
                            default=8,
                            type=int,
                            help="Config `DataLoader` of pytorch")
        return parser


def generic_train(args: argparse.Namespace,
                  model_class: Type[pl.LightningModule]) -> Dict:
    """
        Train (and optionally predict) and return dict results.
        # Parameters
        args : `argparse.Namespace`, required.
            Configuration of the training and the model
        model_class : `Type[pl.LightningModule]`, required.
            Class of the model to be trained.
        # Returns
        A `dict` object containing the following keys and types.
            trainer: `pl.Trainer`
            model: `pl.LightningModule`
            val_results_best: `list[dict]`
                If `args.do_predict==True`
            test_results_best: `list[dict]`
                If `args.do_predict==True`
            best_model_path: `Path`
                Path to the checkpoint of the best model.
        """
    pl.seed_everything(args.seed)

    tensorboard_log_dir = Path(args.output_dir).joinpath('tensorboard_logs')
    tensorboard_log_dir.mkdir(parents=True, exist_ok=True)

    tensorboard_logger = pl_loggers.TensorBoardLogger(
        save_dir=tensorboard_log_dir,
        version='version_' + datetime.now().strftime('%Y%m%d-%H%M%S'),
        name='',
        default_hp_metric=True)

    checkpoint_dir = Path(args.output_dir).joinpath(tensorboard_logger.version,
                                                    'checkpoints')
    checkpoint_callback = pl.callbacks.ModelCheckpoint(dirpath=checkpoint_dir,
                                                       filename='{epoch}-{val_acc:.2f}',
                                                       monitor='val_acc',
                                                       mode='max',
                                                       save_top_k=1,
                                                       verbose=True)

    dict_args = vars(args)
    model = model_class(**dict_args)
    trainer = pl.Trainer.from_argparse_args(args,
                                            logger=tensorboard_logger,
                                            callbacks=[checkpoint_callback])

    output_dict = {'trainer': trainer, 'model': model}

    if args.do_train:
        trainer.fit(model=model)
        tensorboard_logger.log_hyperparams(
            params=model.hparams,
            metrics={'hp_metric': checkpoint_callback.best_model_score.item()})
        tensorboard_logger.save()

        best_model_path = checkpoint_dir.joinpath('best_model.ckpt')
        logger.info(f"Copy best model from {checkpoint_callback.best_model_path} "
                    f"to {best_model_path}.")
        shutil.copy(checkpoint_callback.best_model_path, best_model_path)

        output_dict.update({
            'trainer': trainer,
            'model': model,
            'best_model_path': best_model_path
        })

    if args.do_predict:
        best_model_path = checkpoint_dir.joinpath('best_model.ckpt')
        model = model.load_from_checkpoint(best_model_path)
        val_results_best = trainer.validate(model, verbose=True)
        test_results_best = trainer.test(model, verbose=True)
        print("Validation accuracy on the best model: {: .4f}".format(
            val_results_best[0]['val_acc']))
        print("Test       accuracy on the best model: {: .4f}".format(
            test_results_best[0]['test_acc']))
        output_dict.update({
            'val_results_best': val_results_best,
            'test_results_best': test_results_best,
        })

    return output_dict

# %% [markdown]
#  ## Binary classifier based on curated features.

# %%
class FeatureBasedBinaryClassificationLModule(BinaryClassificationLModule):

    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def get_model(self) -> nn.Module:
        return LogisticRegressionModel(num_features=self.hparams.vocab_size)

    def batch2input(self, batch):
        return {'features': batch[0]}

    def batch2labels(self, batch):
        return batch[1]

    def get_dataloader(self,
                       split: str,
                       batch_size: int,
                       shuffle: bool = False) -> DataLoader:
        
        data_dir = Path(self.hparams.data_dir)
        features_filepath = data_dir.joinpath(
            f"{split}_{self.hparams.feature_name}_features.npz")
        labels_filepath = data_dir.joinpath(split + "_labels.npz")
        features = sparse.load_npz(features_filepath).todense()
        labels = np.load(labels_filepath, allow_pickle=True)["arr_0"]
        dataset = torch.utils.data.TensorDataset(
            torch.from_numpy(features).float(),
            torch.from_numpy(labels).float())

        logger.info(f"Loading {split} features and labels "
                    f"from {features_filepath} and {labels_filepath}")
        data_loader = torch.utils.data.DataLoader(dataset=dataset,
                                                  batch_size=batch_size,
                                                  shuffle=shuffle,
                                                  num_workers=self.hparams.num_workers)
        return data_loader

    @classmethod
    def add_model_specific_args(cls, parser: ArgumentParser) -> ArgumentParser:
        parser = super().add_model_specific_args(parser)
        parser.add_argument('--feature_name',
                            default=None,
                            type=str,
                            required=True,
                            help="Name of the feature")
        parser.add_argument('--task',
                            default='featurebinarycls',
                            type=str,
                            help="Name of the task.")
        return parser

# %% [markdown]
#  ## Training loop for the feature-based model of binary logistic regression

# %%
logging.basicConfig(format="%(asctime)s - %(levelname)s - %(name)s - %(message)s",
                    datefmt="%Y-%m-%d %H:%M:%S",
                    level=logging.INFO)
logger = logging.getLogger(__name__)

parser = ArgumentParser()
parser = FeatureBasedBinaryClassificationLModule.add_model_specific_args(parser)

args_str = ("--vocab_filename unigram_vocab.json --feature_name unigram_binary "
            "--output_dir output/ftrlogistic --optimizer adam --do_train --do_predict ")

args = parser.parse_args(args_str.split())

if args.output_dir is None:
    args.output_dir = str(
        Path('output').joinpath(
            f"{args.task}_{datetime.now().strftime('%Y%m%d-%H%M%S')}"))
Path(args.output_dir).mkdir(parents=True, exist_ok=True)

print(f"Parsed arguments: {args}")

training_outout = generic_train(args=args,
                                model_class=FeatureBasedBinaryClassificationLModule)
# Out:
# Global seed set to 42
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Parsed arguments: Namespace(data_dir='sst2', do_predict=True, do_train=True, eval_batch_size=32, feature_name='unigram_binary', gpus=0, learning_rate=0.001, max_epochs=10, num_workers=8, optimizer='adam', output_dir='output/ftrlogistic', seed=42, task='featurebinarycls', train_batch_size=32, vocab_filename='unigram_vocab.json')
#   | Name     | Type                    | Params
# -----------------------------------------------------
# 0 | model    | LogisticRegressionModel | 5.0 K
# 1 | accuracy | Accuracy                | 0
# -----------------------------------------------------
# 5.0 K     Trainable params
# 0         Non-trainable params
# 5.0 K     Total params
# 0.020     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# 2022-02-07 01:46:40 - INFO - __main__ - Loading dev features and labels from sst2/dev_unigram_binary_features.npz and sst2/dev_labels.npz
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Global seed set to 42
# 2022-02-07 01:46:42 - INFO - __main__ - Loading train features and labels from sst2/train_unigram_binary_features.npz and sst2/train_labels.npz
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Epoch 0, global step 216: val_acc reached 0.49083 (best 0.49083), saving model to "/content/output/ftrlogistic/version_20220207-014634/checkpoints/epoch=0-val_acc=0.49.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 1, global step 433: val_acc was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 2, global step 650: val_acc reached 0.53211 (best 0.53211), saving model to "/content/output/ftrlogistic/version_20220207-014634/checkpoints/epoch=2-val_acc=0.53.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 3, global step 867: val_acc reached 0.59977 (best 0.59977), saving model to "/content/output/ftrlogistic/version_20220207-014634/checkpoints/epoch=3-val_acc=0.60.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 4, global step 1084: val_acc reached 0.66399 (best 0.66399), saving model to "/content/output/ftrlogistic/version_20220207-014634/checkpoints/epoch=4-val_acc=0.66.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 5, global step 1301: val_acc reached 0.68922 (best 0.68922), saving model to "/content/output/ftrlogistic/version_20220207-014634/checkpoints/epoch=5-val_acc=0.69.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 6, global step 1518: val_acc reached 0.71330 (best 0.71330), saving model to "/content/output/ftrlogistic/version_20220207-014634/checkpoints/epoch=6-val_acc=0.71.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 7, global step 1735: val_acc reached 0.73739 (best 0.73739), saving model to "/content/output/ftrlogistic/version_20220207-014634/checkpoints/epoch=7-val_acc=0.74.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 8, global step 1952: val_acc reached 0.74541 (best 0.74541), saving model to "/content/output/ftrlogistic/version_20220207-014634/checkpoints/epoch=8-val_acc=0.75.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 9, global step 2169: val_acc reached 0.75000 (best 0.75000), saving model to "/content/output/ftrlogistic/version_20220207-014634/checkpoints/epoch=9-val_acc=0.75.ckpt" as top 1
# 2022-02-07 01:47:17 - INFO - __main__ - Copy best model from /content/output/ftrlogistic/version_20220207-014634/checkpoints/epoch=9-val_acc=0.75.ckpt to output/ftrlogistic/version_20220207-014634/checkpoints/best_model.ckpt.
# 2022-02-07 01:47:17 - INFO - __main__ - Loading dev features and labels from sst2/dev_unigram_binary_features.npz and sst2/dev_labels.npz
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Validating: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 VALIDATE RESULTS
# {'val_acc': 0.75, 'val_loss': 0.6399576663970947}
# --------------------------------------------------------------------------------
# 2022-02-07 01:47:18 - INFO - __main__ - Loading test features and labels from sst2/test_unigram_binary_features.npz and sst2/test_labels.npz
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Testing: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.7567270994186401, 'test_loss': 0.6439116597175598}
# --------------------------------------------------------------------------------
# Validation accuracy on the best model:  0.7500
# Test       accuracy on the best model:  0.7567

# %% [markdown]
#  ## Feature weight analysis

# %%
model = training_outout['model']
best_model_path = training_outout['best_model_path']
data_dir = Path('sst2')

model = model.load_from_checkpoint(best_model_path)
weights = model.model.linear.weight.squeeze().detach().numpy()
vocab = json.load(open(data_dir.joinpath('unigram_vocab.json')))
print_important_weights(weights=weights, words=vocab.keys())
# Out:
# Most positive words:
#  0.7245 | best
#  0.7157 | powerful
#  0.7087 | solid
#  0.7068 | fun
#  0.6341 | heart
#  0.6335 | enjoyable
#  0.6182 | entertaining
#  0.5945 | moving
#  0.5836 | portrait
#  0.5788 | wonderful
#
# Most negative words:
# -0.8932 | too
# -0.8373 | bad
# -0.7212 | ?
# -0.6349 | dull
# -0.6252 | worst
# -0.6169 | mess
# -0.6143 | no
# -0.5759 | suffers
# -0.5630 | stupid
# -0.5351 | plot
#
# Most neutral words:
#  0.0000 | charge
#  0.0001 | storyline
#  0.0001 | somehow
#  0.0001 | zombie
#  0.0002 | luster
#  0.0002 | philosophical
#  0.0003 | rob
#  0.0004 | telling
#  0.0005 | wallace
#  0.0005 | effects

# %% [markdown]
# ## Error Analysis

# %%
def error_analysis(fit_model, test_X):
    '''
    Returns predicted label output for given training and testing data
    '''

    test_X = test_X.todense()
    test_X = torch.from_numpy(test_X).float()
    
    y_pred = fit_model(test_X)
    y_pred = y_pred.detach().numpy()
    y_pred = np.where(y_pred <= 0.5, 0, y_pred) 
    y_pred = np.where(y_pred > 0.5, 1, y_pred) 
    
    return y_pred.T[0]

test_labels = np.load('sst2/test_labels.npz')
test_features = sparse.load_npz('sst2/test_unigram_binary_features.npz')
test_model = error_analysis(model.load_from_checkpoint(best_model_path), test_features)

# %%
import pandas as pd
from nltk.tokenize import WordPunctTokenizer

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

def error_frame(pred_model, labels):
    '''
    Generates a pandas dataframe of mislabeled reviews
    '''
    
    tokenizer = WordPunctTokenizer()
    label_column = pd.DataFrame(labels)
    label_column.rename(columns = {0: "True"}, inplace = True)
    model_column = pd.DataFrame(pred_model)
    model_column.rename(columns = {0: "Predicted"}, inplace = True)
    
    data_test = open(data_dir.joinpath('sst2.test')).readlines()
    tokens = []
    for line in data_test:
        lower_line = line.lower()
        tokens.append(tokenizer.tokenize(lower_line))
    
    full_frame = label_column.join(model_column)
    full_frame["Match"] = (full_frame["True"] == full_frame["Predicted"]).astype(int)
    full_frame["Line"] = tokens
    full_frame.index += 1
    
    print("The number of errors found: ", len(full_frame.loc[full_frame['Match'] == 0]))
    return full_frame.loc[full_frame['Match'] == 0]
    
error_frame(test_model, test_labels['arr_0'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   import s
# 1706  [1, awkward, but, sincere, and, ,, ultimately, ,, it, wins, you, over, .]
# 1716  [1, this, cheery, ,, down, -, to, -, earth, film, is, warm, with, the, cozy, feeling, of, relaxing, around, old, friends, .]
# 1730  [1, if, this, movie, were, a, book, ,, it, would, be, a, page, -, turner, ,, you, ca, n, ', t, wait, to, see, what, happens, next, .]
# 1732  [1, -, lrb, -, villeneuve, -, rrb, -, seems, to, realize, intuitively, that, even, morality, is, reduced, to, an, option, by, the, ultimate, mysteries, of, life, and, death, .]
# 1736  [1, for, benigni, it, was, n, ', t, shakespeare, whom, he, wanted, to, define, his, career, with, but, pinocchio, .]
# 1741  [1, guaranteed, to, move, anyone, who, ever, shook, ,, rattled, ,, or, rolled, .]
# 1742  [0, unlike, his, directorial, efforts, ,, la, femme, nikita, and, the, professional, ,, the, transporter, lacks, besson, ', s, perspective, as, a, storyteller, .]
# 1743  [1, at, about, 95, minutes, ,, treasure, planet, maintains, a, brisk, pace, as, it, races, through, the, familiar, story, .]
# 1753  [1, steers, turns, in, a, snappy, screenplay, that, curls, at, the, edges, ;, it, ', s, so, clever, you, want, to, hate, it, .]
# 1754  [1, this, is, what, imax, was, made, for, :, strap, on, a, pair, of, 3, -, d, goggles, ,, shut, out, the, real, world, ,, and, take, a, vicarious, voyage, to, the, last, frontier, --, space, .]
# 1759  [1, there, are, just, enough, twists, in, the, tale, to, make, it, far, more, satisfying, than, almost, any, horror, film, in, recent, memory, .]
# 1772  [1, tailored, to, entertain, !]
# 1775  [1, the, tone, is, balanced, ,, reflective, and, reasonable, .]
# 1779  [1, an, intimate, ,, good, -, humored, ethnic, comedy, like, numerous, others, but, cuts, deeper, than, expected, .]
# 1780  [1, fans, of, the, animated, wildlife, adventure, show, will, be, in, warthog, heaven, ;, others, need, not, necessarily, apply, .]
# 1807  [1, a, sensitive, and, expertly, acted, crowd, -, pleaser, that, is, n, ', t, above, a, little, broad, comedy, and, a, few, unabashedly, sentimental, tears, .]
# 1808  [1, the, experience, of, watching, blobby, old, -, school, cgi, animation, in, this, superlarge, format, is, just, surreal, enough, to, be, diverting, .]
# 1813  [1, -, lrb, -, a, -, rrb, -, hollywood, sheen, bedevils, the, film, from, the, very, beginning, ..., -, lrb, -, but, -, rrb, -, lohman, ', s, moist, ,, deeply, emotional, eyes, shine, through, this, bogus, veneer, ...]
# 1815  [1, ..., blade, ii, is, more, enjoyable, than, the, original, .]
# 1819  [0, safe, conduct, ,, however, ambitious, and, well, -, intentioned, ,, fails, to, hit, the, entertainment, bull, ', s, -, eye, .]

# %%
def print_weight(weights, words):
    """
    Prints all word-weight pairs for given data and vocabulary
    """

    def print_pairs(pairs):
        for weight, word in pairs:
            print("{: .4f} | {}".format(weight, word))

    assert len(weights) == len(words)
    pairs = list(zip(weights, words))
    pairs = sorted(pairs, key=lambda x: x[0], reverse=True)
    print_pairs(pairs)

# %%
print_weight(weights=weights, words=vocab.keys())
# Out:
#  0.7245 | best
#  0.7157 | powerful
#  0.7087 | solid
#  0.7068 | fun
#  0.6341 | heart
#  0.6335 | enjoyable
#  0.6182 | entertaining
#  0.5945 | moving
#  0.5836 | portrait
#  0.5788 | wonderful
#  0.5593 | beautifully
#  0.5571 | works
#  0.5567 | fascinating
#  0.5530 | always
#  0.5521 | touching
#  0.5501 | funny
#  0.5377 | remarkable
#  0.5363 | love
#  0.5308 | family
#  0.5289 | terrific
#  0.5284 | rare
#  0.5259 | beautiful
#  0.5238 | perfectly
#  0.5217 | worth
#  0.5206 | captures
#  0.5193 | refreshing
#  0.5167 | documentary
#  0.5083 | engrossing
#  0.5055 | human
#  0.5024 | hilarious
#  0.5006 | inventive
#  0.4992 | performances
#  0.4972 | charming
#  0.4939 | warm
#  0.4913 | spirit
#  0.4901 | thoughtful
#  0.4872 | spielberg
#  0.4867 | cinema
#  0.4836 | manages
#  0.4831 | somewhat
#  0.4829 | delivers
#  0.4802 | performance
#  0.4766 | our
#  0.4697 | fashioned
#  0.4676 | unexpected
#  0.4656 | definitely
#  0.4643 | deeply
#  0.4627 | years
#  0.4597 | brings
#  0.4547 | also
#  0.4545 | provides
#  0.4541 | unique
#  0.4501 | wonderfully
#  0.4482 | world
#  0.4447 | dazzling
#  0.4437 | intelligent
#  0.4426 | witty
#  0.4413 | elegant
#  0.4406 | brilliant
#  0.4403 | treat
#  0.4382 | appealing
#  0.4381 | enjoyed
#  0.4377 | riveting
#  0.4303 | eyes
#  0.4300 | smart
#  0.4280 | sweet
#  0.4276 | vibrant
#  0.4274 | delightful
#  0.4268 | assured
#  0.4252 | gem
#  0.4241 | rich
#  0.4228 | part
#  0.4226 | compelling
#  0.4200 | undeniably
#  0.4155 | chilling
#  0.4146 | beauty
#  0.4141 | heartwarming
#  0.4140 | honest
#  0.4099 | spectacular
#  0.4088 | absorbing
#  0.4082 | pleasing
#  0.4079 | intoxicating
#  0.4055 | look
#  0.4053 | impressive
#  0.4039 | strange
#  0.4037 | frailty
#  0.4003 | perfect
#  0.3974 | heartfelt
#  0.3973 | places
#  0.3971 | and
#  0.3970 | refreshingly
#  0.3961 | stirring
#  0.3956 | still
#  0.3950 | meditation
#  0.3938 | musical
#  0.3937 | us
#  0.3925 | answers
#  0.3909 | pleasures
#  0.3880 | masterpiece
#  0.3866 | bittersweet
#  0.3848 | delicate
#  0.3843 | joyous
#  0.3841 | delight
#  0.3832 | chance
#  0.3831 | summer
#  0.3810 | ride
#  0.3808 | charmer
#  0.3807 | playful
#  0.3801 | imax
#  0.3785 | journey
#  0.3776 | notch
#  0.3772 | hearts
#  0.3772 | cat
#  0.3762 | sharp
#  0.3754 | hopeful
#  0.3751 | power
#  0.3731 | thought
#  0.3720 | form
#  0.3711 | america
#  0.3705 | mesmerizing
#  0.3703 | imagery
#  0.3690 | nicholson
#  0.3678 | indian
#  0.3678 | ability
#  0.3664 | stunning
#  0.3646 | gorgeous
#  0.3645 | oddly
#  0.3643 | culture
#  0.3634 | gosling
#  0.3634 | french
#  0.3622 | rewarding
#  0.3615 | life
#  0.3608 | sweetly
#  0.3607 | well
#  0.3603 | ghetto
#  0.3582 | engaging
#  0.3581 | heartbreaking
#  0.3580 | means
#  0.3578 | record
#  0.3576 | vividly
#  0.3563 | russian
#  0.3561 | detailed
#  0.3546 | respect
#  0.3545 | thanks
#  0.3535 | resist
#  0.3529 | amazing
#  0.3525 | wry
#  0.3524 | deft
#  0.3521 | allows
#  0.3520 | work
#  0.3520 | help
#  0.3519 | highly
#  0.3518 | pulls
#  0.3517 | excellent
#  0.3506 | touched
#  0.3502 | satisfying
#  0.3495 | succeeds
#  0.3493 | sadness
#  0.3491 | vivid
#  0.3484 | behold
#  0.3482 | intriguing
#  0.3467 | ramsay
#  0.3465 | combines
#  0.3460 | smarter
#  0.3457 | sparkling
#  0.3455 | gently
#  0.3451 | strong
#  0.3446 | wrenching
#  0.3439 | cast
#  0.3435 | evocative
#  0.3435 | measured
#  0.3434 | keep
#  0.3433 | delicately
#  0.3427 | integrity
#  0.3427 | extraordinary
#  0.3425 | with
#  0.3422 | faith
#  0.3417 | history
#  0.3415 | great
#  0.3404 | both
#  0.3389 | quietly
#  0.3385 | diversion
#  0.3384 | haunting
#  0.3382 | tragedy
#  0.3376 | force
#  0.3374 | deftly
#  0.3374 | good
#  0.3371 | subtle
#  0.3367 | pure
#  0.3351 | colorful
#  0.3347 | breathtaking
#  0.3332 | masterful
#  0.3330 | adventure
#  0.3318 | startling
#  0.3317 | miller
#  0.3314 | polanski
#  0.3312 | harrowing
#  0.3309 | creative
#  0.3307 | hope
#  0.3303 | accomplished
#  0.3301 | duvall
#  0.3291 | sympathetic
#  0.3286 | delightfully
#  0.3284 | kidman
#  0.3283 | flawed
#  0.3279 | souls
#  0.3271 | faithful
#  0.3270 | visceral
#  0.3264 | conduct
#  0.3262 | stuart
#  0.3262 | delivering
#  0.3261 | study
#  0.3255 | soulful
#  0.3254 | ages
#  0.3249 | delicious
#  0.3249 | unforced
#  0.3248 | nice
#  0.3248 | bringing
#  0.3247 | cheek
#  0.3247 | wide
#  0.3244 | year
#  0.3239 | different
#  0.3238 | son
#  0.3236 | intimate
#  0.3235 | france
#  0.3234 | smartly
#  0.3231 | uplifting
#  0.3221 | creates
#  0.3218 | washington
#  0.3214 | constant
#  0.3207 | layers
#  0.3202 | masterfully
#  0.3201 | winning
#  0.3200 | strikes
#  0.3199 | changing
#  0.3197 | grace
#  0.3197 | intense
#  0.3184 | tender
#  0.3183 | tears
#  0.3181 | crisp
#  0.3180 | thrill
#  0.3178 | shanghai
#  0.3171 | marks
#  0.3168 | thick
#  0.3167 | red
#  0.3165 | finely
#  0.3162 | tsai
#  0.3147 | lips
#  0.3146 | adventurous
#  0.3144 | richly
#  0.3144 | unpredictable
#  0.3143 | barry
#  0.3138 | ways
#  0.3137 | while
#  0.3134 | spare
#  0.3131 | conservative
#  0.3118 | sexy
#  0.3113 | pleaser
#  0.3111 | humorous
#  0.3110 | bring
#  0.3107 | polished
#  0.3106 | celebrates
#  0.3104 | sensual
#  0.3103 | builds
#  0.3097 | age
#  0.3093 | gentle
#  0.3088 | experience
#  0.3086 | unnerving
#  0.3077 | timely
#  0.3076 | authority
#  0.3075 | damn
#  0.3075 | viewing
#  0.3074 | light
#  0.3073 | art
#  0.3072 | wonders
#  0.3069 | sly
#  0.3063 | whimsical
#  0.3062 | understated
#  0.3047 | enormously
#  0.3047 | leigh
#  0.3047 | energetic
#  0.3047 | remarkably
#  0.3046 | patient
#  0.3045 | encouraging
#  0.3039 | poem
#  0.3038 | experiment
#  0.3034 | splendid
#  0.3034 | jessica
#  0.3031 | gives
#  0.3025 | spell
#  0.3022 | immensely
#  0.3009 | secretary
#  0.3007 | affection
#  0.3006 | drama
#  0.3004 | universal
#  0.3000 | quirky
#  0.2990 | outstanding
#  0.2987 | greek
#  0.2986 | man
#  0.2982 | fluid
#  0.2982 | born
#  0.2980 | speaks
#  0.2974 | cool
#  0.2972 | understands
#  0.2972 | originality
#  0.2971 | politically
#  0.2969 | gripping
#  0.2967 | saga
#  0.2966 | foster
#  0.2966 | fessenden
#  0.2964 | openness
#  0.2960 | pacino
#  0.2959 | sobering
#  0.2950 | guessing
#  0.2944 | confident
#  0.2943 | genuine
#  0.2942 | piece
#  0.2940 | astonishing
#  0.2938 | melancholy
#  0.2937 | transcends
#  0.2937 | poignant
#  0.2934 | successful
#  0.2931 | shines
#  0.2930 | rank
#  0.2928 | modest
#  0.2926 | reminder
#  0.2924 | offers
#  0.2923 | twohy
#  0.2918 | profile
#  0.2913 | mood
#  0.2912 | reveals
#  0.2906 | hypnotic
#  0.2905 | relief
#  0.2899 | clooney
#  0.2896 | tour
#  0.2895 | guaranteed
#  0.2895 | idiosyncratic
#  0.2892 | deliciously
#  0.2891 | impressively
#  0.2887 | ideal
#  0.2885 | adequately
#  0.2884 | cult
#  0.2882 | enormous
#  0.2880 | inspirational
#  0.2880 | unusual
#  0.2874 | watchable
#  0.2871 | demons
#  0.2870 | contemporary
#  0.2870 | effective
#  0.2870 | job
#  0.2866 | captivating
#  0.2864 | exhilarating
#  0.2864 | strength
#  0.2859 | huppert
#  0.2855 | alert
#  0.2855 | solidly
#  0.2854 | greene
#  0.2853 | irresistible
#  0.2850 | freedom
#  0.2834 | usual
#  0.2833 | peek
#  0.2833 | smile
#  0.2831 | ingenious
#  0.2829 | deceptively
#  0.2828 | neil
#  0.2827 | happiness
#  0.2826 | chabrol
#  0.2826 | accept
#  0.2826 | genre
#  0.2825 | band
#  0.2823 | ballot
#  0.2820 | haynes
#  0.2817 | slightly
#  0.2817 | spike
#  0.2812 | drumline
#  0.2812 | technology
#  0.2811 | lifts
#  0.2810 | duke
#  0.2807 | examines
#  0.2800 | bold
#  0.2798 | living
#  0.2793 | excels
#  0.2788 | sisters
#  0.2787 | gloriously
#  0.2786 | flow
#  0.2785 | destined
#  0.2783 | resonant
#  0.2780 | makes
#  0.2777 | bogdanovich
#  0.2774 | testament
#  0.2769 | glimpse
#  0.2767 | taut
#  0.2767 | unfolds
#  0.2767 | quiet
#  0.2762 | honesty
#  0.2757 | transforms
#  0.2753 | consistently
#  0.2750 | curves
#  0.2750 | confidence
#  0.2749 | blend
#  0.2744 | tomorrow
#  0.2739 | cho
#  0.2734 | gradually
#  0.2729 | familial
#  0.2728 | popcorn
#  0.2728 | willing
#  0.2726 | music
#  0.2724 | loneliness
#  0.2724 | carmen
#  0.2723 | satisfies
#  0.2721 | provocative
#  0.2720 | her
#  0.2717 | impeccable
#  0.2717 | perspective
#  0.2716 | paxton
#  0.2711 | concern
#  0.2707 | steal
#  0.2706 | salton
#  0.2702 | yiddish
#  0.2701 | provoking
#  0.2701 | rodriguez
#  0.2700 | potent
#  0.2699 | stylized
#  0.2697 | detail
#  0.2691 | surprisingly
#  0.2690 | nerve
#  0.2680 | relationship
#  0.2678 | distinctive
#  0.2678 | explore
#  0.2678 | moonlight
#  0.2675 | physical
#  0.2673 | bowling
#  0.2669 | waydowntown
#  0.2665 | proud
#  0.2663 | humanity
#  0.2663 | holofcener
#  0.2659 | edges
#  0.2655 | korean
#  0.2650 | embraces
#  0.2650 | chief
#  0.2646 | miyazaki
#  0.2645 | campanella
#  0.2644 | deep
#  0.2644 | managed
#  0.2643 | argue
#  0.2643 | subtly
#  0.2638 | chord
#  0.2637 | kinnear
#  0.2634 | daily
#  0.2633 | worthwhile
#  0.2631 | romances
#  0.2629 | film
#  0.2627 | industry
#  0.2627 | kwan
#  0.2626 | nicole
#  0.2625 | whale
#  0.2623 | revelation
#  0.2621 | denying
#  0.2620 | unexpectedly
#  0.2620 | constructed
#  0.2620 | isolation
#  0.2619 | camera
#  0.2615 | superbly
#  0.2613 | gorgeously
#  0.2612 | wedding
#  0.2609 | uncompromising
#  0.2605 | department
#  0.2602 | explores
#  0.2601 | believable
#  0.2601 | challenges
#  0.2599 | jealousy
#  0.2599 | simple
#  0.2598 | layered
#  0.2594 | nuanced
#  0.2592 | neighborhood
#  0.2589 | uses
#  0.2588 | 20th
#  0.2588 | average
#  0.2583 | taking
#  0.2583 | fits
#  0.2581 | true
#  0.2576 | crack
#  0.2576 | edge
#  0.2575 | discovery
#  0.2572 | whose
#  0.2571 | scope
#  0.2571 | artist
#  0.2571 | later
#  0.2569 | kissing
#  0.2569 | showcases
#  0.2567 | flaws
#  0.2566 | ties
#  0.2566 | recovery
#  0.2565 | follow
#  0.2564 | intelligently
#  0.2561 | gory
#  0.2561 | holds
#  0.2557 | invaluable
#  0.2556 | lets
#  0.2552 | specifically
#  0.2550 | uncommonly
#  0.2549 | diverse
#  0.2544 | sustains
#  0.2544 | consuming
#  0.2541 | interaction
#  0.2538 | miracle
#  0.2538 | comics
#  0.2537 | visuals
#  0.2537 | exotic
#  0.2532 | incredible
#  0.2531 | perdition
#  0.2531 | primary
#  0.2527 | hopefully
#  0.2526 | extraordinarily
#  0.2525 | landscape
#  0.2524 | skillfully
#  0.2523 | lie
#  0.2520 | system
#  0.2518 | quieter
#  0.2517 | fantastic
#  0.2516 | dickens
#  0.2516 | napoleon
#  0.2514 | glorious
#  0.2512 | imamura
#  0.2511 | enduring
#  0.2511 | popular
#  0.2510 | benefit
#  0.2509 | wing
#  0.2505 | daniel
#  0.2503 | films
#  0.2502 | tuned
#  0.2499 | dancing
#  0.2499 | worthy
#  0.2498 | played
#  0.2497 | suitably
#  0.2495 | bond
#  0.2495 | infuses
#  0.2495 | ache
#  0.2493 | woman
#  0.2492 | bartlett
#  0.2489 | franklin
#  0.2488 | timeless
#  0.2487 | animated
#  0.2487 | chuckle
#  0.2486 | strongest
#  0.2485 | win
#  0.2485 | chaos
#  0.2484 | angel
#  0.2483 | forceful
#  0.2477 | enjoy
#  0.2477 | courage
#  0.2476 | ferrara
#  0.2475 | moviemaking
#  0.2473 | handling
#  0.2473 | most
#  0.2471 | korea
#  0.2470 | elevates
#  0.2468 | pleasure
#  0.2465 | reassuring
#  0.2463 | betrayal
#  0.2463 | romp
#  0.2461 | breathes
#  0.2459 | stein
#  0.2456 | savvy
#  0.2456 | urgency
#  0.2456 | peter
#  0.2455 | reminds
#  0.2452 | rocks
#  0.2451 | tempting
#  0.2450 | separate
#  0.2448 | raw
#  0.2448 | carries
#  0.2443 | returns
#  0.2437 | tosca
#  0.2435 | establishes
#  0.2432 | burst
#  0.2431 | gosford
#  0.2431 | lonely
#  0.2431 | stark
#  0.2431 | dazzle
#  0.2430 | father
#  0.2425 | marshall
#  0.2425 | rubbo
#  0.2424 | marvelously
#  0.2424 | element
#  0.2420 | lovers
#  0.2420 | passionate
#  0.2417 | unpretentious
#  0.2417 | format
#  0.2417 | confessions
#  0.2417 | grew
#  0.2416 | uniformly
#  0.2416 | resistance
#  0.2414 | undercurrent
#  0.2413 | happy
#  0.2410 | cops
#  0.2410 | lord
#  0.2409 | craig
#  0.2407 | sophisticated
#  0.2407 | odyssey
#  0.2406 | darned
#  0.2402 | moviegoing
#  0.2402 | objectivity
#  0.2402 | welsh
#  0.2400 | group
#  0.2400 | moore
#  0.2400 | sneaks
#  0.2398 | shortcomings
#  0.2398 | esteem
#  0.2395 | literate
#  0.2394 | charlotte
#  0.2393 | recent
#  0.2393 | compulsively
#  0.2391 | engagingly
#  0.2391 | wholesome
#  0.2390 | manage
#  0.2389 | capturing
#  0.2387 | kosminsky
#  0.2387 | saves
#  0.2386 | breathtakingly
#  0.2386 | unblinking
#  0.2381 | stroke
#  0.2378 | packed
#  0.2378 | formed
#  0.2378 | beats
#  0.2378 | chaplin
#  0.2376 | exceptional
#  0.2375 | breaking
#  0.2375 | infectious
#  0.2373 | unknown
#  0.2372 | beneath
#  0.2371 | adrenaline
#  0.2371 | realistic
#  0.2368 | canon
#  0.2367 | skin
#  0.2367 | draws
#  0.2365 | touch
#  0.2364 | since
#  0.2364 | portrayal
#  0.2362 | compellingly
#  0.2361 | struggles
#  0.2360 | goods
#  0.2360 | awake
#  0.2360 | resonate
#  0.2358 | derrida
#  0.2357 | taps
#  0.2357 | skillful
#  0.2354 | everyday
#  0.2354 | inviting
#  0.2351 | bourne
#  0.2350 | lesser
#  0.2349 | escapist
#  0.2349 | food
#  0.2348 | seeing
#  0.2348 | depiction
#  0.2347 | intellect
#  0.2346 | brilliantly
#  0.2346 | you
#  0.2343 | brave
#  0.2343 | greatness
#  0.2339 | urban
#  0.2338 | shakespearean
#  0.2334 | right
#  0.2331 | brown
#  0.2329 | variety
#  0.2329 | mythic
#  0.2328 | steals
#  0.2325 | lee
#  0.2324 | goofball
#  0.2322 | dickensian
#  0.2316 | toes
#  0.2315 | heartbreak
#  0.2314 | kubrick
#  0.2312 | grown
#  0.2311 | read
#  0.2310 | others
#  0.2310 | morton
#  0.2308 | higher
#  0.2307 | foremost
#  0.2306 | israeli
#  0.2306 | intact
#  0.2303 | immediacy
#  0.2302 | filmmaker
#  0.2302 | incident
#  0.2302 | ably
#  0.2300 | reveal
#  0.2299 | suitable
#  0.2298 | warrior
#  0.2296 | robert
#  0.2295 | china
#  0.2295 | horrifying
#  0.2292 | face
#  0.2291 | tradition
#  0.2291 | bravery
#  0.2290 | allowing
#  0.2286 | heroic
#  0.2285 | extravagant
#  0.2284 | lightly
#  0.2284 | eloquently
#  0.2283 | insightfully
#  0.2283 | roles
#  0.2283 | silver
#  0.2283 | puts
#  0.2282 | pianist
#  0.2282 | darling
#  0.2280 | bill
#  0.2280 | exploration
#  0.2280 | prism
#  0.2279 | hoot
#  0.2278 | adult
#  0.2277 | tale
#  0.2277 | christopher
#  0.2275 | nair
#  0.2275 | albeit
#  0.2273 | prose
#  0.2273 | yarn
#  0.2273 | likeable
#  0.2272 | liberating
#  0.2270 | venice
#  0.2269 | sublime
#  0.2268 | heaven
#  0.2266 | embracing
#  0.2265 | pulpy
#  0.2265 | hidden
#  0.2263 | arresting
#  0.2261 | pertinent
#  0.2259 | surprising
#  0.2259 | education
#  0.2257 | illuminating
#  0.2257 | sprightly
#  0.2257 | empire
#  0.2256 | images
#  0.2256 | tavernier
#  0.2256 | chinese
#  0.2256 | examination
#  0.2255 | fast
#  0.2252 | bodied
#  0.2251 | strangely
#  0.2250 | canny
#  0.2250 | overrun
#  0.2249 | slight
#  0.2248 | bracing
#  0.2248 | grind
#  0.2246 | juan
#  0.2244 | martha
#  0.2244 | elegance
#  0.2242 | alice
#  0.2242 | racial
#  0.2239 | bride
#  0.2237 | their
#  0.2233 | mamet
#  0.2233 | scott
#  0.2232 | an
#  0.2230 | purely
#  0.2229 | kahlo
#  0.2228 | unlike
#  0.2227 | huston
#  0.2227 | may
#  0.2226 | claude
#  0.2225 | obstacles
#  0.2224 | jolt
#  0.2223 | surreal
#  0.2222 | communal
#  0.2222 | expressive
#  0.2220 | beings
#  0.2216 | pellington
#  0.2216 | enveloping
#  0.2215 | passions
#  0.2215 | visually
#  0.2207 | design
#  0.2206 | pleasurable
#  0.2205 | thornberrys
#  0.2204 | columbine
#  0.2204 | tongue
#  0.2202 | multi
#  0.2201 | capability
#  0.2198 | unconditional
#  0.2197 | century
#  0.2195 | minor
#  0.2194 | embrace
#  0.2194 | vietnamese
#  0.2193 | knows
#  0.2192 | spirits
#  0.2191 | possess
#  0.2191 | ahead
#  0.2190 | collectively
#  0.2190 | memento
#  0.2190 | keeping
#  0.2189 | nervy
#  0.2188 | outer
#  0.2187 | breadth
#  0.2186 | environment
#  0.2186 | tension
#  0.2186 | appreciate
#  0.2186 | seams
#  0.2185 | spiced
#  0.2185 | vintage
#  0.2184 | especially
#  0.2181 | dragon
#  0.2180 | backdrop
#  0.2179 | metaphorical
#  0.2179 | submarine
#  0.2179 | broadway
#  0.2175 | predecessor
#  0.2175 | jacquot
#  0.2174 | questions
#  0.2173 | traditional
#  0.2173 | quaid
#  0.2173 | gritty
#  0.2172 | dynamics
#  0.2171 | insane
#  0.2167 | hashiguchi
#  0.2167 | nachtwey
#  0.2165 | hatred
#  0.2164 | surprised
#  0.2163 | debate
#  0.2161 | cerebral
#  0.2160 | nicely
#  0.2158 | bridge
#  0.2157 | twisted
#  0.2157 | satisfyingly
#  0.2156 | subversive
#  0.2154 | fantasies
#  0.2153 | metropolis
#  0.2152 | take
#  0.2149 | fontaine
#  0.2149 | captivates
#  0.2149 | dover
#  0.2148 | young
#  0.2148 | ambiguity
#  0.2148 | realistically
#  0.2148 | striking
#  0.2143 | child
#  0.2143 | wang
#  0.2142 | salma
#  0.2140 | laughter
#  0.2140 | crafted
#  0.2138 | anguish
#  0.2138 | wondrous
#  0.2137 | flair
#  0.2136 | garcia
#  0.2135 | lovely
#  0.2135 | birthday
#  0.2130 | treasure
#  0.2130 | interviews
#  0.2129 | ian
#  0.2127 | adds
#  0.2127 | neatly
#  0.2124 | driven
#  0.2122 | nerves
#  0.2121 | lane
#  0.2120 | demonstrates
#  0.2119 | charged
#  0.2119 | woven
#  0.2118 | tough
#  0.2117 | native
#  0.2116 | starting
#  0.2114 | functions
#  0.2114 | memorable
#  0.2114 | larger
#  0.2114 | rival
#  0.2113 | enhances
#  0.2110 | binoche
#  0.2110 | sun
#  0.2109 | iconoclastic
#  0.2108 | share
#  0.2106 | splashed
#  0.2106 | schmidt
#  0.2105 | smith
#  0.2104 | minds
#  0.2104 | composition
#  0.2104 | fierce
#  0.2102 | effortlessly
#  0.2101 | refusal
#  0.2100 | unforgettable
#  0.2100 | informative
#  0.2099 | impact
#  0.2095 | spite
#  0.2094 | refugees
#  0.2094 | singing
#  0.2093 | skins
#  0.2091 | obsessions
#  0.2090 | reminiscent
#  0.2089 | positive
#  0.2088 | themes
#  0.2087 | access
#  0.2087 | caine
#  0.2085 | introduction
#  0.2085 | levels
#  0.2083 | visit
#  0.2076 | graham
#  0.2076 | michael
#  0.2075 | knowledge
#  0.2072 | beguiling
#  0.2069 | pleasant
#  0.2067 | cuban
#  0.2066 | jolts
#  0.2065 | beast
#  0.2064 | audiard
#  0.2064 | war
#  0.2063 | morvern
#  0.2061 | psycho
#  0.2061 | delights
#  0.2060 | limits
#  0.2058 | searing
#  0.2057 | successfully
#  0.2057 | sides
#  0.2055 | 50s
#  0.2054 | enigmatic
#  0.2053 | sensibility
#  0.2051 | piercing
#  0.2051 | flashes
#  0.2048 | live
#  0.2046 | responsibility
#  0.2045 | affecting
#  0.2043 | mr
#  0.2042 | charismatic
#  0.2042 | document
#  0.2041 | kosashvili
#  0.2041 | lies
#  0.2037 | belongs
#  0.2035 | mysteries
#  0.2035 | lends
#  0.2032 | office
#  0.2021 | reminded
#  0.2020 | wallop
#  0.2018 | greater
#  0.2018 | undeniable
#  0.2018 | reliable
#  0.2017 | heat
#  0.2017 | bloody
#  0.2013 | economic
#  0.2012 | gut
#  0.2009 | israel
#  0.2009 | richer
#  0.2008 | via
#  0.2007 | acted
#  0.2002 | sensitivity
#  0.2001 | detective
#  0.2000 | educational
#  0.1999 | warmth
#  0.1996 | expertly
#  0.1995 | simplicity
#  0.1991 | cheeky
#  0.1991 | tiny
#  0.1989 | idealism
#  0.1986 | iranian
#  0.1986 | jaw
#  0.1985 | society
#  0.1984 | rapid
#  0.1984 | pointed
#  0.1984 | ,
#  0.1983 | !
#  0.1982 | seen
#  0.1980 | standards
#  0.1976 | testimony
#  0.1975 | alternately
#  0.1974 | superb
#  0.1974 | likable
#  0.1973 | gere
#  0.1972 | griffiths
#  0.1970 | ended
#  0.1969 | romantic
#  0.1969 | tragically
#  0.1962 | considerable
#  0.1961 | straightforward
#  0.1958 | ancient
#  0.1957 | roll
#  0.1956 | resourceful
#  0.1953 | providing
#  0.1953 | entertainment
#  0.1951 | paints
#  0.1949 | credit
#  0.1949 | imaginative
#  0.1946 | talk
#  0.1945 | timing
#  0.1943 | walk
#  0.1943 | skill
#  0.1941 | color
#  0.1941 | rhythms
#  0.1941 | modern
#  0.1938 | revealing
#  0.1938 | elusive
#  0.1933 | deeds
#  0.1933 | janklowicz
#  0.1932 | overwhelming
#  0.1932 | marriage
#  0.1931 | white
#  0.1931 | uncanny
#  0.1927 | sensitive
#  0.1920 | amused
#  0.1917 | photographed
#  0.1917 | manhattan
#  0.1915 | odds
#  0.1915 | existed
#  0.1913 | meditative
#  0.1909 | hayek
#  0.1909 | grand
#  0.1907 | mel
#  0.1906 | relationships
#  0.1905 | large
#  0.1902 | directors
#  0.1900 | see
#  0.1894 | j
#  0.1890 | amiable
#  0.1887 | diesel
#  0.1887 | often
#  0.1886 | wanted
#  0.1884 | wilco
#  0.1881 | existential
#  0.1879 | shadows
#  0.1879 | vitality
#  0.1879 | neo
#  0.1879 | brutal
#  0.1876 | landscapes
#  0.1873 | holocaust
#  0.1872 | funniest
#  0.1871 | accessible
#  0.1869 | nation
#  0.1867 | told
#  0.1865 | yearning
#  0.1865 | fare
#  0.1863 | terrifying
#  0.1859 | centered
#  0.1859 | comfortable
#  0.1859 | real
#  0.1856 | realized
#  0.1855 | suspenseful
#  0.1854 | insightful
#  0.1852 | members
#  0.1850 | who
#  0.1850 | observant
#  0.1849 | soul
#  0.1846 | struggle
#  0.1846 | wo
#  0.1846 | inner
#  0.1841 | debut
#  0.1840 | able
#  0.1838 | barbershop
#  0.1834 | scratch
#  0.1832 | subtitles
#  0.1830 | radiant
#  0.1829 | nicholas
#  0.1829 | charm
#  0.1828 | decades
#  0.1828 | scale
#  0.1828 | felt
#  0.1828 | service
#  0.1827 | certainly
#  0.1824 | lively
#  0.1821 | lives
#  0.1819 | filling
#  0.1819 | buoyant
#  0.1817 | uniquely
#  0.1817 | together
#  0.1816 | genuinely
#  0.1816 | stylish
#  0.1816 | holm
#  0.1815 | 300
#  0.1815 | hugely
#  0.1814 | lewis
#  0.1814 | relaxed
#  0.1813 | presents
#  0.1811 | rohmer
#  0.1811 | australia
#  0.1808 | fragile
#  0.1806 | throughout
#  0.1805 | weeks
#  0.1802 | grant
#  0.1801 | james
#  0.1801 | balance
#  0.1797 | primarily
#  0.1791 | comedies
#  0.1790 | mix
#  0.1786 | freshness
#  0.1780 | locales
#  0.1778 | filmmaking
#  0.1776 | helps
#  0.1775 | stuff
#  0.1770 | offbeat
#  0.1767 | huge
#  0.1765 | sardonic
#  0.1761 | fan
#  0.1761 | complicated
#  0.1758 | dance
#  0.1755 | open
#  0.1752 | exquisite
#  0.1745 | pathology
#  0.1745 | hearted
#  0.1744 | loved
#  0.1742 | generous
#  0.1740 | sincerity
#  0.1735 | determination
#  0.1733 | intensely
#  0.1731 | immediate
#  0.1730 | ambitious
#  0.1730 | role
#  0.1726 | compared
#  0.1725 | distinguished
#  0.1716 | cleverness
#  0.1716 | presence
#  0.1715 | handled
#  0.1709 | sweetness
#  0.1704 | parent
#  0.1702 | stylistic
#  0.1701 | lady
#  0.1701 | narc
#  0.1698 | space
#  0.1694 | difference
#  0.1692 | nonetheless
#  0.1691 | carol
#  0.1689 | plenty
#  0.1688 | &
#  0.1686 | challenging
#  0.1686 | shows
#  0.1685 | dream
#  0.1679 | give
#  0.1674 | enthusiasm
#  0.1674 | carry
#  0.1673 | psychologically
#  0.1670 | pace
#  0.1670 | secret
#  0.1669 | loves
#  0.1667 | children
#  0.1665 | lived
#  0.1665 | unconventional
#  0.1665 | jones
#  0.1663 | daring
#  0.1660 | comic
#  0.1656 | meets
#  0.1652 | fine
#  0.1651 | unsettling
#  0.1649 | complex
#  0.1645 | wise
#  0.1641 | baby
#  0.1639 | aliens
#  0.1639 | convey
#  0.1635 | spirited
#  0.1635 | couple
#  0.1635 | enthusiastic
#  0.1632 | seat
#  0.1631 | doo
#  0.1630 | breath
#  0.1629 | process
#  0.1628 | fans
#  0.1627 | devastating
#  0.1622 | blue
#  0.1621 | marvel
#  0.1621 | thriller
#  0.1620 | protagonists
#  0.1616 | illustrates
#  0.1615 | rewards
#  0.1613 | tremendous
#  0.1607 | subculture
#  0.1603 | key
#  0.1601 | actors
#  0.1599 | endearing
#  0.1596 | renner
#  0.1595 | determined
#  0.1588 | hilarity
#  0.1587 | endure
#  0.1587 | keeps
#  0.1587 | norton
#  0.1581 | measure
#  0.1578 | anderson
#  0.1574 | shocks
#  0.1574 | finds
#  0.1573 | topic
#  0.1573 | labute
#  0.1571 | demands
#  0.1564 | laid
#  0.1561 | feeling
#  0.1553 | german
#  0.1551 | revelatory
#  0.1549 | breezy
#  0.1547 | weirdly
#  0.1545 | sweeping
#  0.1543 | style
#  0.1542 | jolie
#  0.1540 | reggio
#  0.1539 | sand
#  0.1538 | view
#  0.1538 | convincing
#  0.1537 | reel
#  0.1534 | differences
#  0.1533 | aficionados
#  0.1530 | blockbuster
#  0.1530 | dude
#  0.1529 | deadpan
#  0.1529 | island
#  0.1527 | eloquent
#  0.1525 | honor
#  0.1524 | exciting
#  0.1523 | callar
#  0.1523 | oscar
#  0.1522 | stand
#  0.1519 | entertained
#  0.1518 | giddy
#  0.1514 | return
#  0.1513 | versus
#  0.1512 | lyrical
#  0.1510 | disquieting
#  0.1508 | sensational
#  0.1508 | eventual
#  0.1508 | english
#  0.1507 | transformation
#  0.1506 | covers
#  0.1504 | small
#  0.1503 | artists
#  0.1503 | events
#  0.1502 | end
#  0.1499 | c
#  0.1499 | expect
#  0.1497 | regardless
#  0.1497 | literary
#  0.1495 | tragic
#  0.1490 | costume
#  0.1488 | girl
#  0.1488 | home
#  0.1482 | distance
#  0.1481 | web
#  0.1481 | vein
#  0.1480 | lanes
#  0.1477 | ensemble
#  0.1477 | east
#  0.1472 | spooky
#  0.1471 | outrageous
#  0.1469 | personal
#  0.1469 | topics
#  0.1468 | amusing
#  0.1468 | intimacy
#  0.1468 | artistic
#  0.1468 | appeal
#  0.1463 | clarity
#  0.1461 | fresh
#  0.1461 | locations
#  0.1460 | sumptuous
#  0.1457 | motivations
#  0.1454 | land
#  0.1454 | pretty
#  0.1451 | sarandon
#  0.1451 | finest
#  0.1448 | angst
#  0.1445 | proves
#  0.1445 | clever
#  0.1441 | dark
#  0.1440 | brothers
#  0.1440 | vietnam
#  0.1439 | spot
#  0.1439 | spectacularly
#  0.1435 | kong
#  0.1435 | executed
#  0.1433 | encounter
#  0.1433 | unflinching
#  0.1433 | desperation
#  0.1432 | certain
#  0.1432 | tasty
#  0.1431 | gifted
#  0.1427 | plus
#  0.1426 | accident
#  0.1426 | 21st
#  0.1425 | steers
#  0.1424 | though
#  0.1423 | improbable
#  0.1422 | verbal
#  0.1421 | added
#  0.1418 | longing
#  0.1417 | reaction
#  0.1414 | background
#  0.1412 | assayas
#  0.1408 | constantly
#  0.1408 | those
#  0.1404 | parable
#  0.1402 | movies
#  0.1402 | paranoia
#  0.1401 | rose
#  0.1398 | black
#  0.1397 | values
#  0.1397 | concerned
#  0.1396 | hong
#  0.1395 | italian
#  0.1395 | profound
#  0.1391 | darkly
#  0.1389 | continues
#  0.1385 | ego
#  0.1381 | remember
#  0.1379 | sexual
#  0.1373 | wickedly
#  0.1371 | prospect
#  0.1369 | damaged
#  0.1366 | eerie
#  0.1366 | legal
#  0.1366 | moral
#  0.1362 | awards
#  0.1362 | kids
#  0.1360 | pitch
#  0.1360 | she
#  0.1357 | mcgrath
#  0.1357 | pride
#  0.1357 | meaningful
#  0.1355 | his
#  0.1354 | japanese
#  0.1352 | fairly
#  0.1350 | casting
#  0.1347 | use
#  0.1346 | create
#  0.1339 | move
#  0.1339 | neat
#  0.1336 | thrillers
#  0.1336 | bright
#  0.1335 | am
#  0.1333 | strip
#  0.1332 | guts
#  0.1329 | mexican
#  0.1327 | energy
#  0.1327 | extremely
#  0.1325 | entertain
#  0.1323 | killed
#  0.1323 | maintains
#  0.1322 | anime
#  0.1320 | parents
#  0.1319 | will
#  0.1317 | jackson
#  0.1317 | moments
#  0.1315 | themed
#  0.1315 | written
#  0.1315 | hilariously
#  0.1313 | sad
#  0.1312 | sheer
#  0.1312 | shattering
#  0.1310 | pop
#  0.1310 | cuts
#  0.1306 | adaptation
#  0.1305 | mark
#  0.1305 | carried
#  0.1304 | potential
#  0.1302 | screen
#  0.1298 | unsentimental
#  0.1298 | punching
#  0.1297 | walter
#  0.1296 | full
#  0.1296 | protagonist
#  0.1293 | company
#  0.1293 | poverty
#  0.1292 | 80
#  0.1292 | eye
#  0.1292 | despair
#  0.1291 | fuzzy
#  0.1291 | beat
#  0.1291 | addition
#  0.1288 | new
#  0.1288 | hold
#  0.1287 | diverting
#  0.1286 | michel
#  0.1285 | square
#  0.1285 | slowly
#  0.1282 | payne
#  0.1282 | brother
#  0.1281 | rollicking
#  0.1280 | joy
#  0.1275 | avoids
#  0.1274 | truthful
#  0.1273 | 15
#  0.1273 | happily
#  0.1270 | feature
#  0.1268 | finally
#  0.1267 | deserved
#  0.1266 | teenage
#  0.1262 | classics
#  0.1262 | palpable
#  0.1261 | twists
#  0.1260 | christian
#  0.1260 | rouge
#  0.1259 | extent
#  0.1258 | working
#  0.1257 | front
#  0.1256 | grief
#  0.1254 | fellow
#  0.1252 | fest
#  0.1251 | list
#  0.1250 | news
#  0.1249 | ranks
#  0.1247 | catch
#  0.1245 | early
#  0.1244 | s
#  0.1243 | tense
#  0.1243 | if
#  0.1242 | story
#  0.1242 | atmosphere
#  0.1241 | austin
#  0.1237 | tells
#  0.1234 | revealed
#  0.1232 | demonstrate
#  0.1230 | buffs
#  0.1230 | flavor
#  0.1230 | laughed
#  0.1229 | families
#  0.1228 | hoping
#  0.1228 | marvelous
#  0.1228 | aging
#  0.1227 | undoubtedly
#  0.1227 | national
#  0.1227 | punk
#  0.1226 | oriented
#  0.1226 | unabashedly
#  0.1224 | decent
#  0.1223 | productions
#  0.1222 | nickleby
#  0.1222 | aspects
#  0.1221 | admirably
#  0.1220 | mendes
#  0.1220 | laughing
#  0.1220 | muccino
#  0.1216 | important
#  0.1214 | interpretation
#  0.1212 | mention
#  0.1212 | verve
#  0.1211 | genial
#  0.1210 | belly
#  0.1210 | directed
#  0.1208 | battle
#  0.1207 | a
#  0.1205 | slice
#  0.1202 | asian
#  0.1196 | proper
#  0.1196 | medium
#  0.1195 | identity
#  0.1193 | relevant
#  0.1192 | emerges
#  0.1191 | sometimes
#  0.1188 | crew
#  0.1188 | sacrifice
#  0.1186 | enough
#  0.1186 | penetrating
#  0.1184 | whimsy
#  0.1184 | backstage
#  0.1183 | weirdness
#  0.1183 | myth
#  0.1182 | conspiracy
#  0.1181 | games
#  0.1181 | fascination
#  0.1181 | landmark
#  0.1178 | danny
#  0.1178 | fat
#  0.1176 | enthralling
#  0.1176 | strangeness
#  0.1167 | songs
#  0.1167 | breakthrough
#  0.1166 | handsomely
#  0.1163 | done
#  0.1162 | planet
#  0.1160 | spots
#  0.1157 | godard
#  0.1153 | created
#  0.1151 | american
#  0.1151 | \*\*\*
#  0.1149 | intensity
#  0.1149 | taymor
#  0.1148 | languorous
#  0.1146 | media
#  0.1146 | entertainingly
#  0.1145 | of
#  0.1144 | stays
#  0.1142 | triumph
#  0.1140 | natural
#  0.1136 | can
#  0.1135 | four
#  0.1133 | dogtown
#  0.1129 | undisputed
#  0.1128 | push
#  0.1126 | diggs
#  0.1125 | de
#  0.1124 | emerge
#  0.1122 | admirable
#  0.1121 | trap
#  0.1120 | newcomer
#  0.1118 | sugar
#  0.1118 | committed
#  0.1117 | ocean
#  0.1116 | entirely
#  0.1116 | psychological
#  0.1115 | borders
#  0.1114 | era
#  0.1113 | individual
#  0.1113 | moody
#  0.1110 | cell
#  0.1109 | director
#  0.1109 | absolutely
#  0.1104 | bit
#  0.1104 | page
#  0.1103 | worry
#  0.1103 | recommended
#  0.1101 | workplace
#  0.1100 | root
#  0.1100 | diane
#  0.1100 | ode
#  0.1098 | hit
#  0.1097 | gave
#  0.1096 | metaphors
#  0.1095 | aware
#  0.1094 | cartoons
#  0.1092 | animals
#  0.1091 | ring
#  0.1090 | thousands
#  0.1086 | kaufman
#  0.1085 | event
#  0.1085 | valuable
#  0.1084 | trenchant
#  0.1082 | malkovich
#  0.1081 | emotions
#  0.1080 | foreign
#  0.1079 | craft
#  0.1076 | permeates
#  0.1075 | defies
#  0.1074 | mixture
#  0.1071 | elling
#  0.1071 | enticing
#  0.1071 | sequence
#  0.1070 | established
#  0.1070 | must
#  0.1070 | personalities
#  0.1068 | rarely
#  0.1065 | drew
#  0.1064 | shyamalan
#  0.1063 | boisterous
#  0.1059 | theme
#  0.1059 | inquisitive
#  0.1058 | legacy
#  0.1057 | capture
#  0.1056 | knowing
#  0.1056 | influence
#  0.1054 | droppingly
#  0.1053 | photography
#  0.1053 | frequent
#  0.1052 | naughty
#  0.1052 | sport
#  0.1049 | elegantly
#  0.1048 | jane
#  0.1047 | reasonably
#  0.1047 | succeeded
#  0.1047 | truth
#  0.1046 | class
#  0.1045 | acts
#  0.1045 | banter
#  0.1043 | bible
#  0.1043 | hall
#  0.1042 | score
#  0.1042 | dares
#  0.1041 | ease
#  0.1039 | according
#  0.1036 | memories
#  0.1035 | provided
#  0.1035 | moved
#  0.1033 | realize
#  0.1032 | frozen
#  0.1031 | reno
#  0.1030 | metaphor
#  0.1030 | matthew
#  0.1029 | city
#  0.1028 | thirteen
#  0.1027 | chouraqui
#  0.1027 | cup
#  0.1026 | noir
#  0.1026 | chemistry
#  0.1025 | count
#  0.1024 | notwithstanding
#  0.1024 | dana
#  0.1021 | keen
#  0.1020 | conflict
#  0.1019 | discover
#  0.1019 | trashy
#  0.1018 | powerpuff
#  0.1017 | 12
#  0.1016 | wonder
#  0.1016 | 95
#  0.1015 | thomas
#  0.1015 | specific
#  0.1014 | wow
#  0.1012 | ozpetek
#  0.1011 | pictures
#  0.1011 | sacrificing
#  0.1011 | wesley
#  0.1010 | promises
#  0.1009 | bio
#  0.1007 | supremely
#  0.1007 | bruce
#  0.1006 | men
#  0.1004 | transcend
#  0.1004 | contemplation
#  0.1003 | bank
#  0.1003 | yet
#  0.1003 | cultural
#  0.1002 | robinson
#  0.1002 | knack
#  0.0997 | jewish
#  0.0997 | madness
#  0.0996 | one
#  0.0993 | above
#  0.0992 | roger
#  0.0991 | irony
#  0.0990 | liberation
#  0.0989 | scripting
#  0.0989 | my
#  0.0988 | ash
#  0.0986 | blast
#  0.0985 | phones
#  0.0985 | powers
#  0.0983 | drawing
#  0.0980 | teacher
#  0.0978 | ever
#  0.0977 | sinister
#  0.0975 | recording
#  0.0975 | emotional
#  0.0975 | ai
#  0.0974 | chilly
#  0.0974 | friendship
#  0.0974 | mother
#  0.0973 | day
#  0.0973 | received
#  0.0971 | mira
#  0.0968 | actions
#  0.0966 | brosnan
#  0.0966 | number
#  0.0966 | maintain
#  0.0965 | mike
#  0.0964 | deliberately
#  0.0964 | achievement
#  0.0964 | extended
#  0.0962 | fair
#  0.0962 | cloying
#  0.0961 | wendigo
#  0.0960 | easily
#  0.0958 | mann
#  0.0957 | fills
#  0.0956 | wednesday
#  0.0955 | innovative
#  0.0952 | feat
#  0.0951 | pulling
#  0.0951 | pathos
#  0.0950 | environmental
#  0.0950 | junior
#  0.0949 | engaged
#  0.0948 | jumbo
#  0.0948 | complexities
#  0.0947 | creature
#  0.0947 | \/
#  0.0943 | adolescent
#  0.0941 | base
#  0.0940 | documentaries
#  0.0939 | directly
#  0.0938 | cinematic
#  0.0936 | stage
#  0.0935 | meyjes
#  0.0934 | noyce
#  0.0934 | competition
#  0.0933 | issue
#  0.0931 | shenanigans
#  0.0930 | darkness
#  0.0929 | diaries
#  0.0928 | gibson
#  0.0927 | section
#  0.0926 | express
#  0.0926 | juicy
#  0.0925 | dose
#  0.0923 | birot
#  0.0921 | singer
#  0.0920 | recognize
#  0.0919 | holiday
#  0.0918 | assembled
#  0.0918 | paced
#  0.0918 | tea
#  0.0916 | york
#  0.0915 | realism
#  0.0914 | b
#  0.0913 | exists
#  0.0911 | sits
#  0.0911 | flourishes
#  0.0909 | assassin
#  0.0909 | midnight
#  0.0907 | bullock
#  0.0907 | icon
#  0.0906 | season
#  0.0904 | counter
#  0.0904 | dumas
#  0.0902 | first
#  0.0902 | impressed
#  0.0901 | started
#  0.0901 | aimed
#  0.0899 | tambor
#  0.0895 | soaked
#  0.0895 | epic
#  0.0895 | increasingly
#  0.0893 | auteuil
#  0.0892 | casts
#  0.0892 | please
#  0.0891 | celebrity
#  0.0890 | astounding
#  0.0890 | savage
#  0.0890 | hugh
#  0.0889 | rendered
#  0.0889 | lip
#  0.0888 | road
#  0.0884 | leads
#  0.0883 | standard
#  0.0882 | although
#  0.0881 | dramas
#  0.0880 | bodily
#  0.0879 | cute
#  0.0879 | effectively
#  0.0877 | coming
#  0.0877 | charles
#  0.0875 | fight
#  0.0872 | top
#  0.0872 | tell
#  0.0871 | catching
#  0.0869 | proceedings
#  0.0867 | political
#  0.0867 | fanciful
#  0.0867 | box
#  0.0866 | familiar
#  0.0864 | ya
#  0.0864 | took
#  0.0863 | emphasizes
#  0.0862 | sudden
#  0.0862 | wild
#  0.0861 | theatre
#  0.0861 | criminal
#  0.0861 | scherfig
#  0.0860 | roman
#  0.0859 | duration
#  0.0858 | derived
#  0.0858 | loss
#  0.0858 | dutiful
#  0.0857 | ryan
#  0.0855 | participants
#  0.0855 | producer
#  0.0851 | recipe
#  0.0851 | scorsese
#  0.0850 | douglas
#  0.0849 | villain
#  0.0848 | admittedly
#  0.0848 | double
#  0.0847 | astonishingly
#  0.0844 | lingering
#  0.0843 | insurance
#  0.0840 | boobs
#  0.0839 | step
#  0.0839 | p
#  0.0838 | kline
#  0.0838 | dangerous
#  0.0837 | articulate
#  0.0836 | thankfully
#  0.0836 | what
#  0.0835 | intricate
#  0.0831 | garde
#  0.0831 | poetic
#  0.0830 | super
#  0.0829 | days
#  0.0829 | auteur
#  0.0826 | mental
#  0.0826 | safe
#  0.0825 | inject
#  0.0825 | once
#  0.0824 | ravishing
#  0.0824 | donovan
#  0.0824 | general
#  0.0823 | inspiring
#  0.0822 | observations
#  0.0822 | afternoon
#  0.0819 | consequences
#  0.0819 | capacity
#  0.0818 | ear
#  0.0817 | waiting
#  0.0817 | expands
#  0.0816 | endlessly
#  0.0816 | appropriate
#  0.0815 | avant
#  0.0813 | angle
#  0.0813 | success
#  0.0812 | broomfield
#  0.0810 | irwin
#  0.0810 | sports
#  0.0808 | lucas
#  0.0802 | saying
#  0.0799 | jagger
#  0.0799 | organic
#  0.0798 | venture
#  0.0798 | merits
#  0.0798 | peak
#  0.0796 | non
#  0.0796 | phenomenal
#  0.0793 | pushed
#  0.0791 | cultures
#  0.0791 | kissinger
#  0.0789 | steeped
#  0.0789 | friendly
#  0.0788 | celebration
#  0.0787 | mysterious
#  0.0787 | award
#  0.0786 | conviction
#  0.0785 | ignored
#  0.0784 | instincts
#  0.0784 | deliver
#  0.0783 | hitting
#  0.0780 | molly
#  0.0778 | attitude
#  0.0777 | rely
#  0.0774 | deserves
#  0.0774 | distinct
#  0.0772 | innocence
#  0.0771 | practice
#  0.0770 | magnificent
#  0.0770 | problematic
#  0.0766 | objective
#  0.0766 | solaris
#  0.0764 | highest
#  0.0762 | emotion
#  0.0761 | rolling
#  0.0761 | panache
#  0.0759 | heady
#  0.0758 | juliette
#  0.0758 | awe
#  0.0758 | gloss
#  0.0756 | grim
#  0.0754 | surface
#  0.0753 | dare
#  0.0753 | example
#  0.0752 | amy
#  0.0752 | jumps
#  0.0752 | reign
#  0.0751 | illness
#  0.0750 | park
#  0.0750 | unable
#  0.0749 | suck
#  0.0749 | alluring
#  0.0745 | seek
#  0.0741 | maid
#  0.0740 | damon
#  0.0740 | fascinate
#  0.0739 | rewarded
#  0.0739 | todd
#  0.0736 | problems
#  0.0734 | favorite
#  0.0734 | willis
#  0.0732 | hybrid
#  0.0731 | hedonistic
#  0.0728 | sees
#  0.0728 | abuse
#  0.0728 | frightening
#  0.0728 | within
#  0.0727 | relies
#  0.0726 | boldly
#  0.0724 | blame
#  0.0720 | jonathan
#  0.0720 | host
#  0.0716 | obsessive
#  0.0715 | infidelity
#  0.0715 | develops
#  0.0713 | gangs
#  0.0712 | people
#  0.0711 | spiritual
#  0.0711 | deprecating
#  0.0710 | aged
#  0.0709 | brightly
#  0.0709 | insecure
#  0.0709 | bound
#  0.0708 | decade
#  0.0707 | predict
#  0.0707 | outcome
#  0.0706 | improvisation
#  0.0706 | revolution
#  0.0705 | welcome
#  0.0705 | coppola
#  0.0705 | departure
#  0.0704 | arguments
#  0.0704 | women
#  0.0702 | speculation
#  0.0701 | boasting
#  0.0700 | spoof
#  0.0700 | significantly
#  0.0699 | letting
#  0.0699 | church
#  0.0697 | stone
#  0.0696 | struggling
#  0.0696 | equally
#  0.0693 | divine
#  0.0692 | leave
#  0.0692 | pays
#  0.0690 | known
#  0.0687 | your
#  0.0687 | sayles
#  0.0686 | nutty
#  0.0686 | compassion
#  0.0685 | trick
#  0.0684 | subject
#  0.0683 | each
#  0.0682 | date
#  0.0682 | shifting
#  0.0681 | audiences
#  0.0681 | developments
#  0.0680 | notorious
#  0.0680 | exterior
#  0.0680 | olivier
#  0.0679 | inhabit
#  0.0678 | blockbusters
#  0.0676 | nonstop
#  0.0675 | across
#  0.0672 | features
#  0.0669 | suggest
#  0.0668 | matinee
#  0.0667 | e
#  0.0667 | fights
#  0.0667 | because
#  0.0666 | sets
#  0.0666 | flop
#  0.0664 | morality
#  0.0663 | terror
#  0.0662 | er
#  0.0661 | sword
#  0.0661 | tribute
#  0.0661 | field
#  0.0660 | adage
#  0.0659 | fantasy
#  0.0658 | chase
#  0.0656 | esque
#  0.0656 | crowd
#  0.0656 | last
#  0.0656 | henry
#  0.0655 | creepy
#  0.0652 | piccoli
#  0.0652 | wit
#  0.0652 | 19
#  0.0648 | spy
#  0.0646 | revenge
#  0.0644 | parade
#  0.0642 | historically
#  0.0641 | arrest
#  0.0641 | screens
#  0.0640 | retains
#  0.0639 | late
#  0.0639 | edward
#  0.0639 | achingly
#  0.0638 | crammed
#  0.0637 | make
#  0.0636 | raymond
#  0.0635 | portray
#  0.0635 | soderbergh
#  0.0634 | saving
#  0.0634 | claustrophobic
#  0.0634 | swimming
#  0.0633 | atlantic
#  0.0633 | conversations
#  0.0632 | dirty
#  0.0632 | treatment
#  0.0629 | common
#  0.0629 | current
#  0.0628 | cop
#  0.0628 | directs
#  0.0627 | curious
#  0.0625 | touches
#  0.0625 | quasi
#  0.0624 | deception
#  0.0624 | l
#  0.0624 | david
#  0.0623 | produced
#  0.0620 | justify
#  0.0619 | professionals
#  0.0619 | gift
#  0.0617 | commercialism
#  0.0614 | community
#  0.0612 | paul
#  0.0611 | jazzy
#  0.0610 | lifetime
#  0.0609 | air
#  0.0606 | droll
#  0.0603 | shocking
#  0.0603 | issues
#  0.0602 | scare
#  0.0602 | held
#  0.0600 | escapes
#  0.0600 | insider
#  0.0599 | biting
#  0.0596 | swim
#  0.0596 | somber
#  0.0594 | frame
#  0.0592 | schnitzler
#  0.0591 | mainstream
#  0.0590 | allen
#  0.0590 | pitched
#  0.0589 | gangster
#  0.0588 | nuance
#  0.0588 | everywhere
#  0.0586 | bielinsky
#  0.0584 | specimen
#  0.0584 | walking
#  0.0582 | boasts
#  0.0579 | round
#  0.0579 | tensions
#  0.0577 | cost
#  0.0577 | janice
#  0.0575 | reluctant
#  0.0575 | terry
#  0.0574 | theaters
#  0.0574 | exceedingly
#  0.0573 | motion
#  0.0573 | meaning
#  0.0573 | john
#  0.0571 | murder
#  0.0571 | chris
#  0.0571 | pungent
#  0.0570 | beach
#  0.0564 | improvement
#  0.0564 | devices
#  0.0563 | pain
#  0.0563 | master
#  0.0562 | that
#  0.0560 | folk
#  0.0560 | evokes
#  0.0558 | drawn
#  0.0558 | reflection
#  0.0557 | cheese
#  0.0557 | african
#  0.0557 | famous
#  0.0556 | kennedy
#  0.0556 | childhood
#  0.0556 | flamboyant
#  0.0555 | biz
#  0.0553 | offering
#  0.0552 | sons
#  0.0551 | nails
#  0.0550 | wave
#  0.0550 | character
#  0.0549 | smoking
#  0.0547 | many
#  0.0547 | freeman
#  0.0545 | mouth
#  0.0545 | tortured
#  0.0543 | achieve
#  0.0542 | unbelievable
#  0.0542 | vision
#  0.0541 | without
#  0.0541 | marginal
#  0.0540 | brit
#  0.0540 | monsoon
#  0.0540 | disney
#  0.0539 | shaggy
#  0.0539 | going
#  0.0537 | baffled
#  0.0537 | path
#  0.0536 | pro
#  0.0535 | turns
#  0.0534 | hammy
#  0.0534 | burns
#  0.0534 | trees
#  0.0534 | destructive
#  0.0530 | stitch
#  0.0530 | satisfactory
#  0.0529 | from
#  0.0529 | 60s
#  0.0529 | uncertain
#  0.0529 | inspires
#  0.0528 | projects
#  0.0527 | schrader
#  0.0527 | enjoyably
#  0.0525 | co
#  0.0524 | scotland
#  0.0524 | outsiders
#  0.0520 | misanthropic
#  0.0520 | mind
#  0.0518 | attractive
#  0.0517 | race
#  0.0515 | career
#  0.0514 | becoming
#  0.0513 | yes
#  0.0512 | gary
#  0.0511 | seven
#  0.0511 | insomnia
#  0.0509 | dying
#  0.0507 | chicago
#  0.0506 | unassuming
#  0.0506 | symbolic
#  0.0505 | villains
#  0.0505 | weighty
#  0.0503 | twisting
#  0.0501 | kim
#  0.0500 | pleasantly
#  0.0500 | extravaganza
#  0.0499 | bettany
#  0.0499 | intrigue
#  0.0499 | chick
#  0.0497 | provide
#  0.0495 | humanly
#  0.0493 | regret
#  0.0491 | grow
#  0.0491 | task
#  0.0490 | redemption
#  0.0490 | admission
#  0.0487 | austerity
#  0.0486 | package
#  0.0482 | blaxploitation
#  0.0482 | vincent
#  0.0482 | unlikely
#  0.0482 | lush
#  0.0482 | h
#  0.0482 | youthful
#  0.0481 | bump
#  0.0481 | bruckheimer
#  0.0480 | expectation
#  0.0478 | fate
#  0.0477 | collaboration
#  0.0476 | tales
#  0.0476 | public
#  0.0476 | otherwise
#  0.0475 | hits
#  0.0474 | filmed
#  0.0472 | 1
#  0.0472 | release
#  0.0472 | has
#  0.0472 | fourth
#  0.0471 | massive
#  0.0471 | theories
#  0.0469 | stunts
#  0.0468 | evans
#  0.0468 | adults
#  0.0468 | enjoyment
#  0.0468 | message
#  0.0464 | mushy
#  0.0463 | brooding
#  0.0463 | shrek
#  0.0461 | times
#  0.0459 | profoundly
#  0.0457 | killer
#  0.0456 | state
#  0.0456 | gifts
#  0.0456 | punch
#  0.0456 | jerry
#  0.0455 | arrive
#  0.0455 | simultaneously
#  0.0454 | equal
#  0.0454 | apted
#  0.0453 | amidst
#  0.0452 | based
#  0.0452 | won
#  0.0452 | got
#  0.0451 | wake
#  0.0451 | crossover
#  0.0448 | calm
#  0.0448 | makeup
#  0.0446 | musicians
#  0.0446 | condensed
#  0.0444 | caper
#  0.0443 | edgy
#  0.0443 | furiously
#  0.0442 | titles
#  0.0441 | innocent
#  0.0440 | deceptions
#  0.0439 | spin
#  0.0438 | awfully
#  0.0437 | q
#  0.0437 | throws
#  0.0437 | ponder
#  0.0436 | overall
#  0.0436 | wisdom
#  0.0434 | antwone
#  0.0434 | big
#  0.0434 | killing
#  0.0433 | hyper
#  0.0433 | parts
#  0.0433 | kiss
#  0.0431 | precious
#  0.0430 | bone
#  0.0430 | antonia
#  0.0430 | tackles
#  0.0429 | stories
#  0.0428 | signals
#  0.0428 | british
#  0.0428 | eat
#  0.0427 | drug
#  0.0427 | alien
#  0.0427 | summertime
#  0.0427 | asks
#  0.0425 | nomination
#  0.0424 | artistry
#  0.0423 | these
#  0.0423 | domestic
#  0.0422 | awareness
#  0.0422 | liked
#  0.0422 | patience
#  0.0421 | tackling
#  0.0421 | definition
#  0.0421 | soars
#  0.0420 | fence
#  0.0420 | schepisi
#  0.0417 | em
#  0.0416 | humor
#  0.0416 | western
#  0.0416 | associated
#  0.0415 | complaint
#  0.0415 | hawn
#  0.0414 | expected
#  0.0414 | upbeat
#  0.0413 | structured
#  0.0413 | reaches
#  0.0411 | steven
#  0.0411 | martin
#  0.0410 | bursts
#  0.0408 | appreciated
#  0.0408 | alternative
#  0.0407 | dignity
#  0.0407 | learning
#  0.0406 | star
#  0.0405 | powerfully
#  0.0405 | bollywood
#  0.0404 | passes
#  0.0403 | dismissed
#  0.0402 | exploring
#  0.0400 | cyber
#  0.0400 | anybody
#  0.0399 | forgive
#  0.0399 | proof
#  0.0398 | fabric
#  0.0398 | don
#  0.0397 | silence
#  0.0396 | circumstances
#  0.0396 | usually
#  0.0395 | diary
#  0.0394 | downtown
#  0.0392 | chamber
#  0.0392 | chateau
#  0.0387 | actor
#  0.0383 | radar
#  0.0382 | towards
#  0.0381 | meticulously
#  0.0380 | lurid
#  0.0380 | replete
#  0.0378 | crudup
#  0.0375 | properly
#  0.0375 | ray
#  0.0374 | survivors
#  0.0374 | scrooge
#  0.0373 | edited
#  0.0373 | combat
#  0.0372 | inside
#  0.0371 | raises
#  0.0371 | tadpole
#  0.0369 | struck
#  0.0367 | religious
#  0.0366 | exceptionally
#  0.0366 | portrays
#  0.0366 | minority
#  0.0364 | subtext
#  0.0364 | among
#  0.0364 | tool
#  0.0363 | horrors
#  0.0363 | spins
#  0.0363 | fearless
#  0.0362 | nettelbeck
#  0.0362 | unusually
#  0.0361 | being
#  0.0358 | harmless
#  0.0358 | twist
#  0.0356 | disappointed
#  0.0356 | poetry
#  0.0355 | chops
#  0.0355 | private
#  0.0354 | zone
#  0.0354 | lion
#  0.0354 | hey
#  0.0354 | heated
#  0.0353 | arnold
#  0.0353 | paradiso
#  0.0352 | intermittently
#  0.0352 | scares
#  0.0352 | suffocating
#  0.0351 | creativity
#  0.0349 | narrator
#  0.0349 | deal
#  0.0348 | mothman
#  0.0348 | due
#  0.0346 | details
#  0.0345 | affable
#  0.0344 | interview
#  0.0344 | least
#  0.0343 | directorial
#  0.0343 | sounds
#  0.0342 | barrels
#  0.0342 | dong
#  0.0341 | foibles
#  0.0340 | wollter
#  0.0340 | mostly
#  0.0339 | tasteful
#  0.0339 | politics
#  0.0336 | creating
#  0.0334 | aggressive
#  0.0333 | stands
#  0.0332 | satin
#  0.0330 | wilde
#  0.0329 | understanding
#  0.0329 | strands
#  0.0328 | comfort
#  0.0326 | zealand
#  0.0325 | teachers
#  0.0324 | comprehension
#  0.0324 | said
#  0.0324 | manner
#  0.0323 | bits
#  0.0323 | rattling
#  0.0323 | evening
#  0.0323 | word
#  0.0320 | girls
#  0.0319 | sentimental
#  0.0319 | affirming
#  0.0318 | loving
#  0.0318 | bullets
#  0.0317 | surf
#  0.0316 | rock
#  0.0316 | writer
#  0.0315 | remind
#  0.0314 | headed
#  0.0312 | believer
#  0.0312 | dreams
#  0.0312 | fancy
#  0.0311 | reserved
#  0.0310 | denied
#  0.0310 | messy
#  0.0309 | outing
#  0.0309 | wars
#  0.0309 | elaborate
#  0.0308 | stops
#  0.0308 | artful
#  0.0307 | brisk
#  0.0307 | research
#  0.0307 | show
#  0.0306 | high
#  0.0306 | kid
#  0.0305 | torn
#  0.0304 | genius
#  0.0303 | stronger
#  0.0301 | sustained
#  0.0299 | vignettes
#  0.0297 | cuteness
#  0.0296 | pair
#  0.0296 | ultimate
#  0.0296 | finish
#  0.0293 | digs
#  0.0292 | king
#  0.0289 | picture
#  0.0288 | comedic
#  0.0286 | sea
#  0.0285 | sight
#  0.0282 | japan
#  0.0282 | satirical
#  0.0278 | nijinsky
#  0.0277 | tones
#  0.0276 | watch
#  0.0276 | palestinian
#  0.0275 | stomach
#  0.0275 | two
#  0.0274 | survival
#  0.0273 | rap
#  0.0273 | lavish
#  0.0272 | elevate
#  0.0272 | eccentric
#  0.0271 | ichi
#  0.0269 | warfare
#  0.0268 | siegel
#  0.0267 | youth
#  0.0267 | hair
#  0.0266 | inclination
#  0.0266 | strangers
#  0.0265 | gong
#  0.0265 | deepest
#  0.0264 | behind
#  0.0263 | image
#  0.0260 | incisive
#  0.0259 | astute
#  0.0259 | fly
#  0.0257 | romance
#  0.0257 | center
#  0.0257 | includes
#  0.0256 | language
#  0.0256 | pulp
#  0.0255 | meal
#  0.0254 | adding
#  0.0252 | cut
#  0.0252 | let
#  0.0251 | mattei
#  0.0251 | maintaining
#  0.0251 | between
#  0.0251 | believe
#  0.0250 | at
#  0.0249 | flesh
#  0.0249 | way
#  0.0247 | pants
#  0.0247 | eerily
#  0.0247 | oh
#  0.0246 | regarding
#  0.0245 | roots
#  0.0245 | required
#  0.0244 | now
#  0.0244 | noble
#  0.0244 | makers
#  0.0244 | profane
#  0.0244 | convince
#  0.0243 | iii
#  0.0241 | rhythm
#  0.0240 | sorvino
#  0.0239 | appear
#  0.0238 | earnestness
#  0.0238 | voices
#  0.0237 | words
#  0.0237 | today
#  0.0236 | indie
#  0.0236 | retro
#  0.0235 | about
#  0.0235 | meat
#  0.0234 | revelations
#  0.0233 | reduced
#  0.0232 | heroine
#  0.0232 | fisher
#  0.0231 | cheer
#  0.0230 | wanting
#  0.0230 | macabre
#  0.0230 | slam
#  0.0230 | afraid
#  0.0230 | blown
#  0.0229 | heal
#  0.0228 | travel
#  0.0227 | farts
#  0.0224 | psychopathic
#  0.0224 | diaz
#  0.0223 | folks
#  0.0222 | game
#  0.0221 | earnest
#  0.0221 | everyone
#  0.0220 | capable
#  0.0219 | but
#  0.0219 | besson
#  0.0218 | original
#  0.0218 | overcomes
#  0.0218 | payami
#  0.0217 | par
#  0.0210 | shot
#  0.0209 | order
#  0.0207 | williams
#  0.0202 | darker
#  0.0201 | caught
#  0.0199 | scooby
#  0.0199 | naturally
#  0.0197 | collision
#  0.0197 | minded
#  0.0196 | talking
#  0.0189 | lines
#  0.0189 | circus
#  0.0187 | performed
#  0.0187 | herself
#  0.0186 | narrative
#  0.0186 | sense
#  0.0183 | audacious
#  0.0182 | speak
#  0.0180 | animation
#  0.0180 | technical
#  0.0179 | manners
#  0.0178 | ralph
#  0.0177 | desire
#  0.0177 | spend
#  0.0176 | takes
#  0.0175 | clear
#  0.0173 | justice
#  0.0173 | delivery
#  0.0172 | shadowy
#  0.0172 | destruction
#  0.0171 | bizarre
#  0.0171 | staggeringly
#  0.0169 | in
#  0.0169 | dimension
#  0.0168 | frida
#  0.0168 | instance
#  0.0167 | burger
#  0.0165 | seeming
#  0.0165 | comedy
#  0.0164 | come
#  0.0162 | album
#  0.0159 | election
#  0.0158 | cletis
#  0.0158 | brought
#  0.0158 | daughter
#  0.0157 | costumes
#  0.0154 | driver
#  0.0153 | impressions
#  0.0153 | displays
#  0.0152 | apart
#  0.0151 | faster
#  0.0151 | harry
#  0.0150 | leaving
#  0.0150 | featuring
#  0.0149 | roberto
#  0.0148 | 22
#  0.0148 | clash
#  0.0147 | easy
#  0.0147 | trust
#  0.0147 | riot
#  0.0143 | rise
#  0.0142 | fully
#  0.0142 | kick
#  0.0141 | christmas
#  0.0140 | fathers
#  0.0139 | business
#  0.0138 | old
#  0.0138 | affleck
#  0.0138 | embarrassed
#  0.0137 | wrought
#  0.0136 | panoramic
#  0.0132 | hear
#  0.0131 | intelligence
#  0.0130 | lan
#  0.0129 | willingness
#  0.0129 | allow
#  0.0127 | escapism
#  0.0127 | nicks
#  0.0124 | freaky
#  0.0123 | noise
#  0.0117 | frequently
#  0.0116 | buñuel
#  0.0116 | lark
#  0.0115 | remembering
#  0.0114 | indictment
#  0.0113 | spider
#  0.0111 | minimalist
#  0.0110 | survive
#  0.0110 | destination
#  0.0109 | <pad>
#  0.0108 | dean
#  0.0103 | spectacle
#  0.0101 | occasionally
#  0.0100 | boy
#  0.0096 | aspect
#  0.0095 | australian
#  0.0095 | member
#  0.0094 | eventually
#  0.0094 | existence
#  0.0090 | visual
#  0.0089 | anger
#  0.0088 | judd
#  0.0087 | memory
#  0.0086 | poignancy
#  0.0086 | happen
#  0.0085 | absolute
#  0.0082 | sleeve
#  0.0082 | momentum
#  0.0081 | wildly
#  0.0080 | critics
#  0.0078 | downbeat
#  0.0078 | 2
#  0.0078 | critical
#  0.0076 | weep
#  0.0075 | check
#  0.0074 | shining
#  0.0073 | consciousness
#  0.0072 | wall
#  0.0072 | pokemon
#  0.0070 | crackle
#  0.0068 | period
#  0.0067 | disregard
#  0.0066 | know
#  0.0065 | boys
#  0.0065 | pantheon
#  0.0064 | talent
#  0.0063 | notion
#  0.0062 | brash
#  0.0061 | bartleby
#  0.0061 | aloof
#  0.0061 | sisterhood
#  0.0060 | mile
#  0.0059 | lilo
#  0.0059 | filled
#  0.0058 | sting
#  0.0058 | jack
#  0.0057 | baran
#  0.0056 | cinematography
#  0.0056 | accurately
#  0.0055 | daytime
#  0.0054 | runs
#  0.0053 | bombastic
#  0.0053 | scratching
#  0.0052 | area
#  0.0051 | pushes
#  0.0050 | ourselves
#  0.0050 | goofy
#  0.0050 | listen
#  0.0049 | female
#  0.0048 | bang
#  0.0048 | earth
#  0.0047 | biopic
#  0.0047 | château
#  0.0046 | martial
#  0.0045 | actual
#  0.0044 | respectable
#  0.0043 | 101
#  0.0042 | cohesive
#  0.0039 | glass
#  0.0038 | fable
#  0.0035 | presentation
#  0.0034 | doubt
#  0.0034 | string
#  0.0033 | compromise
#  0.0032 | construct
#  0.0029 | sort
#  0.0027 | ideas
#  0.0025 | ben
#  0.0025 | somebody
#  0.0022 | superior
#  0.0020 | sex
#  0.0019 | passion
#  0.0019 | americans
#  0.0017 | persona
#  0.0015 | dysfunctional
#  0.0014 | the
#  0.0013 | plight
#  0.0013 | scenario
#  0.0012 | kevin
#  0.0010 | raunch
#  0.0010 | squeeze
#  0.0010 | conjures
#  0.0009 | enter
#  0.0009 | prove
#  0.0008 | flicks
#  0.0008 | anne
#  0.0008 | turn
#  0.0005 | wallace
#  0.0004 | telling
#  0.0002 | philosophical
#  0.0001 | storyline
#  0.0000 | charge
# -0.0001 | somehow
# -0.0001 | zombie
# -0.0002 | luster
# -0.0003 | rob
# -0.0005 | effects
# -0.0006 | talented
# -0.0009 | second
# -0.0010 | alive
# -0.0010 | crisis
# -0.0011 | artifice
# -0.0011 | subtlety
# -0.0012 | guilty
# -0.0018 | avoid
# -0.0019 | wish
# -0.0019 | ice
# -0.0020 | station
# -0.0020 | computer
# -0.0020 | song
# -0.0021 | cautionary
# -0.0023 | remains
# -0.0025 | twice
# -0.0025 | serves
# -0.0028 | abstract
# -0.0034 | bard
# -0.0034 | determine
# -0.0035 | conveying
# -0.0036 | finale
# -0.0036 | ordinary
# -0.0037 | shakespeare
# -0.0039 | niche
# -0.0041 | scenery
# -0.0042 | pull
# -0.0044 | outside
# -0.0044 | excitement
# -0.0045 | nevertheless
# -0.0047 | solutions
# -0.0048 | nature
# -0.0048 | quality
# -0.0057 | gondry
# -0.0058 | chills
# -0.2781 | witch
# -0.2789 | desperately
# -0.2791 | manufactured
# -0.2797 | retread
# -0.2798 | carvey
# -0.2804 | not
# -0.2806 | remake
# -0.2807 | excesses
# -0.2809 | sentiment
# -0.2811 | really
# -0.2813 | banal
# -0.2814 | name
# -0.2814 | clumsy
# -0.2818 | european
# -0.2819 | exploitation
# -0.2824 | busy
# -0.2832 | built
# -0.2834 | merit
# -0.2835 | fatal
# -0.2835 | more
# -0.2839 | flaccid
# -0.2847 | dogs
# -0.2847 | sour
# -0.2847 | sheridan
# -0.2849 | might
# -0.2860 | com
# -0.2860 | cynical
# -0.2863 | vulgar
# -0.2875 | apparently
# -0.2875 | house
# -0.2878 | slip
# -0.2880 | hollow
# -0.2882 | routine
# -0.2883 | superficial
# -0.2892 | unimaginative
# -0.2894 | i
# -0.2899 | obnoxious
# -0.2904 | violence
# -0.2907 | bother
# -0.2922 | shapeless
# -0.2927 | rent
# -0.2930 | frontal
# -0.2940 | plain
# -0.2942 | television
# -0.2943 | unintentionally
# -0.2944 | deuces
# -0.2948 | insulting
# -0.2954 | wants
# -0.2956 | grating
# -0.2959 | length
# -0.2960 | sinks
# -0.2965 | pass
# -0.2965 | silly
# -0.2968 | lackluster
# -0.2975 | terribly
# -0.2981 | sappy
# -0.2987 | video
# -0.2993 | material
# -0.2994 | uneven
# -0.2996 | deadly
# -0.3003 | drag
# -0.3014 | gags
# -0.3014 | stilted
# -0.3022 | lacks
# -0.3027 | disappointment
# -0.3030 | sleep
# -0.3030 | preachy
# -0.3032 | cold
# -0.3033 | muddled
# -0.3038 | supposed
# -0.3039 | thing
# -0.3041 | toward
# -0.3050 | attempts
# -0.3051 | any
# -0.3051 | artificial
# -0.3051 | conceived
# -0.3052 | over
# -0.3057 | editing
# -0.3060 | sandler
# -0.3061 | except
# -0.3062 | guess
# -0.3063 | gone
# -0.3066 | comes
# -0.3069 | needs
# -0.3076 | awkward
# -0.3080 | witless
# -0.3083 | imagine
# -0.3112 | holes
# -0.3129 | sluggish
# -0.3132 | dreary
# -0.3134 | preposterous
# -0.3144 | every
# -0.3151 | humorless
# -0.3152 | soulless
# -0.3153 | uninspired
# -0.3161 | inconsequential
# -0.3162 | half
# -0.3167 | shoot
# -0.3180 | cliches
# -0.3196 | unconvincing
# -0.3198 | whole
# -0.3201 | pity
# -0.3207 | someone
# -0.3209 | ghost
# -0.3209 | so
# -0.3218 | scene
# -0.3236 | vapid
# -0.3238 | collapses
# -0.3244 | reason
# -0.3245 | soap
# -0.3246 | opportunity
# -0.3250 | horrible
# -0.3253 | appears
# -0.3257 | formulaic
# -0.3266 | nor
# -0.3271 | car
# -0.3275 | unlikable
# -0.3275 | cliché
# -0.3278 | unless
# -0.3280 | premise
# -0.3287 | out
# -0.3293 | where
# -0.3308 | trying
# -0.3314 | sadly
# -0.3330 | weak
# -0.3342 | unpleasant
# -0.3362 | chan
# -0.3363 | disaster
# -0.3367 | much
# -0.3367 | mistake
# -0.3375 | junk
# -0.3376 | long
# -0.3382 | annoying
# -0.3395 | unfocused
# -0.3398 | waste
# -0.3401 | ultimately
# -0.3410 | ends
# -0.3414 | barely
# -0.3421 | amateurish
# -0.3431 | episode
# -0.3432 | quickly
# -0.3435 | unnecessary
# -0.3438 | money
# -0.3440 | incoherent
# -0.3444 | repetitive
# -0.3476 | worse
# -0.3486 | lawrence
# -0.3488 | bears
# -0.3491 | left
# -0.3501 | queen
# -0.3506 | clichés
# -0.3517 | choppy
# -0.3521 | why
# -0.3532 | logic
# -0.3539 | manipulative
# -0.3543 | lifeless
# -0.3547 | weight
# -0.3556 | failure
# -0.3560 | falls
# -0.3563 | obvious
# -0.3591 | plotting
# -0.3593 | lazy
# -0.3600 | pay
# -0.3607 | would
# -0.3617 | action
# -0.3620 | seagal
# -0.3642 | empty
# -0.3644 | was
# -0.3672 | me
# -0.3683 | title
# -0.3686 | wasted
# -0.3692 | do
# -0.3698 | nowhere
# -0.3700 | inept
# -0.3704 | loses
# -0.3705 | seem
# -0.3709 | bore
# -0.3730 | virtually
# -0.3733 | attempt
# -0.3755 | wannabe
# -0.3760 | another
# -0.3773 | running
# -0.3788 | awful
# -0.3792 | wrong
# -0.3795 | missing
# -0.3798 | been
# -0.3863 | badly
# -0.3864 | listless
# -0.3879 | thinks
# -0.3883 | lousy
# -0.3883 | down
# -0.3910 | irritating
# -0.3925 | plays
# -0.3925 | product
# -0.3962 | jokes
# -0.3962 | disguise
# -0.3968 | dialogue
# -0.3973 | poor
# -0.3977 | lame
# -0.3982 | loud
# -0.3989 | becomes
# -0.3998 | devoid
# -0.4008 | joke
# -0.4013 | mediocre
# -0.4019 | offensive
# -0.4054 | movie
# -0.4062 | stale
# -0.4063 | thin
# -0.4069 | script
# -0.4140 | tries
# -0.4143 | generic
# -0.4152 | tedious
# -0.4152 | neither
# -0.4156 | ill
# -0.4188 | pointless
# -0.4221 | boring
# -0.4221 | seems
# -0.4238 | off
# -0.4245 | less
# -0.4251 | poorly
# -0.4282 | unfortunately
# -0.4297 | depressing
# -0.4320 | tiresome
# -0.4369 | instead
# -0.4384 | shallow
# -0.4425 | starts
# -0.4460 | bland
# -0.4471 | just
# -0.4501 | nothing
# -0.4624 | lacking
# -0.4693 | were
# -0.4730 | exercise
# -0.4754 | contrived
# -0.4773 | or
# -0.4794 | already
# -0.4795 | tv
# -0.4840 | tired
# -0.4858 | lack
# -0.4888 | ugly
# -0.4926 | only
# -0.4942 | fails
# -0.4973 | none
# -0.5018 | t
# -0.5060 | unfunny
# -0.5063 | idea
# -0.5093 | problem
# -0.5166 | pretentious
# -0.5271 | flat
# -0.5291 | like
# -0.5296 | feels
# -0.5309 | n
# -0.5320 | minutes
# -0.5351 | plot
# -0.5630 | stupid
# -0.5759 | suffers
# -0.6143 | no
# -0.6169 | mess
# -0.6252 | worst
# -0.6349 | dull
# -0.7212 | ?
# -0.8373 | bad
# -0.8932 | too

# %% [markdown]
#  # View modeling training curves

# %%
# %load_ext tensorboard
# %tensorboard --logdir output/ftrlogistic
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6007 (pid 35340), started 0:38:15 ago. (Use '!kill 35340' to kill it.)

# %% [markdown]
#  ## Deep Averaging Networks (DAN)

# %%
class DeepAveragingNetworksModel(nn.Module):

    def __init__(self,
                 vocab,
                 vocab_size: int,
                 word_embedding_size: int,
                 hidden_size: int,
                 num_intermediate_layers: int,
                 dropout_rate: float,
                 use_glove: bool = False):
        """
        # Parameters
        vocab : `dict[str, int]`, required.
            A map from the word type to the index of the word.
        vocab_size : `int`, required.
            Size of the vocabulary.
        word_embedding_size : `int`, required.
            Size of word embeddings.
        hidden_size : `int`, required.
            Size of hidden layer or number of hidden units per layer.
        num_intermediate_layers : `int`, required.
            Number of intermediate layers, the arg takes 0 or greater integers.
        dropout_rate : `float`, required.
            Dropout rate.
        use_glove : `bool`, optional.
            Whether or not to use Glove embeddings instead of randomly initialized ones.
        """
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, word_embedding_size, padding_idx=0)
        if use_glove:
            self.load_glove(vocab, word_embedding_size)

        self.linear = nn.Linear(hidden_size, hidden_size)
        m = torch.nn.Tanh()
        
        if num_intermediate_layers <= 0:
            self.int_layers = [m]
        else:
            layers = torch.nn.ModuleList([m for i in range(0, num_intermediate_layers)])
            self.int_layers = torch.nn.ModuleList(layers)
            
        self.dropout_layer = torch.nn.Dropout(dropout_rate)
        self.output_layer = torch.nn.Linear(hidden_size, 1)

    def forward(self, input_ids, lengths):
        """
        # Parameters
        input_ids : `torch.Tensor`, required.
            Tensor of shape (batch_size, feature_length).
            Each row is a datapoint represented by input words.
        lengths: `torch.Tensor`, required.
            Tensor of shape (batch_size, 1). Token length of input text.
            Used to compute average word embeddings.
        # Returns
        probs : `torch.Tensor`
            Tensor of shape (batch_size)
        """
        out = self.embedding(input_ids)
        out = torch.mean(out, 1)
        
        for index, layer in enumerate(self.int_layers):
            out = self.linear(out)
            out = layer(out)
            out = self.dropout_layer(out)
        
        return self.output_layer(out)

    def load_glove(self, vocab, word_embedding_size):
        logger.info("Load glove pretrained word embeddings")

# %% [markdown]
#  ## Binary classifier based on curated features.

# %%
from nltk.tokenize import WordPunctTokenizer

class SST2Dataset(Dataset):
    """
    Using dataset to process input text on-the-fly
    """

    def __init__(self, vocab, data, tokenizer):
        self.data = data
        self.vocab = vocab
        self.max_len = 50
        self.tokenizer = tokenizer

    def __getitem__(self, index):
        note = []
        label, text = int(self.data[index][0]), self.data[index][1]
        tokens = self.tokenizer.tokenize(text.lower())
        token_ids = [self.vocab.get(t, 1) for t in tokens]
        length = min(len(token_ids), self.max_len)
        padded_token_ids = token_ids[:50] + [0] * (self.max_len - length)
        return padded_token_ids, length, label

    def collate_fn(self, batch_data):
        padded_token_ids, lengths, labels = list(zip(*batch_data))
        return (
            torch.LongTensor(padded_token_ids).view(-1, self.max_len),
            torch.FloatTensor(lengths).view(-1, 1),
            torch.FloatTensor(labels).view(-1, 1),
        )

    def __len__(self):
        return len(self.data)


class DeepAveragingBinaryClassificationLModule(BinaryClassificationLModule):

    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def get_model(self) -> nn.Module:
        return DeepAveragingNetworksModel(
            vocab=self.hparams.vocab,
            vocab_size=self.hparams.vocab_size,
            word_embedding_size=self.hparams.word_embedding_size,
            hidden_size=self.hparams.hidden_size,
            num_intermediate_layers=self.hparams.num_intermediate_layers,
            dropout_rate=self.hparams.dropout_rate,
            use_glove=self.hparams.use_glove)

    def batch2input(self, batch):
        return {'input_ids': batch[0], 'lengths': batch[1]}

    def batch2labels(self, batch):
        return batch[2].squeeze()

    def get_dataloader(self, split, batch_size, shuffle=False) -> DataLoader:
        data_dir = Path(self.hparams.data_dir)
        datapath = data_dir.joinpath(f"sst2.{split}")
        data = open(datapath).readlines()
        data = [d.strip().split(" ", maxsplit=1) for d in data]  
        dataset = SST2Dataset(vocab=self.hparams.vocab,
                              data=data,
                              tokenizer=WordPunctTokenizer())

        logger.info(f"Loading {split} data and labels from {datapath}")
        data_loader = DataLoader(dataset=dataset,
                                 batch_size=batch_size,
                                 shuffle=shuffle,
                                 num_workers=self.hparams.num_workers,
                                 collate_fn=dataset.collate_fn)

        return data_loader

    def configure_optimizers(self):
        if self.hparams.optimizer == 'sgd':
            optimizer = torch.optim.SGD(self.model.parameters(),
                                        lr=self.hparams.learning_rate)
        elif self.hparams.optimizer == 'adam':
            optimizer = torch.optim.Adam(self.model.parameters(),
                                         lr=self.hparams.learning_rate)
        elif self.hparams.optimizer == 'adagrad':
            optimizer = torch.optim.Adagrad(self.model.parameters(),
                                         lr=self.hparams.learning_rate)
        elif self.hparams.optimizer == 'rprop':
            optimizer = torch.optim.Rprop(self.model.parameters(), 
                                          lr=0.01)
        else:
            raise NotImplementedError
        return optimizer

    @classmethod
    def add_model_specific_args(cls, parser: ArgumentParser) -> ArgumentParser:
        parser = super().add_model_specific_args(parser)

        parser.add_argument('--num_intermediate_layers',
                            type=int,
                            help="number of intermediate layers")
        parser.add_argument('--dropout_rate',
                            default=0.5,
                            type=float,
                            help="Dropout rate")
        parser.add_argument('--word_embedding_size',
                            default=300,
                            type=int,
                            help="Size of word embeddings")
        parser.add_argument('--hidden_size',
                            default=300,
                            type=int,
                            help="Size of hidden layer")
        parser.add_argument('--use_glove',
                            action="store_true",
                            help="Whether to run predictions on the test set.")
        parser.add_argument('--task',
                            default='danbinarycls',
                            type=str,
                            help="Name of the task.")
        return parser

# %% [markdown]
#  ## Training loop for the feature-based model of deep averaging networks.

# %%
logging.basicConfig(format="%(asctime)s - %(levelname)s - %(name)s - %(message)s",
                    datefmt="%Y-%m-%d %H:%M:%S",
                    level=logging.INFO)
logger = logging.getLogger(__name__)

parser = ArgumentParser()
parser = DeepAveragingBinaryClassificationLModule.add_model_specific_args(parser)

args_str = ("--vocab_filename unigram_vocab.json "
            "--optimizer sgd --num_intermediate_layers 1 "
            "--output_dir output/dan  --do_train --do_predict ")
args = parser.parse_args(args_str.split())

if args.output_dir is None:
    args.output_dir = str(
        Path('output').joinpath(
            f"{args.task}_{datetime.now().strftime('%Y%m%d-%H%M%S')}"))
Path(args.output_dir).mkdir(parents=True, exist_ok=True)

print(f"Parsed arguments: {args}")

training_outout = generic_train(args=args,
                                model_class=DeepAveragingBinaryClassificationLModule)
# Out:
# Global seed set to 42
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
#
#   | Name     | Type                       | Params
# --------------------------------------------------------
# 0 | model    | DeepAveragingNetworksModel | 1.6 M
# 1 | accuracy | Accuracy                   | 0
# --------------------------------------------------------
# 1.6 M     Trainable params
# 0         Non-trainable params
# 1.6 M     Total params
# 6.301     Total estimated model params size (MB)
# Parsed arguments: Namespace(data_dir='sst2', do_predict=True, do_train=True, dropout_rate=0.5, eval_batch_size=32, gpus=0, hidden_size=300, learning_rate=0.001, max_epochs=10, num_intermediate_layers=1, num_workers=8, optimizer='sgd', output_dir='output/dan', seed=42, task='danbinarycls', train_batch_size=32, use_glove=False, vocab_filename='unigram_vocab.json', word_embedding_size=300)
# Validation sanity check: 0it [00:00, ?it/s]
# 2022-02-07 01:47:21 - INFO - __main__ - Loading dev data and labels from sst2/sst2.dev
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Global seed set to 42
# 2022-02-07 01:47:22 - INFO - __main__ - Loading train data and labels from sst2/sst2.train
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Epoch 0, global step 216: val_acc reached 0.49083 (best 0.49083), saving model to "/content/output/dan/version_20220207-014721/checkpoints/epoch=0-val_acc=0.49.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 1, global step 433: val_acc was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 2, global step 650: val_acc was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 3, global step 867: val_acc was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 4, global step 1084: val_acc was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 5, global step 1301: val_acc was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 6, global step 1518: val_acc was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 7, global step 1735: val_acc was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 8, global step 1952: val_acc was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 9, global step 2169: val_acc was not in top 1
# 2022-02-07 01:48:16 - INFO - __main__ - Copy best model from /content/output/dan/version_20220207-014721/checkpoints/epoch=0-val_acc=0.49.ckpt to output/dan/version_20220207-014721/checkpoints/best_model.ckpt.
# 2022-02-07 01:48:16 - INFO - __main__ - Loading dev data and labels from sst2/sst2.dev
# Validating: 0it [00:00, ?it/s]
# 2022-02-07 01:48:17 - INFO - __main__ - Loading test data and labels from sst2/sst2.test
# --------------------------------------------------------------------------------
# DATALOADER:0 VALIDATE RESULTS
# {'val_acc': 0.49082568287849426, 'val_loss': 0.6934987902641296}
# --------------------------------------------------------------------------------
# Testing: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.5008237361907959, 'test_loss': 0.6940311789512634}
# --------------------------------------------------------------------------------
# Validation accuracy on the best model:  0.4908
# Test       accuracy on the best model:  0.5008

# %% [markdown]
#  Another example with Adam optimizer and 2 hidden layers

# %%
parser = ArgumentParser()
parser = DeepAveragingBinaryClassificationLModule.add_model_specific_args(parser)

args_str = ("--vocab_filename unigram_vocab.json "
            "--optimizer adam --num_intermediate_layers 2 "
            "--output_dir output/dan  --do_train --do_predict ")
args = parser.parse_args(args_str.split())

if args.output_dir is None:
    args.output_dir = str(
        Path('output').joinpath(
            f"{args.task}_{datetime.now().strftime('%Y%m%d-%H%M%S')}"))
Path(args.output_dir).mkdir(parents=True, exist_ok=True)

print(f"Parsed arguments: {args}")

training_outout = generic_train(args=args,
                                model_class=DeepAveragingBinaryClassificationLModule)
# Out:
# Global seed set to 42
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
#
#   | Name     | Type                       | Params
# --------------------------------------------------------
# 0 | model    | DeepAveragingNetworksModel | 1.6 M
# 1 | accuracy | Accuracy                   | 0
# --------------------------------------------------------
# 1.6 M     Trainable params
# 0         Non-trainable params
# 1.6 M     Total params
# 6.301     Total estimated model params size (MB)
# Parsed arguments: Namespace(data_dir='sst2', do_predict=True, do_train=True, dropout_rate=0.5, eval_batch_size=32, gpus=0, hidden_size=300, learning_rate=0.001, max_epochs=10, num_intermediate_layers=2, num_workers=8, optimizer='adam', output_dir='output/dan', seed=42, task='danbinarycls', train_batch_size=32, use_glove=False, vocab_filename='unigram_vocab.json', word_embedding_size=300)
# Validation sanity check: 0it [00:00, ?it/s]
# 2022-02-07 01:48:18 - INFO - __main__ - Loading dev data and labels from sst2/sst2.dev
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Global seed set to 42
# 2022-02-07 01:48:19 - INFO - __main__ - Loading train data and labels from sst2/sst2.train
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Epoch 0, global step 216: val_acc reached 0.66972 (best 0.66972), saving model to "/content/output/dan/version_20220207-014818/checkpoints/epoch=0-val_acc=0.67.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 1, global step 433: val_acc reached 0.73624 (best 0.73624), saving model to "/content/output/dan/version_20220207-014818/checkpoints/epoch=1-val_acc=0.74.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 2, global step 650: val_acc reached 0.76376 (best 0.76376), saving model to "/content/output/dan/version_20220207-014818/checkpoints/epoch=2-val_acc=0.76.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 3, global step 867: val_acc reached 0.76491 (best 0.76491), saving model to "/content/output/dan/version_20220207-014818/checkpoints/epoch=3-val_acc=0.76.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 4, global step 1084: val_acc reached 0.76950 (best 0.76950), saving model to "/content/output/dan/version_20220207-014818/checkpoints/epoch=4-val_acc=0.77.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 5, global step 1301: val_acc was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 6, global step 1518: val_acc reached 0.77294 (best 0.77294), saving model to "/content/output/dan/version_20220207-014818/checkpoints/epoch=6-val_acc=0.77.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 7, global step 1735: val_acc was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 8, global step 1952: val_acc was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 9, global step 2169: val_acc was not in top 1
# 2022-02-07 01:49:34 - INFO - __main__ - Copy best model from /content/output/dan/version_20220207-014818/checkpoints/epoch=6-val_acc=0.77.ckpt to output/dan/version_20220207-014818/checkpoints/best_model.ckpt.
# 2022-02-07 01:49:34 - INFO - __main__ - Loading dev data and labels from sst2/sst2.dev
# Validating: 0it [00:00, ?it/s]
# 2022-02-07 01:49:35 - INFO - __main__ - Loading test data and labels from sst2/sst2.test
# --------------------------------------------------------------------------------
# DATALOADER:0 VALIDATE RESULTS
# {'val_acc': 0.7729358077049255, 'val_loss': 0.6977782845497131}
# --------------------------------------------------------------------------------
# Testing: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.7841845154762268, 'test_loss': 0.6381437182426453}
# --------------------------------------------------------------------------------
# Validation accuracy on the best model:  0.7729
# Test       accuracy on the best model:  0.7842

# %% [markdown]
# Example with Adagrad optimizer and 2 hidden layers (lr default = 1e-2)

# %%
parser = ArgumentParser()
parser = DeepAveragingBinaryClassificationLModule.add_model_specific_args(parser)

args_str = ("--vocab_filename unigram_vocab.json "
            "--optimizer adagrad --num_intermediate_layers 2 "
            "--output_dir output/dan  --do_train --do_predict ")
args = parser.parse_args(args_str.split())

if args.output_dir is None:
    args.output_dir = str(
        Path('output').joinpath(
            f"{args.task}_{datetime.now().strftime('%Y%m%d-%H%M%S')}"))
Path(args.output_dir).mkdir(parents=True, exist_ok=True)

print(f"Parsed arguments: {args}")

training_outout = generic_train(args=args,
                                model_class=DeepAveragingBinaryClassificationLModule)
# Out:
# Global seed set to 42
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
#
#   | Name     | Type                       | Params
# --------------------------------------------------------
# 0 | model    | DeepAveragingNetworksModel | 1.6 M
# 1 | accuracy | Accuracy                   | 0
# --------------------------------------------------------
# 1.6 M     Trainable params
# 0         Non-trainable params
# 1.6 M     Total params
# 6.301     Total estimated model params size (MB)
# Parsed arguments: Namespace(data_dir='sst2', do_predict=True, do_train=True, dropout_rate=0.5, eval_batch_size=32, gpus=0, hidden_size=300, learning_rate=0.001, max_epochs=10, num_intermediate_layers=2, num_workers=8, optimizer='adagrad', output_dir='output/dan', seed=42, task='danbinarycls', train_batch_size=32, use_glove=False, vocab_filename='unigram_vocab.json', word_embedding_size=300)
# Validation sanity check: 0it [00:00, ?it/s]
# 2022-02-07 01:49:36 - INFO - __main__ - Loading dev data and labels from sst2/sst2.dev
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Global seed set to 42
# 2022-02-07 01:49:37 - INFO - __main__ - Loading train data and labels from sst2/sst2.train
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Epoch 0, global step 216: val_acc reached 0.49312 (best 0.49312), saving model to "/content/output/dan/version_20220207-014936/checkpoints/epoch=0-val_acc=0.49.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 1, global step 433: val_acc reached 0.50573 (best 0.50573), saving model to "/content/output/dan/version_20220207-014936/checkpoints/epoch=1-val_acc=0.51.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 2, global step 650: val_acc reached 0.51835 (best 0.51835), saving model to "/content/output/dan/version_20220207-014936/checkpoints/epoch=2-val_acc=0.52.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 3, global step 867: val_acc reached 0.54243 (best 0.54243), saving model to "/content/output/dan/version_20220207-014936/checkpoints/epoch=3-val_acc=0.54.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 4, global step 1084: val_acc reached 0.55161 (best 0.55161), saving model to "/content/output/dan/version_20220207-014936/checkpoints/epoch=4-val_acc=0.55.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 5, global step 1301: val_acc reached 0.56307 (best 0.56307), saving model to "/content/output/dan/version_20220207-014936/checkpoints/epoch=5-val_acc=0.56.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 6, global step 1518: val_acc reached 0.58486 (best 0.58486), saving model to "/content/output/dan/version_20220207-014936/checkpoints/epoch=6-val_acc=0.58.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 7, global step 1735: val_acc reached 0.59060 (best 0.59060), saving model to "/content/output/dan/version_20220207-014936/checkpoints/epoch=7-val_acc=0.59.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 8, global step 1952: val_acc reached 0.60780 (best 0.60780), saving model to "/content/output/dan/version_20220207-014936/checkpoints/epoch=8-val_acc=0.61.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 9, global step 2169: val_acc was not in top 1
# 2022-02-07 01:50:39 - INFO - __main__ - Copy best model from /content/output/dan/version_20220207-014936/checkpoints/epoch=8-val_acc=0.61.ckpt to output/dan/version_20220207-014936/checkpoints/best_model.ckpt.
# 2022-02-07 01:50:40 - INFO - __main__ - Loading dev data and labels from sst2/sst2.dev
# Validating: 0it [00:00, ?it/s]
# 2022-02-07 01:50:41 - INFO - __main__ - Loading test data and labels from sst2/sst2.test
# --------------------------------------------------------------------------------
# DATALOADER:0 VALIDATE RESULTS
# {'val_acc': 0.607798159122467, 'val_loss': 0.6229878067970276}
# --------------------------------------------------------------------------------
# Testing: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.6232839226722717, 'test_loss': 0.6190968751907349}
# --------------------------------------------------------------------------------
# Validation accuracy on the best model:  0.6078
# Test       accuracy on the best model:  0.6233

# %% [markdown]
# Example with RProp optimizer and 2 hidden layers (lr default = 1e-2)

# %%
parser = ArgumentParser()
parser = DeepAveragingBinaryClassificationLModule.add_model_specific_args(parser)

args_str = ("--vocab_filename unigram_vocab.json "
            "--optimizer rprop --num_intermediate_layers 2 "
            "--output_dir output/dan  --do_train --do_predict ")
args = parser.parse_args(args_str.split())

if args.output_dir is None:
    args.output_dir = str(
        Path('output').joinpath(
            f"{args.task}_{datetime.now().strftime('%Y%m%d-%H%M%S')}"))
Path(args.output_dir).mkdir(parents=True, exist_ok=True)

print(f"Parsed arguments: {args}")

training_outout = generic_train(args=args,
                                model_class=DeepAveragingBinaryClassificationLModule)
# Out:
# Global seed set to 42
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
#
#   | Name     | Type                       | Params
# --------------------------------------------------------
# 0 | model    | DeepAveragingNetworksModel | 1.6 M
# 1 | accuracy | Accuracy                   | 0
# --------------------------------------------------------
# 1.6 M     Trainable params
# 0         Non-trainable params
# 1.6 M     Total params
# 6.301     Total estimated model params size (MB)
# Parsed arguments: Namespace(data_dir='sst2', do_predict=True, do_train=True, dropout_rate=0.5, eval_batch_size=32, gpus=0, hidden_size=300, learning_rate=0.001, max_epochs=10, num_intermediate_layers=2, num_workers=8, optimizer='rprop', output_dir='output/dan', seed=42, task='danbinarycls', train_batch_size=32, use_glove=False, vocab_filename='unigram_vocab.json', word_embedding_size=300)
# Validation sanity check: 0it [00:00, ?it/s]
# 2022-02-07 01:50:42 - INFO - __main__ - Loading dev data and labels from sst2/sst2.dev
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Global seed set to 42
# 2022-02-07 01:50:43 - INFO - __main__ - Loading train data and labels from sst2/sst2.train
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Epoch 0, global step 216: val_acc reached 0.63761 (best 0.63761), saving model to "/content/output/dan/version_20220207-015042/checkpoints/epoch=0-val_acc=0.64.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 1, global step 433: val_acc reached 0.67661 (best 0.67661), saving model to "/content/output/dan/version_20220207-015042/checkpoints/epoch=1-val_acc=0.68.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 2, global step 650: val_acc reached 0.69954 (best 0.69954), saving model to "/content/output/dan/version_20220207-015042/checkpoints/epoch=2-val_acc=0.70.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 3, global step 867: val_acc reached 0.71904 (best 0.71904), saving model to "/content/output/dan/version_20220207-015042/checkpoints/epoch=3-val_acc=0.72.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 4, global step 1084: val_acc reached 0.73853 (best 0.73853), saving model to "/content/output/dan/version_20220207-015042/checkpoints/epoch=4-val_acc=0.74.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 5, global step 1301: val_acc reached 0.74541 (best 0.74541), saving model to "/content/output/dan/version_20220207-015042/checkpoints/epoch=5-val_acc=0.75.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 6, global step 1518: val_acc reached 0.75000 (best 0.75000), saving model to "/content/output/dan/version_20220207-015042/checkpoints/epoch=6-val_acc=0.75.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 7, global step 1735: val_acc reached 0.75917 (best 0.75917), saving model to "/content/output/dan/version_20220207-015042/checkpoints/epoch=7-val_acc=0.76.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 8, global step 1952: val_acc reached 0.76835 (best 0.76835), saving model to "/content/output/dan/version_20220207-015042/checkpoints/epoch=8-val_acc=0.77.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 9, global step 2169: val_acc reached 0.77294 (best 0.77294), saving model to "/content/output/dan/version_20220207-015042/checkpoints/epoch=9-val_acc=0.77.ckpt" as top 1
# 2022-02-07 01:52:39 - INFO - __main__ - Copy best model from /content/output/dan/version_20220207-015042/checkpoints/epoch=9-val_acc=0.77.ckpt to output/dan/version_20220207-015042/checkpoints/best_model.ckpt.
# 2022-02-07 01:52:39 - INFO - __main__ - Loading dev data and labels from sst2/sst2.dev
# Validating: 0it [00:00, ?it/s]
# 2022-02-07 01:52:40 - INFO - __main__ - Loading test data and labels from sst2/sst2.test
# --------------------------------------------------------------------------------
# DATALOADER:0 VALIDATE RESULTS
# {'val_acc': 0.7729358077049255, 'val_loss': 0.48662206530570984}
# --------------------------------------------------------------------------------
# Testing: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.7753981351852417, 'test_loss': 0.4759145677089691}
# --------------------------------------------------------------------------------
# Validation accuracy on the best model:  0.7729
# Test       accuracy on the best model:  0.7754

# %%
# %reload_ext  tensorboard
# %tensorboard --logdir output/dan
# Out:
# Reusing TensorBoard on port 6006 (pid 32322), started 0:48:42 ago. (Use '!kill 32322' to kill it.)
