# %% [markdown]
#  See links for instructions on installation if not already installed.
#   - [NLTK](https://www.nltk.org/install.html) (tested with 3.6.7 and with 3.2.5.)
#   - [Scikit-Learn](https://scikit-learn.org/stable/install.html) (test with 1.0.2)
#   - [SciPy](https://scipy.org/install/) (tested with 1.7.3 and with 1.4.1)

# %%
# !pip install gdown
# !gdown --id 1thWkUj7uGOApr_dXRvMr9TsEHpo_H_2q -O sst2.zip
# !mkdir -p data
# !unzip sst2.zip -d data
# !rm sst2.zip

# %% [markdown]
#  # Feature Engineering - Lemmatization

# %%
from collections import Counter
import json
import re
from pathlib import Path

from nltk.tokenize import WordPunctTokenizer
from nltk.stem import WordNetLemmatizer

print("Build lemmatization vocab from sst2.train")
data_dir = Path('sst2/')
tokenizer = WordPunctTokenizer()
lemmatizer = WordNetLemmatizer()
lem_counter = Counter()
lem_counter.update(['<pad>', '<unk>'])
data_train = open(data_dir.joinpath('sst2.train')).readlines()
print(f"Size of training data: {len(data_train)}")

token_lines = []

for line in data_train:
    lower_line = line.lower()
    token_lines.append(tokenizer.tokenize(lower_line))

lem_lines = []

for line in token_lines:
    lem_lines.append([lemmatizer.lemmatize(word, 'v') for word in line])
        
for sentence in lem_lines:
    sentence = sentence[1:]
    #sentence = [word for word in sentence if word not in lst_stopwords]
    for word in sentence:
        lem_counter[word] = lem_counter.get(word, 0) + 1

print(f"Vocab size before frequency filtering: {len(lem_counter)}")

lem_vocab = {key: val for key, val in lem_counter.items() if val >= 3 or key == '<pad>' or key == '<unk>'}
lem_vocab = {key: 0 for key in lem_vocab}
lem_vocab.update((k, i) for i, k in enumerate(lem_vocab))

print(f"Vocab size after frequency filtering: {len(lem_vocab)}")
output_filepath = data_dir.joinpath('lemmatization_vocab.json')
json.dump(lem_vocab, open(output_filepath, mode='w'))
# Out:
# Build lemmatization vocab from sst2.train
# Size of training data: 6920
# Vocab size before frequency filtering: 11568
# Vocab size after frequency filtering: 4480

# %%
import json
from nltk.tokenize import WordPunctTokenizer
import numpy as np
import math
from scipy import sparse

def lem_features(vocab, data_dir, dataset, data_type, tokenizer, feature_name, tfidf):
    '''
    Generates sparse matrices for lemmatization with TF-IDF
    '''
        
    data = open(data_dir.joinpath(dataset)).readlines()
    tokenizer = WordPunctTokenizer()
    lemmatizer = WordNetLemmatizer()
    
    tokens = []
    for line in data:
        lower_line = line.lower()
        tokens.append(tokenizer.tokenize(lower_line))
        
    lemma = []
    for line in tokens:
        lemma.append([lemmatizer.lemmatize(word, 'v') for word in line])
    
    final_lemma = []
    for line in lemma:
        split_line = line[1:]
        final_lemma.append(split_line)

    idf_dict = {key: 0 for key in vocab.keys()}
    for line in final_lemma:
        for word in line:
            if word in vocab.keys():
                idf_dict[word] = idf_dict.get(word, 0) + 1
            
    for key, value in idf_dict.items():
        idf_dict[key] = math.log10(len(final_lemma)/(value + 1))
        
    data_dict = {index: {key: value for key, value in idf_dict.items()} for index, value in enumerate(final_lemma)}
    for line in final_lemma:
        for word in line:
            tf = line.count(word) / len(line)
            if word in vocab.keys():
                data_dict[final_lemma.index(line)][word] = data_dict[final_lemma.index(line)].get(word)*tf
    
    binary_lem = {index: {key: 0 for key in vocab.keys()} for index, value in enumerate(final_lemma)}
    for line in final_lemma:
        for word in line:
            if word in vocab.keys():
                binary_lem[final_lemma.index(line)][word] = 1
            else:
                binary_lem[final_lemma.index(line)]['<unk>'] = 1
    
    data_matrix = np.array([[data_dict[index][key] for key in vocab.keys()] for index, value in enumerate(final_lemma)])
    lem_matrix = np.array([[binary_lem[index][key] for key in vocab.keys()] for index, value in enumerate(final_lemma)])
    
    if tfidf is True: 
        sparse_matrix = sparse.csr_matrix(data_matrix)
        print(("The shape of the " + data_type + " matrix is: "), data_matrix.shape)
        print()
    else:
        sparse_matrix = sparse.csr_matrix(lem_matrix)
        print(("The shape of the " + data_type + " matrix is: "), lem_matrix.shape)
        print()
        
    sparse.save_npz('sst2/' + data_type + '_' + feature_name + '_features.npz', sparse_matrix)

# %%
lem_features(lem_vocab, Path('sst2/'), 'sst2.train', 'train', WordPunctTokenizer(), 'lemmatization', True)
lem_features(lem_vocab, Path('sst2/'), 'sst2.dev', 'dev', WordPunctTokenizer(), 'lemmatization', True)
lem_features(lem_vocab, Path('sst2/'), 'sst2.test', 'test', WordPunctTokenizer(), 'lemmatization', True)
# Out:
# The shape of the train matrix is:  (6920, 4480)
#
# The shape of the dev matrix is:  (872, 4480)
#
# The shape of the test matrix is:  (1821, 4480)

# %%
train_lemma = sparse.load_npz('sst2/train_lemmatization_features.npz')
dev_lemma = sparse.load_npz('sst2/dev_lemmatization_features.npz')
test_lemma = sparse.load_npz('sst2/test_lemmatization_features.npz')

train_labels = np.load('sst2/train_labels.npz')
dev_labels = np.load('sst2/dev_labels.npz')
test_labels = np.load('sst2/test_labels.npz')

# %%
def print_important_weights(weights, words):
    """
    Print important pairs of weights and words.
    # Parameters
    weights : `Iterable`, required.
        Weights from a learned model.
    words : `Iterable`, required.
        Word types of the vocabulary.  
        It must be true that `len(weights) == len(words)`.
    # Returns
        `None`
    """

    def print_pairs(pairs):
        for weight, word in pairs:
            print("{: .4f} | {}".format(weight, word))

    assert len(weights) == len(words)
    pairs = list(zip(weights, words))
    pairs = sorted(pairs, key=lambda x: x[0], reverse=True)
    print("Most positive words:")
    print_pairs(reversed(pairs[-10:]))
    print("\nMost negative words:")
    print_pairs(pairs[:10])

    pairs = list(zip(abs(weights), words))
    pairs = sorted(pairs, key=lambda x: x[0], reverse=False)
    print("\nMost neutral words:")
    print_pairs(pairs[:10])

# %% [markdown]
#  # Logistic regression with scikit-learn

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score

def fit_and_eval_logistic_regression(data_dir: Path,
                                     train_X, train_Y,
                                     test_X, test_Y,
                                     feature_name: str) -> LogisticRegression:
    '''
    Fits and evaluates the logistic regression model using the scikit-learn library
    
    Inputs:
        data_dir (path): the data directory
        trn_data (file): training data 
        tst_data (file): testing or dev data
        
    Output:
        model_trained (LogisticRegression): object of LogisticRegression after it is trained
    '''
    
    model = LogisticRegression()
    model.fit(train_X, train_Y['arr_0'])
    y_pred = model.predict(test_X)
    
    print("The accuracy score is: ", accuracy_score(test_Y['arr_0'], y_pred))
    print("The f1 score is: ", f1_score(test_Y['arr_0'], y_pred, average = 'weighted'))
    
    return model

# %% [markdown]
# ### dev model

# %%
print("These are the scores for dev")
print()

fit_and_eval_logistic_regression(feature_name = 'lemmatization',
                                 train_X = train_lemma, train_Y = train_labels,
                                 test_X = dev_lemma, test_Y = dev_labels,
                                 data_dir = Path('sst2/'))
# Out:
# These are the scores for dev
#
# The accuracy score is:  0.6422018348623854
# The f1 score is:  0.5967287870722757
# /usr/local/anaconda3/envs/nlp_env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ### test model

# %%
print("These are the scores for test")
print()

fit_and_eval_logistic_regression(feature_name = 'lemmatization',
                                 train_X = train_lemma, train_Y = train_labels,
                                 test_X = test_lemma, test_Y = test_labels,
                                 data_dir = Path('sst2/'))
# Out:
# These are the scores for test
#
# The accuracy score is:  0.7660626029654036
# The f1 score is:  0.7616246637172223
# /usr/local/anaconda3/envs/nlp_env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ## Weights Analysis

# %%
model_trained: LogisticRegression = fit_and_eval_logistic_regression(
    feature_name='lemmatization', train_X = train_lemma, train_Y = train_labels, test_X = test_lemma, test_Y = test_labels,data_dir=Path('data'))
weights = model_trained.coef_[0]
vocab = json.load(open(data_dir.joinpath('lemmatization_vocab.json')))
print_important_weights(weights=weights, words=vocab.keys())
# Out:
# The accuracy score is:  0.7660626029654036
# The f1 score is:  0.7616246637172223
# Most positive words:
# -1.8231 | solid
# -1.7849 | powerful
# -1.7820 | remarkable
# -1.7757 | enjoyable
# -1.7091 | fun
# -1.6996 | and
# -1.6156 | refresh
# -1.3956 | hilarious
# -1.3933 | love
# -1.3918 | beautifully
#
# Most negative words:
#  1.7768 | stupid
#  1.6524 | suffer
#  1.6224 | lack
#  1.6055 | bland
#  1.6001 | dull
#  1.5975 | bore
#  1.5635 | worst
#  1.5444 | depress
#  1.4741 | flat
#  1.4548 | instead
#
# Most neutral words:
#  0.0000 | stage
#  0.0000 | narrative
#  0.0002 | sane
#  0.0003 | bake
#  0.0004 | handle
#  0.0004 | --
#  0.0008 | hunter
#  0.0012 | legged
#  0.0014 | upper
#  0.0018 | mcgrath
# /usr/local/anaconda3/envs/nlp_env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ## Error Analysis

# %%
def test_errors(data_dir: Path, train_X, train_Y, test_X, test_Y, feature_name: str) -> LogisticRegression:
    '''
    Returns predicted label output for given training and testing data
    '''
    
    model = LogisticRegression()
    model.fit(train_X, train_Y['arr_0'])
    y_pred = model.predict(test_X)
    
    return y_pred

# %%
test_model = test_errors(feature_name = 'lemmatization',
                         train_X = train_lemma, train_Y = train_labels,
                         test_X = test_lemma, test_Y = test_labels,
                         data_dir = Path('sst2/'))
# Out:
# /usr/local/anaconda3/envs/nlp_env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

def error_frame(pred_model, labels):
    '''
    Generates a pandas dataframe of mislabeled reviews
    '''
    
    label_column = pd.DataFrame(labels)
    label_column.rename(columns = {0: "True"}, inplace = True)
    model_column = pd.DataFrame(pred_model)
    model_column.rename(columns = {0: "Predicted"}, inplace = True)
    
    data_test = open(data_dir.joinpath('sst2.test')).readlines()
    tokens = []
    for line in data_test:
        lower_line = line.lower()
        tokens.append(tokenizer.tokenize(lower_line))
    
    full_frame = label_column.join(model_column)
    full_frame["Match"] = (full_frame["True"] == full_frame["Predicted"]).astype(int)
    full_frame["Line"] = tokens
    full_frame.index += 1
    
    print("The number of errors found: ", len(full_frame.loc[full_frame['Match'] == 0]))
    return full_frame.loc[full_frame['Match'] == 0]
# Out:
# /var/folders/dv/2_6b6bzd04x61zh3lkj7mmxm0000gn/T/ipykernel_57502/2119148839.py:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
error_frame(test_model, test_labels['arr_0'])
# Out:
# The number of errors found:  426
#       True  Predicted  Match  \
# 2     0     1          0
# 8     1     0          0
# 9     0     1          0
# 17    1     0          0
# 19    0     1          0
# 20    0     1          0
# 22    0     1          0
# 23    1     0          0
# 29    0     1          0
# 44    1     0          0
# 53    1     0          0
# 55    0     1          0
# 58    1     0          0
# 59    0     1          0
# 75    1     0          0
# 76    0     1          0
# 83    0     1          0
# 85    1     0          0
# 88    0     1          0
# 95    1     0          0
# 97    0     1          0
# 100   0     1          0
# 110   0     1          0
# 114   0     1          0
# 119   0     1          0
# 125   1     0          0
# 126   0     1          0
# 127   0     1          0
# 130   1     0          0
# 132   0     1          0
# 140   0     1          0
# 144   0     1          0
# 150   0     1          0
# 151   0     1          0
# 152   0     1          0
# 159   0     1          0
# 166   1     0          0
# 170   0     1          0
# 171   0     1          0
# 173   0     1          0
# 177   1     0          0
# 189   0     1          0
# 191   0     1          0
# 198   0     1          0
# 202   0     1          0
# 207   0     1          0
# 209   1     0          0
# 219   0     1          0
# 221   0     1          0
# 237   0     1          0
# 246   0     1          0
# 248   1     0          0
# 252   1     0          0
# 257   0     1          0
# 261   0     1          0
# 263   0     1          0
# 273   0     1          0
# 276   0     1          0
# 281   1     0          0
# 282   0     1          0
# 285   0     1          0
# 293   0     1          0
# 300   0     1          0
# 302   1     0          0
# 308   0     1          0
# 309   0     1          0
# 312   1     0          0
# 313   0     1          0
# 325   0     1          0
# 329   0     1          0
# 345   1     0          0
# 346   0     1          0
# 350   0     1          0
# 361   1     0          0
# 362   0     1          0
# 363   1     0          0
# 369   0     1          0
# 371   0     1          0
# 372   0     1          0
# 375   0     1          0
# 377   1     0          0
# 379   0     1          0
# 380   1     0          0
# 381   0     1          0
# 383   0     1          0
# 387   0     1          0
# 391   0     1          0
# 394   0     1          0
# 395   0     1          0
# 400   0     1          0
# 403   0     1          0
# 405   0     1          0
# 406   1     0          0
# 407   0     1          0
# 411   0     1          0
# 413   1     0          0
# 422   0     1          0
# 426   1     0          0
# 427   0     1          0
# 438   0     1          0
# 440   0     1          0
# 447   0     1          0
# 453   0     1          0
# 470   0     1          0
# 473   1     0          0
# 474   1     0          0
# 476   0     1          0
# 478   0     1          0
# 483   1     0          0
# 487   1     0          0
# 488   0     1          0
# 490   0     1          0
# 499   0     1          0
# 502   0     1          0
# 508   0     1          0
# 509   0     1          0
# 515   0     1          0
# 516   0     1          0
# 517   0     1          0
# 520   0     1          0
# 523   0     1          0
# 525   1     0          0
# 526   0     1          0
# 528   0     1          0
# 529   0     1          0
# 530   0     1          0
# 535   0     1          0
# 539   0     1          0
# 541   0     1          0
# 547   1     0          0
# 548   0     1          0
# 556   1     0          0
# 558   0     1          0
# 565   0     1          0
# 568   0     1          0
# 580   0     1          0
# 593   0     1          0
# 599   0     1          0
# 602   0     1          0
# 603   0     1          0
# 604   0     1          0
# 607   0     1          0
# 613   1     0          0
# 619   0     1          0
# 636   0     1          0
# 645   0     1          0
# 647   0     1          0
# 650   0     1          0
# 652   1     0          0
# 653   0     1          0
# 655   1     0          0
# 660   1     0          0
# 661   0     1          0
# 669   0     1          0
# 673   1     0          0
# 674   0     1          0
# 675   0     1          0
# 677   1     0          0
# 678   0     1          0
# 682   0     1          0
# 684   0     1          0
# 685   0     1          0
# 686   0     1          0
# 689   1     0          0
# 691   0     1          0
# 692   0     1          0
# 700   1     0          0
# 712   1     0          0
# 715   1     0          0
# 721   0     1          0
# 722   0     1          0
# 727   1     0          0
# 728   1     0          0
# 732   0     1          0
# 738   1     0          0
# 759   1     0          0
# 763   1     0          0
# 767   0     1          0
# 769   1     0          0
# 771   0     1          0
# 777   0     1          0
# 778   0     1          0
# 779   0     1          0
# 784   0     1          0
# 785   0     1          0
# 790   0     1          0
# 792   0     1          0
# 794   0     1          0
# 797   0     1          0
# 798   1     0          0
# 800   1     0          0
# 801   0     1          0
# 804   0     1          0
# 813   0     1          0
# 819   0     1          0
# 822   0     1          0
# 825   0     1          0
# 826   1     0          0
# 831   0     1          0
# 840   0     1          0
# 842   0     1          0
# 847   0     1          0
# 857   0     1          0
# 860   0     1          0
# 863   1     0          0
# 871   0     1          0
# 872   0     1          0
# 882   0     1          0
# 887   0     1          0
# 892   0     1          0
# 894   1     0          0
# 903   0     1          0
# 906   0     1          0
# 908   0     1          0
# 911   0     1          0
# 914   0     1          0
# 915   1     0          0
# 921   0     1          0
# 925   0     1          0
# 927   0     1          0
# 929   1     0          0
# 930   0     1          0
# 931   0     1          0
# 932   0     1          0
# 933   0     1          0
# 937   0     1          0
# 940   0     1          0
# 943   0     1          0
# 947   0     1          0
# 948   0     1          0
# 959   0     1          0
# 964   0     1          0
# 972   0     1          0
# 973   0     1          0
# 975   0     1          0
# 978   0     1          0
# 979   0     1          0
# 981   0     1          0
# 987   1     0          0
# 988   0     1          0
# 989   0     1          0
# 991   0     1          0
# 994   0     1          0
# 997   1     0          0
# 998   0     1          0
# 999   0     1          0
# 1007  1     0          0
# 1010  0     1          0
# 1020  1     0          0
# 1026  0     1          0
# 1029  0     1          0
# 1045  0     1          0
# 1047  0     1          0
# 1052  0     1          0
# 1053  0     1          0
# 1054  0     1          0
# 1057  0     1          0
# 1068  0     1          0
# 1084  0     1          0
# 1097  0     1          0
# 1099  1     0          0
# 1105  0     1          0
# 1106  0     1          0
# 1112  1     0          0
# 1118  0     1          0
# 1120  0     1          0
# 1122  0     1          0
# 1733  0     1          0
# 1736  1     0          0
# 1756  0     1          0
# 1761  0     1          0
# 1767  0     1          0
# 1768  0     1          0
# 1769  0     1          0
# 1771  0     1          0
# 1781  0     1          0
# 1787  0     1          0
# 1788  0     1          0
# 1801  0     1          0
# 1805  0     1          0
# 1810  0     1          0
# 1817  0     1          0
# 1819  0     1          0
# 1820  0     1          0
# 1821  0     1          0
#
#                                                                                                                                                                                                                                                                                                                              Line
# 2     [0, a, gob, of, drivel, so, sickly, sweet, ,, even, the, eager, consumers, of, moore, ', s, pasteurized, ditties, will, retch, it, up, like, rancid, crème, brûlée, .]
# 8     [1, the, movie, exists, for, its, soccer, action, and, its, fine, acting, .]
# 9     [0, arnold, ', s, jump, from, little, screen, to, big, will, leave, frowns, on, more, than, a, few, faces, .]
# 17    [1, if, your, senses, have, n, ', t, been, dulled, by, slasher, films, and, gorefests, ,, if, you, ', re, a, connoisseur, of, psychological, horror, ,, this, is, your, ticket, .]
# 19    [0, as, conceived, by, mr, ., schaeffer, ,, christopher, and, grace, are, little, more, than, collections, of, quirky, traits, lifted, from, a, screenwriter, ', s, outline, and, thrown, at, actors, charged, with, the, impossible, task, of, making, them, jell, .]
# 20    [0, those, who, managed, to, avoid, the, deconstructionist, theorizing, of, french, philosopher, jacques, derrida, in, college, can, now, take, an, 85, -, minute, brush, -, up, course, with, the, documentary, derrida, .]
# 22    [0, but, what, saves, lives, on, the, freeway, does, not, necessarily, make, for, persuasive, viewing, .]
# 23    [1, steve, irwin, ', s, method, is, ernest, hemmingway, at, accelerated, speed, and, volume, .]
# 29    [0, the, premise, for, this, kegger, comedy, probably, sounded, brilliant, four, six, -, packs, and, a, pitcher, of, margaritas, in, ,, but, the, film, must, have, been, written, ..., in, the, thrall, of, a, vicious, hangover, .]
# 44    [1, much, monkeyfun, for, all, .]
# 53    [1, it, represents, better, -, than, -, average, movie, -, making, that, does, n, ', t, demand, a, dumb, ,, distracted, audience, .]
# 55    [0, it, may, be, an, easy, swipe, to, take, ,, but, this, barbershop, just, does, n, ', t, make, the, cut, .]
# 58    [1, for, all, its, failed, connections, ,, divine, secrets, of, the, ya, -, ya, sisterhood, is, nurturing, ,, in, a, gauzy, ,, dithering, way, .]
# 59    [0, as, are, its, star, ,, its, attitude, and, its, obliviousness, .]
# 75    [1, -, lrb, -, schweiger, is, -, rrb, -, talented, and, terribly, charismatic, ,, qualities, essential, to, both, movie, stars, and, social, anarchists, .]
# 76    [0, a, well, acted, and, well, intentioned, snoozer, .]
# 83    [0, about, as, satisfying, and, predictable, as, the, fare, at, your, local, drive, through, .]
# 85    [1, as, lo, -, fi, as, the, special, effects, are, ,, the, folks, who, cobbled, nemesis, together, indulge, the, force, of, humanity, over, hardware, in, a, way, that, george, lucas, has, long, forgotten, .]
# 88    [0, george, ,, hire, a, real, director, and, good, writers, for, the, next, installment, ,, please, .]
# 95    [1, if, it, tried, to, do, anything, more, ,, it, would, fail, and, perhaps, explode, ,, but, at, this, level, of, manic, whimsy, ,, it, is, just, about, right, .]
# 1761  [0, ..., a, haunting, vision, ,, with, images, that, seem, more, like, disturbing, hallucinations, .]
# 1767  [0, with, its, hints, of, a, greater, intelligence, lurking, somewhere, ,, the, ring, makes, its, stupidity, more, than, obvious, .]
# 1768  [0, an, afterschool, special, without, the, courage, of, its, convictions, .]
# 1769  [0, uneasy, mishmash, of, styles, and, genres, .]
# 1771  [0, earnest, falls, short, of, its, ideal, predecessor, largely, due, to, parker, ', s, ill, -, advised, meddling, with, the, timeless, source, material, .]
# 1781  [0, the, story, loses, its, bite, in, a, last, -, minute, happy, ending, that, ', s, even, less, plausible, than, the, rest, of, the, picture, .]
# 1787  [0, he, ', d, create, a, movie, better, than, this, .]
# 1788  [0, my, response, to, the, film, is, best, described, as, lukewarm, .]
# 1801  [0, or, some, damn, thing, .]
# 1805  [0, creepy, but, ultimately, unsatisfying, thriller, .]
# 1810  [0, this, is, pretty, dicey, material, .]
# 1817  [0, an, often, -, deadly, boring, ,, strange, reading, of, a, classic, whose, witty, dialogue, is, treated, with, a, baffling, casual, approach]
# 1819  [0, safe, conduct, ,, however, ambitious, and, well, -, intentioned, ,, fails, to, hit, the, entertainment, bull, ', s, -, eye, .]
# 1820  [0, a, film, made, with, as, little, wit, ,, interest, ,, and, professionalism, as, artistically, possible, for, a, slummy, hollywood, caper, flick, .]
# 1821  [0, but, here, ', s, the, real, damn, :, it, is, n, ', t, funny, ,, either, .]

# %%
def print_weight(weights, words):
    """
    Prints all word-weight pairs for given data and vocabulary
    """

    def print_pairs(pairs):
        for weight, word in pairs:
            print("{: .4f} | {}".format(weight, word))

    assert len(weights) == len(words)
    pairs = list(zip(weights, words))
    pairs = sorted(pairs, key=lambda x: x[0], reverse=True)
    print_pairs(pairs)

# %%
print_weight(weights = weights, words=vocab.keys())
# Out:
#  1.7768 | stupid
#  1.6524 | suffer
#  1.6224 | lack
#  1.6055 | bland
#  1.6001 | dull
#  1.5975 | bore
#  1.5635 | worst
#  1.5444 | depress
#  1.4741 | flat
#  1.4548 | instead
#  1.4349 | too
#  1.4344 | failure
#  1.4247 | lousy
#  1.3922 | none
#  1.3906 | tv
#  1.3571 | unfortunately
#  1.3524 | devoid
#  1.3366 | tiresome
#  1.3352 | mess
#  1.2984 | fail
#  1.2974 | listless
#  1.2928 | unfunny
#  1.2701 | barely
#  1.2666 | bad
#  1.2406 | pretentious
#  1.2330 | ill
#  1.1980 | no
#  1.1938 | violence
#  1.1870 | uneven
#  1.1612 | awful
#  1.1482 | empty
#  1.1465 | settle
#  1.1434 | waste
#  1.1428 | tire
#  1.1376 | already
#  1.1292 | be
#  1.1129 | lazy
#  1.1067 | repetitive
#  1.1053 | wannabe
#  1.0744 | slip
#  1.0731 | lame
#  1.0703 | lose
#  1.0672 | generic
#  1.0642 | ultimately
#  1.0628 | sheridan
#  1.0569 | episode
#  1.0556 | idea
#  1.0536 | incoherent
#  1.0498 | problem
#  1.0359 | obvious
#  1.0334 | only
#  1.0284 | contrive
#  1.0280 | load
#  1.0254 | neither
#  1.0216 | choose
#  1.0179 | pointless
#  1.0149 | mistake
#  1.0094 | dreary
#  1.0094 | insult
#  0.9959 | joke
#  0.9926 | less
#  0.9853 | shallow
#  0.9830 | slap
#  0.9716 | poor
#  0.9671 | irritate
#  0.9657 | disguise
#  0.9638 | try
#  0.9634 | clichés
#  0.9600 | seagal
#  0.9462 | n
#  0.9431 | lawrence
#  0.9426 | product
#  0.9399 | quickly
#  0.9345 | queen
#  0.9316 | drown
#  0.9312 | terrible
#  0.9303 | inconsequential
#  0.9296 | pretend
#  0.9286 | inept
#  0.9276 | mediocre
#  0.9259 | suppose
#  0.9237 | sadly
#  0.9209 | over
#  0.9200 | tedious
#  0.9199 | poorly
#  0.9193 | dog
#  0.9146 | remake
#  0.9121 | manipulative
#  0.9098 | disaster
#  0.9077 | formulaic
#  0.9049 | unpleasant
#  0.9042 | ugly
#  0.8957 | depict
#  0.8954 | ago
#  0.8928 | nowhere
#  0.8912 | distasteful
#  0.8909 | stale
#  0.8874 | fool
#  0.8791 | junk
#  0.8788 | hole
#  0.8729 | miss
#  0.8665 | nothing
#  0.8659 | bug
#  0.8614 | plot
#  0.8606 | monster
#  0.8584 | obscure
#  0.8537 | money
#  0.8519 | strain
#  0.8491 | frontal
#  0.8469 | central
#  0.8424 | length
#  0.8413 | suit
#  0.8388 | car
#  0.8377 | comparison
#  0.8376 | ?
#  0.8376 | pity
#  0.8352 | not
#  0.8350 | disappointment
#  0.8295 | house
#  0.8290 | mildly
#  0.8249 | sandler
#  0.8248 | whole
#  0.8245 | reason
#  0.8245 | squander
#  0.8239 | wear
#  0.8185 | off
#  0.8176 | toss
#  0.8170 | harder
#  0.8123 | sluggish
#  0.8103 | horrible
#  0.8087 | college
#  0.8078 | grate
#  0.8074 | unless
#  0.8066 | scatter
#  0.8051 | insight
#  0.8021 | somewhere
#  0.8015 | cold
#  0.7999 | dialogue
#  0.7974 | shapeless
#  0.7881 | exercise
#  0.7856 | wrong
#  0.7850 | reality
#  0.7846 | virtually
#  0.7839 | badly
#  0.7781 | sentiment
#  0.7739 | sink
#  0.7739 | alienation
#  0.7732 | crap
#  0.7729 | elsewhere
#  0.7724 | artificial
#  0.7718 | muddle
#  0.7687 | fall
#  0.7684 | showgirls
#  0.7683 | terribly
#  0.7683 | weak
#  0.7641 | evidence
#  0.7627 | collapse
#  0.7601 | deuces
#  0.7595 | chan
#  0.7581 | ghost
#  0.7568 | pedigree
#  0.7554 | cause
#  0.7524 | bag
#  0.7503 | author
#  0.7498 | resemble
#  0.7495 | vapid
#  0.7467 | name
#  0.7451 | demme
#  0.7433 | doze
#  0.7428 | clumsy
#  0.7428 | apparent
#  0.7421 | copy
#  0.7416 | lackluster
#  0.7413 | uninspired
#  0.7384 | scene
#  0.7353 | night
#  0.7350 | finger
#  0.7324 | advice
#  0.7309 | glum
#  0.7307 | then
#  0.7306 | quest
#  0.7278 | fluffy
#  0.7269 | reputation
#  0.7263 | except
#  0.7229 | figure
#  0.7216 | screenwriter
#  0.7208 | violent
#  0.7181 | loud
#  0.7171 | scream
#  0.7169 | busy
#  0.7162 | com
#  0.7153 | bleak
#  0.7153 | difficult
#  0.7147 | require
#  0.7147 | undercut
#  0.7131 | apparently
#  0.7119 | ramble
#  0.7119 | unimaginative
#  0.7111 | thin
#  0.7103 | awkward
#  0.7102 | humorless
#  0.7063 | vulgar
#  0.7060 | lifeless
#  0.7010 | context
#  0.7004 | drag
#  0.6987 | unconvincing
#  0.6958 | hollow
#  0.6949 | soccer
#  0.6928 | smash
#  0.6906 | unintentionally
#  0.6903 | overwrought
#  0.6893 | indeed
#  0.6891 | plain
#  0.6889 | premise
#  0.6888 | choppy
#  0.6879 | w
#  0.6860 | uninteresting
#  0.6860 | frankly
#  0.6857 | logic
#  0.6855 | as
#  0.6822 | flaccid
#  0.6805 | trite
#  0.6792 | excuse
#  0.6782 | claim
#  0.6767 | novel
#  0.6764 | week
#  0.6755 | preposterous
#  0.6748 | assume
#  0.6718 | numb
#  0.6716 | absurd
#  0.6701 | unnecessary
#  0.6695 | unfocused
#  0.6672 | undo
#  0.6628 | trademark
#  0.6626 | studio
#  0.6624 | retread
#  0.6604 | imagination
#  0.6600 | scarcely
#  0.6597 | like
#  0.6595 | trappings
#  0.6583 | tropes
#  0.6582 | aim
#  0.6581 | fisted
#  0.6580 | to
#  0.6572 | kick
#  0.6545 | seek
#  0.6535 | alabama
#  0.6525 | weight
#  0.6524 | sum
#  0.6522 | undermine
#  0.6515 | hardly
#  0.6514 | charmless
#  0.6507 | obnoxious
#  0.6496 | rehash
#  0.6450 | another
#  0.6447 | warn
#  0.6428 | bust
#  0.6420 | klein
#  0.6405 | puzzle
#  0.6379 | letdown
#  0.6378 | equilibrium
#  0.6373 | disgust
#  0.6368 | attract
#  0.6366 | maudlin
#  0.6360 | offensive
#  0.6359 | green
#  0.6357 | niro
#  0.6356 | rent
#  0.6352 | me
#  0.6344 | fatal
#  0.6343 | opera
#  0.6332 | wallet
#  0.6330 | textbook
#  0.6324 | hip
#  0.6316 | nose
#  0.6307 | gear
#  0.6297 | attempt
#  0.6295 | alienate
#  0.6284 | confuse
#  0.6260 | tank
#  0.6248 | bread
#  0.6237 | relate
#  0.6234 | under
#  0.6224 | demented
#  0.6216 | advertise
#  0.6214 | unintentional
#  0.6211 | absurdity
#  0.6206 | worse
#  0.6193 | crude
#  0.6167 | run
#  0.6160 | grey
#  0.6157 | quarter
#  0.6143 | underlie
#  0.6135 | minutes
#  0.6133 | snow
#  0.6127 | intentionally
#  0.6124 | trifle
#  0.6117 | limp
#  0.6115 | elizabeth
#  0.6111 | sketch
#  0.6090 | crucial
#  0.6085 | nash
#  0.6080 | clockstoppers
#  0.6078 | action
#  0.6060 | plod
#  0.6027 | television
#  0.6018 | equivalent
#  0.6014 | intend
#  0.6007 | t
#  0.5999 | cliché
#  0.5970 | flail
#  0.5964 | ambition
#  0.5958 | lyne
#  0.5957 | amateurish
#  0.5943 | opportunity
#  0.5940 | pile
#  0.5936 | start
#  0.5933 | or
#  0.5923 | screenplay
#  0.5909 | disjoint
#  0.5908 | 50
#  0.5905 | zero
#  0.5894 | text
#  0.5887 | laughable
#  0.5885 | yourself
#  0.5883 | nostalgia
#  0.5879 | predictable
#  0.5878 | jumble
#  0.5875 | replace
#  0.5872 | content
#  0.5870 | clearly
#  0.5868 | someone
#  0.5867 | midway
#  0.5864 | crazy
#  0.5852 | sleep
#  0.5847 | so
#  0.5840 | hastily
#  0.5830 | pie
#  0.5813 | davis
#  0.5796 | impostor
#  0.5790 | swimfan
#  0.5790 | cars
#  0.5781 | stilted
#  0.5780 | banal
#  0.5770 | medical
#  0.5753 | straight
#  0.5740 | resolutely
#  0.5731 | possibility
#  0.5730 | theater
#  0.5728 | promise
#  0.5727 | painfully
#  0.5715 | sacrifice
#  0.5714 | installment
#  0.5697 | pretension
#  0.5685 | bar
#  0.5682 | #
#  0.5667 | sin
#  0.5661 | endeavor
#  0.5656 | superficial
#  0.5642 | adam
#  0.5640 | situation
#  0.5638 | mckay
#  0.5637 | resident
#  0.5636 | print
#  0.5632 | bone
#  0.5624 | excesses
#  0.5618 | sordid
#  0.5606 | unlikable
#  0.5603 | shoddy
#  0.5600 | inexplicable
#  0.5597 | few
#  0.5594 | cripple
#  0.5593 | preachy
#  0.5586 | simplistic
#  0.5581 | solemn
#  0.5579 | mug
#  0.5573 | surely
#  0.5570 | soap
#  0.5547 | feel
#  0.5547 | detach
#  0.5535 | biggest
#  0.5518 | european
#  0.5510 | hurt
#  0.5510 | foolish
#  0.5504 | naipaul
#  0.5499 | soulless
#  0.5497 | forgettable
#  0.5496 | pay
#  0.5493 | appal
#  0.5492 | hackneyed
#  0.5488 | jay
#  0.5485 | misery
#  0.5481 | conventional
#  0.5478 | mature
#  0.5465 | clunky
#  0.5463 | relentless
#  0.5456 | rush
#  0.5455 | false
#  0.5453 | useless
#  0.5447 | obligatory
#  0.5445 | pathetic
#  0.5440 | title
#  0.5439 | relentlessly
#  0.5439 | match
#  0.5426 | animal
#  0.5419 | bury
#  0.5397 | trip
#  0.5388 | ball
#  0.5386 | wind
#  0.5386 | repetition
#  0.5385 | rude
#  0.5378 | loose
#  0.5365 | corny
#  0.5361 | superficiality
#  0.5357 | irrelevant
#  0.5331 | baggage
#  0.5319 | guy
#  0.5316 | rework
#  0.5308 | hartley
#  0.5305 | drivel
#  0.5304 | brain
#  0.5294 | leaden
#  0.5292 | shamelessly
#  0.5276 | explain
#  0.5267 | hospital
#  0.5264 | shoot
#  0.5261 | disposable
#  0.5252 | nonsense
#  0.5242 | become
#  0.5237 | limit
#  0.5233 | blow
#  0.5228 | tragedies
#  0.5223 | annoy
#  0.5216 | execution
#  0.5204 | jar
#  0.5197 | vague
#  0.5176 | dud
#  0.5175 | crush
#  0.5174 | speed
#  0.5172 | grave
#  0.5171 | cliches
#  0.5171 | lust
#  0.5167 | all
#  0.5163 | short
#  0.5155 | earlier
#  0.5144 | clichéd
#  0.5129 | forget
#  0.5123 | -
#  0.5116 | purpose
#  0.5097 | psychology
#  0.5095 | occasional
#  0.5085 | fish
#  0.5081 | country
#  0.5081 | distinctly
#  0.5069 | anemic
#  0.5068 | 40
#  0.5064 | blind
#  0.5054 | suggest
#  0.5050 | total
#  0.5046 | mad
#  0.5046 | cheapen
#  0.5042 | witless
#  0.5022 | heritage
#  0.5011 | really
#  0.5010 | britney
#  0.4998 | absurdist
#  0.4995 | chelsea
#  0.4994 | predictably
#  0.4990 | conceive
#  0.4989 | aspire
#  0.4979 | moment
#  0.4972 | homage
#  0.4968 | deadly
#  0.4956 | critique
#  0.4951 | fluff
#  0.4950 | hours
#  0.4947 | recognize
#  0.4947 | saddle
#  0.4939 | shrill
#  0.4934 | clue
#  0.4933 | fundamentals
#  0.4926 | much
#  0.4917 | little
#  0.4916 | routines
#  0.4916 | stink
#  0.4915 | middle
#  0.4907 | knock
#  0.4906 | curiosity
#  0.4906 | sappy
#  0.4904 | dress
#  0.4899 | delete
#  0.4888 | frustrate
#  0.4887 | whiny
#  0.4885 | theory
#  0.4882 | thing
#  0.4881 | roberts
#  0.4865 | overlong
#  0.4865 | mid
#  0.4864 | silly
#  0.4864 | glorify
#  0.4854 | split
#  0.4850 | oedekerk
#  0.4833 | search
#  0.4822 | easier
#  0.4817 | costner
#  0.4806 | script
#  0.4795 | however
#  0.4792 | intentions
#  0.4781 | anachronistic
#  0.4773 | air
#  0.4771 | arm
#  0.4756 | rowdy
#  0.4753 | equally
#  0.4752 | race
#  0.4748 | appear
#  0.4739 | windtalkers
#  0.4730 | garbage
#  0.4719 | tool
#  0.4718 | unbearably
#  0.4712 | need
#  0.4712 | toward
#  0.4709 | shrewd
#  0.4705 | convenient
#  0.4703 | tattered
#  0.4702 | truck
#  0.4701 | sake
#  0.4694 | mine
#  0.4691 | case
#  0.4684 | tech
#  0.4676 | 30
#  0.4672 | bogus
#  0.4652 | antic
#  0.4649 | consider
#  0.4647 | taylor
#  0.4646 | incoherence
#  0.4636 | cobble
#  0.4634 | sour
#  0.4628 | switch
#  0.4623 | rollerball
#  0.4623 | particular
#  0.4620 | esther
#  0.4618 | viewer
#  0.4596 | accumulate
#  0.4590 | quick
#  0.4580 | tripe
#  0.4579 | hawke
#  0.4576 | trash
#  0.4576 | witch
#  0.4575 | improvise
#  0.4573 | random
#  0.4569 | baffle
#  0.4567 | cheap
#  0.4563 | radical
#  0.4562 | rote
#  0.4560 | suspect
#  0.4559 | number
#  0.4551 | dramatically
#  0.4550 | slapdash
#  0.4547 | fling
#  0.4537 | vehicle
#  0.4528 | witness
#  0.4522 | final
#  0.4509 | helm
#  0.4507 | sara
#  0.4503 | characterization
#  0.4500 | stinker
#  0.4498 | cliche
#  0.4497 | sketchy
#  0.4491 | nor
#  0.4486 | teenagers
#  0.4478 | george
#  0.4474 | nightmare
#  0.4466 | negligible
#  0.4465 | stock
#  0.4464 | sitcom
#  0.4462 | recycle
#  0.4462 | woody
#  0.4461 | ;
#  0.4456 | bunch
#  0.4453 | brand
#  0.4453 | test
#  0.4448 | same
#  0.4445 | transparent
#  0.4444 | completely
#  0.4435 | exit
#  0.4429 | vampire
#  0.4426 | gaghan
#  0.4426 | collateral
#  0.4425 | deprave
#  0.4411 | support
#  0.4408 | wreck
#  0.4405 | major
#  0.4405 | whenever
#  0.4403 | intentioned
#  0.4402 | self
#  0.4401 | tepid
#  0.4397 | hot
#  0.4387 | table
#  0.4384 | ineptly
#  0.4380 | process
#  0.4378 | cherry
#  0.4378 | orchard
#  0.4364 | latter
#  0.4362 | sequel
#  0.4355 | complete
#  0.4355 | surround
#  0.4352 | mire
#  0.4338 | hokum
#  0.4336 | hawaiian
#  0.4328 | scary
#  0.4323 | plympton
#  0.4321 | harvard
#  0.4316 | desperately
#  0.4308 | fewer
#  0.4308 | arbitrary
#  0.4299 | chaotic
#  0.4275 | team
#  0.4275 | snap
#  0.4275 | lucky
#  0.4274 | del
#  0.4269 | state
#  0.4256 | toilet
#  0.4256 | vast
#  0.4256 | contain
#  0.4253 | gap
#  0.4250 | party
#  0.4245 | lucy
#  0.4243 | crime
#  0.4237 | dumb
#  0.4237 | brutally
#  0.4236 | weary
#  0.4234 | league
#  0.4220 | talky
#  0.4219 | mindless
#  0.4217 | where
#  0.4214 | movie
#  0.4205 | despite
#  0.4205 | instantly
#  0.4192 | numbingly
#  0.4192 | 20
#  0.4187 | stop
#  0.4185 | seemingly
#  0.4182 | misfire
#  0.4177 | indulge
#  0.4162 | dishonest
#  0.4158 | underbelly
#  0.4152 | immediately
#  0.4150 | dead
#  0.4148 | necessarily
#  0.4147 | next
#  0.4140 | kapur
#  0.4140 | ford
#  0.4139 | grade
#  0.4138 | buy
#  0.4119 | 8
#  0.4114 | ten
#  0.4113 | things
#  0.4113 | remotely
#  0.4109 | bleed
#  0.4109 | semi
#  0.4109 | meander
#  0.4108 | blatant
#  0.4097 | core
#  0.4093 | emotionally
#  0.4092 | third
#  0.4089 | stiff
#  0.4086 | mystery
#  0.4081 | viewers
#  0.4070 | hard
#  0.4070 | redundant
#  0.4064 | toback
#  0.4057 | seem
#  0.4052 | incomprehensible
#  0.4051 | crossroads
#  0.4049 | any
#  0.4042 | onscreen
#  0.4040 | veer
#  0.4037 | card
#  0.4035 | pass
#  0.4034 | wet
#  0.4031 | own
#  0.4031 | against
#  0.4029 | wan
#  0.4024 | satire
#  0.4023 | payoff
#  0.4021 | water
#  0.4015 | morning
#  0.4011 | close
#  0.4006 | populate
#  0.4005 | personality
#  0.4002 | clean
#  0.4000 | ballistic
#  0.3996 | halloween
#  0.3992 | stomach
#  0.3991 | m
#  0.3983 | monotonous
#  0.3982 | stack
#  0.3970 | pair
#  0.3957 | franchise
#  0.3954 | devolve
#  0.3950 | head
#  0.3947 | phone
#  0.3941 | stereotype
#  0.3940 | every
#  0.3938 | yawn
#  0.3937 | carvey
#  0.3935 | pulse
#  0.3934 | sham
#  0.3925 | essence
#  0.3918 | thrill
#  0.3917 | imagine
#  0.3916 | waterlogged
#  0.3909 | shoulder
#  0.3908 | `
#  0.3906 | clueless
#  0.3906 | mechanical
#  0.3903 | ruin
#  0.3898 | onto
#  0.3895 | wooden
#  0.3895 | amount
#  0.3891 | string
#  0.3881 | tuxedo
#  0.3878 | drain
#  0.3870 | mediocrity
#  0.3869 | buzz
#  0.3866 | attal
#  0.3860 | call
#  0.3856 | impression
#  0.3855 | level
#  0.3842 | smoochy
#  0.3842 | farcical
#  0.3840 | morally
#  0.3840 | graceful
#  0.3836 | ridiculous
#  0.3835 | writers
#  0.3835 | robin
#  0.3831 | typical
#  0.3826 | pileup
#  0.3818 | 1984
#  0.3818 | needlessly
#  0.3813 | hamper
#  0.3803 | manufacture
#  0.3803 | outside
#  0.3798 | invention
#  0.3798 | dahmer
#  0.3796 | rise
#  0.3788 | erotic
#  0.3782 | very
#  0.3781 | brits
#  0.3776 | anything
#  0.3771 | report
#  0.3770 | snip
#  0.3769 | silence
#  0.3769 | ironically
#  0.3766 | hal
#  0.3761 | escape
#  0.3760 | whether
#  0.3759 | indulgent
#  0.3753 | jim
#  0.3751 | r
#  0.3742 | decide
#  0.3738 | seriously
#  0.3737 | chicken
#  0.3735 | itself
#  0.3733 | fragment
#  0.3731 | weigh
#  0.3720 | journalism
#  0.3720 | awkwardly
#  0.3716 | edit
#  0.3715 | denial
#  0.3705 | cinderella
#  0.3701 | secondhand
#  0.3694 | 2002
#  0.3682 | handful
#  0.3682 | women
#  0.3678 | flashbacks
#  0.3676 | plight
#  0.3675 | idiots
#  0.3664 | account
#  0.3662 | celluloid
#  0.3661 | texture
#  0.3658 | similar
#  0.3651 | serve
#  0.3651 | cry
#  0.3650 | tunney
#  0.3644 | conclusion
#  0.3642 | downright
#  0.3634 | ecks
#  0.3634 | sever
#  0.3633 | which
#  0.3632 | imitation
#  0.3628 | inevitable
#  0.3628 | uninvolving
#  0.3625 | unfulfilling
#  0.3622 | people
#  0.3616 | defeat
#  0.3614 | fiction
#  0.3599 | skip
#  0.3597 | stay
#  0.3596 | hat
#  0.3596 | videos
#  0.3593 | blandness
#  0.3590 | teens
#  0.3589 | crimes
#  0.3589 | would
#  0.3587 | admire
#  0.3584 | overcome
#  0.3583 | 22
#  0.3581 | grow
#  0.3580 | invincible
#  0.3579 | taste
#  0.3577 | book
#  0.3577 | ridiculousness
#  0.3575 | julie
#  0.3572 | person
#  0.3566 | behavior
#  0.3565 | moviegoers
#  0.3562 | gooding
#  0.3561 | bomb
#  0.3554 | might
#  0.3554 | rife
#  0.3550 | god
#  0.3550 | static
#  0.3549 | structure
#  0.3538 | idiotic
#  0.3536 | aimlessly
#  0.3535 | sloppy
#  0.3532 | enigma
#  0.3531 | such
#  0.3529 | inexplicably
#  0.3526 | frustratingly
#  0.3509 | charlie
#  0.3505 | wilson
#  0.3502 | exception
#  0.3502 | stretch
#  0.3499 | insultingly
#  0.3497 | signpost
#  0.3497 | artsy
#  0.3496 | bigger
#  0.3493 | opinion
#  0.3483 | predictability
#  0.3480 | spread
#  0.3478 | cynical
#  0.3476 | campus
#  0.3475 | graphic
#  0.3474 | herzog
#  0.3468 | boat
#  0.3465 | melodrama
#  0.3463 | affair
#  0.3462 | definitive
#  0.3450 | horse
#  0.3442 | shadyac
#  0.3441 | genres
#  0.3440 | bottom
#  0.3439 | nasty
#  0.3432 | steve
#  0.3431 | shake
#  0.3431 | ringu
#  0.3430 | routine
#  0.3424 | whatsoever
#  0.3418 | literally
#  0.3417 | walk
#  0.3417 | joyless
#  0.3411 | flimsy
#  0.3408 | seas
#  0.3406 | broad
#  0.3406 | computer
#  0.3400 | calculate
#  0.3398 | tend
#  0.3398 | embarrassment
#  0.3397 | opaque
#  0.3394 | eisenstein
#  0.3393 | limitations
#  0.3385 | milk
#  0.3384 | explosion
#  0.3384 | moronic
#  0.3382 | stifle
#  0.3381 | sorry
#  0.3379 | want
#  0.3375 | induce
#  0.3371 | soggy
#  0.3366 | concert
#  0.3365 | video
#  0.3363 | spark
#  0.3360 | thinly
#  0.3360 | throw
#  0.3359 | avary
#  0.3357 | schneider
#  0.3348 | peculiar
#  0.3348 | lessons
#  0.3348 | after
#  0.3347 | dim
#  0.3346 | find
#  0.3344 | aimless
#  0.3342 | whodunit
#  0.3336 | introduce
#  0.3328 | nonsensical
#  0.3317 | commentary
#  0.3313 | condition
#  0.3312 | tailor
#  0.3309 | properly
#  0.3304 | inoffensive
#  0.3303 | humor
#  0.3303 | lilia
#  0.3302 | immature
#  0.3297 | term
#  0.3296 | repeat
#  0.3296 | importance
#  0.3295 | malaise
#  0.3291 | labor
#  0.3290 | trot
#  0.3278 | believability
#  0.3277 | hitler
#  0.3275 | studios
#  0.3275 | nevertheless
#  0.3274 | import
#  0.3271 | jackass
#  0.3269 | chekhov
#  0.3269 | $
#  0.3268 | accent
#  0.3263 | feminist
#  0.3260 | clumsily
#  0.3259 | infuriate
#  0.3258 | misguide
#  0.3258 | daughters
#  0.3243 | lesson
#  0.3239 | chop
#  0.3236 | 51
#  0.3235 | childlike
#  0.3227 | loosely
#  0.3224 | incongruous
#  0.3223 | gag
#  0.3218 | kung
#  0.3218 | hickenlooper
#  0.3214 | rest
#  0.3213 | emptiness
#  0.3213 | former
#  0.3210 | rescue
#  0.3209 | collection
#  0.3209 | exact
#  0.3206 | tom
#  0.3199 | develop
#  0.3198 | almost
#  0.3197 | invest
#  0.3193 | low
#  0.3187 | beyond
#  0.3177 | vs
#  0.3171 | target
#  0.3170 | sick
#  0.3169 | accuse
#  0.3167 | schmaltz
#  0.3167 | exploitation
#  0.3155 | insipid
#  0.3155 | modernize
#  0.3154 | excruciate
#  0.3150 | simply
#  0.3150 | qualities
#  0.3146 | laughably
#  0.3143 | heavy
#  0.3142 | utter
#  0.3139 | asleep
#  0.3135 | define
#  0.3135 | poo
#  0.3126 | hype
#  0.3125 | independent
#  0.3124 | circuit
#  0.3120 | enterprise
#  0.3120 | sap
#  0.3120 | in
#  0.3116 | disappointingly
#  0.3112 | ship
#  0.3107 | dry
#  0.3106 | fake
#  0.3105 | audacity
#  0.3105 | criticism
#  0.3103 | stories
#  0.3101 | stick
#  0.3098 | reek
#  0.3095 | wake
#  0.3093 | body
#  0.3087 | wish
#  0.3084 | note
#  0.3083 | frame
#  0.3082 | category
#  0.3077 | dv
#  0.3075 | reach
#  0.3073 | pedestrian
#  0.3071 | palma
#  0.3066 | japan
#  0.3064 | responsible
#  0.3064 | peploe
#  0.3058 | desire
#  0.3057 | lead
#  0.3056 | spear
#  0.3055 | lightweight
#  0.3054 | relatively
#  0.3053 | three
#  0.3050 | farrelly
#  0.3044 | shape
#  0.3042 | normally
#  0.3036 | witherspoon
#  0.3035 | budget
#  0.3035 | hokey
#  0.3031 | blood
#  0.3022 | around
#  0.3020 | philosophy
#  0.3016 | miserable
#  0.3015 | chase
#  0.3011 | cloak
#  0.3009 | away
#  0.3002 | cia
#  0.3001 | wertmuller
#  0.2998 | belt
#  0.2987 | merely
#  0.2984 | initial
#  0.2978 | teen
#  0.2974 | eager
#  0.2971 | nights
#  0.2970 | crawl
#  0.2969 | substance
#  0.2967 | glossy
#  0.2967 | pool
#  0.2967 | innovation
#  0.2966 | explosions
#  0.2964 | happen
#  0.2963 | outtakes
#  0.2962 | alter
#  0.2960 | cooper
#  0.2960 | sentence
#  0.2950 | inane
#  0.2944 | deeper
#  0.2943 | kinda
#  0.2940 | skills
#  0.2940 | other
#  0.2938 | exactly
#  0.2937 | ought
#  0.2937 | 11
#  0.2934 | wholly
#  0.2934 | professional
#  0.2929 | feeble
#  0.2928 | crummy
#  0.2927 | slow
#  0.2923 | humble
#  0.2923 | cage
#  0.2920 | anyway
#  0.2920 | stab
#  0.2919 | expression
#  0.2915 | quite
#  0.2912 | gratuitous
#  0.2909 | friday
#  0.2903 | filmmakers
#  0.2901 | merchant
#  0.2900 | think
#  0.2899 | glimpse
#  0.2896 | street
#  0.2893 | expose
#  0.2890 | before
#  0.2889 | echo
#  0.2888 | slim
#  0.2876 | phony
#  0.2874 | distant
#  0.2871 | auto
#  0.2869 | himself
#  0.2868 | prime
#  0.2863 | favor
#  0.2858 | timid
#  0.2858 | secrets
#  0.2857 | incredibly
#  0.2851 | vain
#  0.2849 | beer
#  0.2847 | susan
#  0.2847 | max
#  0.2846 | juvenile
#  0.2846 | refuse
#  0.2846 | unmemorable
#  0.2844 | jr
#  0.2839 | episodes
#  0.2838 | result
#  0.2835 | trek
#  0.2835 | curiously
#  0.2834 | freak
#  0.2832 | do
#  0.2827 | inspiration
#  0.2823 | today
#  0.2815 | barney
#  0.2815 | continuity
#  0.2809 | acceptable
#  0.2806 | write
#  0.2804 | disappoint
#  0.2794 | marquis
#  0.2793 | suck
#  0.2792 | puerile
#  0.2791 | coma
#  0.2790 | dime
#  0.2790 | advantage
#  0.2787 | ritchie
#  0.2784 | between
#  0.2778 | players
#  0.2778 | consciously
#  0.2777 | naturalistic
#  0.2776 | endless
#  0.2767 | directions
#  0.2762 | earn
#  0.2756 | progress
#  0.2755 | below
#  0.2754 | hotel
#  0.2751 | hallmark
#  0.2746 | succumb
#  0.2746 | eastwood
#  0.2744 | wrap
#  0.2743 | intermittently
#  0.2742 | movements
#  0.2740 | streets
#  0.2740 | entire
#  0.2738 | various
#  0.2725 | shame
#  0.2725 | traveler
#  0.2723 | screenwriters
#  0.2715 | plotless
#  0.2710 | five
#  0.2710 | inconsistent
#  0.2709 | here
#  0.2705 | scenes
#  0.2704 | plumb
#  0.2704 | either
#  0.2703 | gain
#  0.2702 | factor
#  0.2702 | exposition
#  0.2699 | boy
#  0.2693 | fiennes
#  0.2688 | hack
#  0.2686 | dragonfly
#  0.2682 | ararat
#  0.2679 | satirical
#  0.2679 | attack
#  0.2676 | star
#  0.2672 | choices
#  0.2671 | sleeve
#  0.2666 | deniro
#  0.2665 | denis
#  0.2659 | blair
#  0.2658 | depression
#  0.2657 | animation
#  0.2655 | disintegrate
#  0.2655 | yu
#  0.2651 | elements
#  0.2650 | rrb
#  0.2650 | propaganda
#  0.2647 | contrast
#  0.2646 | older
#  0.2637 | brio
#  0.2635 | stumble
#  0.2631 | probably
#  0.2628 | owe
#  0.2626 | sit
#  0.2626 | generation
#  0.2624 | come
#  0.2624 | pseudo
#  0.2623 | kill
#  0.2622 | elaborate
#  0.2619 | just
#  0.2619 | 100
#  0.2617 | sermon
#  0.2615 | sweetest
#  0.2609 | die
#  0.2604 | stereotypical
#  0.2601 | her
#  0.2598 | tone
#  0.2594 | decidedly
#  0.2584 | catholic
#  0.2579 | passion
#  0.2579 | historical
#  0.2575 | coherent
#  0.2575 | gun
#  0.2566 | procession
#  0.2565 | emphasis
#  0.2560 | damage
#  0.2557 | d
#  0.2555 | iwai
#  0.2545 | prefer
#  0.2541 | theatrical
#  0.2537 | review
#  0.2536 | laudable
#  0.2529 | guilty
#  0.2529 | van
#  0.2524 | overly
#  0.2523 | cox
#  0.2521 | hand
#  0.2515 | charisma
#  0.2510 | heights
#  0.2500 | woo
#  0.2497 | on
#  0.2494 | inherent
#  0.2492 | lapse
#  0.2487 | australian
#  0.2484 | rice
#  0.2483 | during
#  0.2481 | slo
#  0.2481 | mo
#  0.2481 | unsympathetic
#  0.2479 | extra
#  0.2478 | turgid
#  0.2476 | feardotcom
#  0.2475 | mummy
#  0.2472 | dig
#  0.2469 | explode
#  0.2465 | generate
#  0.2465 | cow
#  0.2457 | accompany
#  0.2455 | price
#  0.2451 | athletes
#  0.2445 | dub
#  0.2439 | smack
#  0.2436 | tree
#  0.2435 | florid
#  0.2430 | significant
#  0.2430 | regard
#  0.2427 | histrionics
#  0.2426 | supposedly
#  0.2422 | indulgence
#  0.2421 | graceless
#  0.2421 | dvd
#  0.2421 | buddy
#  0.2416 | bear
#  0.2408 | grab
#  0.2399 | terrorism
#  0.2398 | pale
#  0.2396 | territory
#  0.2396 | release
#  0.2394 | shoe
#  0.2392 | prevent
#  0.2389 | infomercial
#  0.2389 | produce
#  0.2389 | philip
#  0.2387 | connect
#  0.2382 | nobody
#  0.2381 | deal
#  0.2368 | magical
#  0.2368 | competent
#  0.2365 | jell
#  0.2358 | fizz
#  0.2355 | strongly
#  0.2354 | postcard
#  0.2349 | pose
#  0.2343 | prep
#  0.2340 | 60
#  0.2338 | formula
#  0.2337 | hate
#  0.2326 | rerun
#  0.2325 | construction
#  0.2321 | nelson
#  0.2316 | foul
#  0.2316 | psychological
#  0.2316 | election
#  0.2312 | swing
#  0.2309 | nearly
#  0.2307 | redeem
#  0.2298 | southern
#  0.2297 | problematic
#  0.2295 | tediously
#  0.2291 | inescapable
#  0.2287 | lilo
#  0.2285 | pyrotechnics
#  0.2284 | makeup
#  0.2281 | rumor
#  0.2279 | familiarity
#  0.2278 | down
#  0.2276 | pain
#  0.2276 | jackie
#  0.2275 | exploitive
#  0.2275 | angels
#  0.2271 | ambiguous
#  0.2270 | o
#  0.2268 | horror
#  0.2265 | everyone
#  0.2265 | remove
#  0.2265 | pryor
#  0.2265 | duck
#  0.2264 | 86
#  0.2263 | extreme
#  0.2262 | degree
#  0.2252 | woefully
#  0.2249 | screenwriting
#  0.2248 | cutesy
#  0.2246 | concentrate
#  0.2245 | murky
#  0.2243 | direction
#  0.2240 | assault
#  0.2240 | spy
#  0.2239 | festival
#  0.2236 | devote
#  0.2234 | store
#  0.2228 | half
#  0.2226 | farce
#  0.2225 | mtv
#  0.2217 | intent
#  0.2217 | bare
#  0.2209 | frustration
#  0.2208 | shelf
#  0.2205 | hundred
#  0.2199 | desperate
#  0.2192 | absolute
#  0.2185 | past
#  0.2181 | anti
#  0.2180 | freddy
#  0.2179 | lrb
#  0.2170 | gender
#  0.2165 | until
#  0.2165 | label
#  0.2164 | vibe
#  0.2160 | allegory
#  0.2160 | piano
#  0.2160 | exploit
#  0.2159 | friend
#  0.2156 | arc
#  0.2143 | dreck
#  0.2135 | crash
#  0.2134 | suffocate
#  0.2134 | combination
#  0.2132 | area
#  0.2130 | involve
#  0.2126 | nary
#  0.2125 | sade
#  0.2119 | creation
#  0.2119 | stronger
#  0.2117 | source
#  0.2115 | ultra
#  0.2108 | parody
#  0.2107 | madonna
#  0.2107 | sign
#  0.2106 | lowbrow
#  0.2105 | observation
#  0.2105 | voice
#  0.2104 | pluck
#  0.2103 | '
#  0.2102 | dramatic
#  0.2102 | some
#  0.2101 | wall
#  0.2101 | alfred
#  0.2101 | hitchcock
#  0.2101 | save
#  0.2099 | bizarre
#  0.2097 | animatronic
#  0.2087 | rattle
#  0.2081 | cable
#  0.2081 | leaven
#  0.2079 | mainly
#  0.2077 | niche
#  0.2073 | camouflage
#  0.2072 | argentine
#  0.2067 | regret
#  0.2064 | destination
#  0.2064 | thematic
#  0.2063 | impersonal
#  0.2062 | muse
#  0.2055 | pastiche
#  0.2055 | hide
#  0.2054 | practically
#  0.2046 | dose
#  0.2043 | somehow
#  0.2041 | weird
#  0.2038 | visible
#  0.2036 | for
#  0.2033 | teeth
#  0.2028 | 4ever
#  0.2025 | 4
#  0.2018 | romanek
#  0.2018 | barrel
#  0.2017 | scorpion
#  0.2015 | squarely
#  0.2013 | segment
#  0.2004 | efforts
#  0.1991 | massive
#  0.1984 | tread
#  0.1977 | everlasting
#  0.1973 | conventions
#  0.1972 | hawk
#  0.1970 | kind
#  0.1970 | unleash
#  0.1967 | classic
#  0.1967 | word
#  0.1966 | social
#  0.1964 | ordinary
#  0.1963 | coal
#  0.1959 | refer
#  0.1952 | occasionally
#  0.1948 | sessions
#  0.1945 | station
#  0.1943 | promisingly
#  0.1938 | painful
#  0.1937 | merit
#  0.1936 | season
#  0.1934 | pat
#  0.1929 | player
#  0.1929 | science
#  0.1928 | ensure
#  0.1926 | slack
#  0.1926 | angry
#  0.1925 | perverse
#  0.1925 | channel
#  0.1924 | storylines
#  0.1922 | set
#  0.1920 | shockingly
#  0.1919 | object
#  0.1919 | willingness
#  0.1915 | more
#  0.1914 | burr
#  0.1914 | psyche
#  0.1914 | halfway
#  0.1913 | path
#  0.1912 | alternate
#  0.1901 | mild
#  0.1900 | greatest
#  0.1899 | through
#  0.1897 | king
#  0.1897 | sub
#  0.1895 | aspirations
#  0.1890 | chuckle
#  0.1890 | sandra
#  0.1890 | roberto
#  0.1887 | latest
#  0.1885 | flame
#  0.1881 | behave
#  0.1879 | kevin
#  0.1877 | prison
#  0.1874 | nature
#  0.1872 | gravity
#  0.1870 | inspire
#  0.1870 | hammer
#  0.1867 | have
#  0.1867 | impenetrable
#  0.1865 | expert
#  0.1861 | shift
#  0.1860 | suspend
#  0.1857 | clothe
#  0.1850 | triangle
#  0.1850 | pulp
#  0.1850 | town
#  0.1849 | tense
#  0.1846 | mill
#  0.1845 | bow
#  0.1844 | fifteen
#  0.1844 | pg
#  0.1843 | severe
#  0.1843 | join
#  0.1842 | by
#  0.1838 | uneventful
#  0.1835 | emphasize
#  0.1831 | paper
#  0.1830 | perhaps
#  0.1827 | rocky
#  0.1825 | riddle
#  0.1824 | shafer
#  0.1822 | how
#  0.1821 | opportunities
#  0.1816 | focus
#  0.1812 | botch
#  0.1806 | dip
#  0.1805 | brian
#  0.1805 | dish
#  0.1801 | impossible
#  0.1801 | slam
#  0.1800 | even
#  0.1793 | clash
#  0.1788 | international
#  0.1787 | remember
#  0.1785 | sonny
#  0.1784 | schwarzenegger
#  0.1779 | without
#  0.1778 | passages
#  0.1775 | alone
#  0.1764 | sweep
#  0.1755 | smug
#  0.1755 | language
#  0.1754 | fear
#  0.1754 | project
#  0.1753 | control
#  0.1751 | wacky
#  0.1741 | eyre
#  0.1741 | victims
#  0.1740 | rap
#  0.1738 | stagger
#  0.1731 | pad
#  0.1730 | him
#  0.1729 | sound
#  0.1724 | poke
#  0.1717 | litter
#  0.1713 | universe
#  0.1705 | rather
#  0.1703 | strictly
#  0.1702 | yellow
#  0.1701 | whom
#  0.1699 | achieve
#  0.1696 | better
#  0.1694 | future
#  0.1687 | theaters
#  0.1685 | consciousness
#  0.1683 | translation
#  0.1680 | hungry
#  0.1677 | admit
#  0.1677 | fade
#  0.1673 | 19th
#  0.1672 | saccharine
#  0.1670 | lurid
#  0.1667 | approach
#  0.1666 | lan
#  0.1663 | current
#  0.1658 | expectations
#  0.1657 | howard
#  0.1654 | fire
#  0.1653 | play
#  0.1648 | first
#  0.1647 | fincher
#  0.1645 | dubious
#  0.1644 | shower
#  0.1641 | benigni
#  0.1641 | humanly
#  0.1639 | mary
#  0.1638 | ...
#  0.1638 | amid
#  0.1631 | joel
#  0.1631 | old
#  0.1631 | laugh
#  0.1631 | schmaltzy
#  0.1617 | uneasy
#  0.1617 | tart
#  0.1615 | driver
#  0.1613 | paradiso
#  0.1612 | urge
#  0.1612 | thirty
#  0.1608 | longest
#  0.1604 | sustain
#  0.1603 | foot
#  0.1603 | adams
#  0.1596 | unassuming
#  0.1591 | dimension
#  0.1589 | costume
#  0.1589 | cross
#  0.1579 | koepp
#  0.1578 | younger
#  0.1577 | destroy
#  0.1577 | ethnic
#  0.1570 | ice
#  0.1568 | pow
#  0.1568 | somebody
#  0.1567 | adequate
#  0.1566 | fumble
#  0.1565 | childhood
#  0.1564 | myself
#  0.1562 | strangers
#  0.1559 | common
#  0.1558 | material
#  0.1556 | heroes
#  0.1550 | issue
#  0.1548 | he
#  0.1547 | whatever
#  0.1542 | remote
#  0.1535 | talents
#  0.1532 | church
#  0.1532 | mean
#  0.1531 | cohesive
#  0.1528 | winner
#  0.1528 | exalt
#  0.1528 | critics
#  0.1526 | memory
#  0.1523 | pic
#  0.1523 | guarantee
#  0.1522 | oleander
#  0.1522 | crass
#  0.1519 | observe
#  0.1515 | rule
#  0.1514 | tight
#  0.1512 | conflict
#  0.1511 | boot
#  0.1509 | crocodile
#  0.1500 | vaguely
#  0.1498 | dysfunctional
#  0.1496 | sorority
#  0.1495 | unfaithful
#  0.1495 | motion
#  0.1495 | depths
#  0.1483 | network
#  0.1482 | insights
#  0.1480 | raunchy
#  0.1473 | cgi
#  0.1472 | primitive
#  0.1470 | west
#  0.1464 | fixate
#  0.1464 | consequences
#  0.1462 | horribly
#  0.1460 | mayhem
#  0.1456 | raise
#  0.1455 | intolerable
#  0.1450 | hopelessly
#  0.1446 | feet
#  0.1445 | cliched
#  0.1441 | cannes
#  0.1437 | goldmember
#  0.1435 | rain
#  0.1434 | anyone
#  0.1433 | plan
#  0.1432 | sometimes
#  0.1425 | technically
#  0.1422 | k
#  0.1421 | stomp
#  0.1419 | cartoonish
#  0.1416 | underscore
#  0.1415 | simultaneously
#  0.1414 | police
#  0.1413 | maker
#  0.1412 | magic
#  0.1400 | pervasive
#  0.1397 | guess
#  0.1391 | atmosphere
#  0.1390 | hideously
#  0.1389 | humour
#  0.1389 | performers
#  0.1384 | closely
#  0.1382 | ah
#  0.1381 | lunacy
#  0.1380 | audiences
#  0.1378 | casual
#  0.1377 | instincts
#  0.1377 | boil
#  0.1375 | marine
#  0.1371 | heavily
#  0.1369 | absurdities
#  0.1367 | genius
#  0.1366 | château
#  0.1366 | them
#  0.1366 | retell
#  0.1365 | earnestness
#  0.1365 | deepest
#  0.1362 | anywhere
#  0.1360 | wildly
#  0.1359 | scenic
#  0.1359 | glory
#  0.1358 | corner
#  0.1357 | care
#  0.1355 | existence
#  0.1350 | cost
#  0.1350 | pre
#  0.1348 | praise
#  0.1343 | creativity
#  0.1340 | soldier
#  0.1340 | footage
#  0.1337 | meet
#  0.1335 | critical
#  0.1333 | version
#  0.1333 | british
#  0.1332 | revelations
#  0.1331 | chateau
#  0.1329 | biography
#  0.1327 | talented
#  0.1322 | liar
#  0.1321 | comment
#  0.1320 | sabotage
#  0.1294 | venture
#  0.1285 | bluster
#  0.1284 | necessary
#  0.1282 | wattage
#  0.1277 | losers
#  0.1276 | bog
#  0.1274 | incompetent
#  0.1273 | ms
#  0.1272 | observations
#  0.1265 | subtlety
#  0.1265 | thousand
#  0.1264 | frank
#  0.1264 | border
#  0.1261 | feather
#  0.1261 | essentially
#  0.1259 | motivate
#  0.1256 | characteristic
#  0.1251 | aggressively
#  0.1245 | misogyny
#  0.1242 | sophomoric
#  0.1240 | obviously
#  0.1235 | indifference
#  0.1235 | point
#  0.1234 | genial
#  0.1231 | swallow
#  0.1228 | lower
#  0.1228 | heroine
#  0.1226 | open
#  0.1225 | scherfig
#  0.1225 | hoffman
#  0.1224 | order
#  0.1218 | redemption
#  0.1215 | droll
#  0.1204 | million
#  0.1204 | domestic
#  0.1202 | guide
#  0.1202 | undead
#  0.1200 | mend
#  0.1199 | pinocchio
#  0.1197 | virtues
#  0.1197 | build
#  0.1196 | girls
#  0.1195 | distract
#  0.1193 | understand
#  0.1193 | borrow
#  0.1193 | drink
#  0.1191 | tolerance
#  0.1189 | infidelity
#  0.1186 | verge
#  0.1186 | soundtrack
#  0.1185 | stone
#  0.1185 | fat
#  0.1174 | aid
#  0.1172 | hour
#  0.1169 | aesthetic
#  0.1167 | yard
#  0.1167 | similarly
#  0.1164 | disturb
#  0.1164 | relative
#  0.1160 | interest
#  0.1160 | far
#  0.1159 | lump
#  0.1159 | influence
#  0.1156 | walsh
#  0.1155 | eric
#  0.1148 | preach
#  0.1146 | sundance
#  0.1143 | abstract
#  0.1140 | astonishingly
#  0.1140 | freaky
#  0.1131 | upon
#  0.1129 | cyber
#  0.1129 | spring
#  0.1128 | bright
#  0.1125 | ignite
#  0.1123 | thematically
#  0.1118 | macdowell
#  0.1115 | market
#  0.1112 | complications
#  0.1111 | attention
#  0.1108 | believe
#  0.1108 | derive
#  0.1105 | mundane
#  0.1102 | madness
#  0.1093 | line
#  0.1092 | douglas
#  0.1088 | overall
#  0.1087 | vignettes
#  0.1085 | second
#  0.1081 | jack
#  0.1081 | traffic
#  0.1078 | evident
#  0.1074 | hero
#  0.1073 | kitchen
#  0.1070 | male
#  0.1065 | melodramatic
#  0.1065 | counter
#  0.1065 | machismo
#  0.1065 | character
#  0.1062 | natural
#  0.1057 | possibly
#  0.1055 | aspect
#  0.1048 | mattei
#  0.1046 | narcissism
#  0.1046 | classical
#  0.1040 | wallace
#  0.1038 | inhabit
#  0.1033 | jordan
#  0.1028 | intellectual
#  0.1027 | victim
#  0.1024 | realize
#  0.1024 | chicago
#  0.1023 | kissinger
#  0.1021 | of
#  0.1013 | prove
#  0.1013 | musicians
#  0.1013 | replete
#  0.1011 | brisk
#  0.1008 | luck
#  0.1008 | ludicrous
#  0.1004 | partly
#  0.1004 | evans
#  0.1002 | commercial
#  0.1002 | bike
#  0.0997 | overtly
#  0.0993 | romance
#  0.0991 | rip
#  0.0988 | elicit
#  0.0980 | newcomer
#  0.0979 | fact
#  0.0979 | park
#  0.0975 | scruffy
#  0.0975 | tarantino
#  0.0970 | threat
#  0.0966 | actresses
#  0.0966 | raunch
#  0.0961 | hewitt
#  0.0960 | el
#  0.0959 | irish
#  0.0958 | cartoon
#  0.0958 | mountain
#  0.0956 | eight
#  0.0955 | album
#  0.0955 | apart
#  0.0953 | jump
#  0.0952 | accurate
#  0.0950 | opt
#  0.0949 | 88
#  0.0948 | student
#  0.0942 | 10
#  0.0941 | long
#  0.0940 | bother
#  0.0940 | \*
#  0.0930 | particularly
#  0.0923 | emotions
#  0.0922 | rhetoric
#  0.0921 | 9
#  0.0917 | foibles
#  0.0916 | pick
#  0.0916 | fine
#  0.0913 | repellent
#  0.0912 | lavish
#  0.0909 | unoriginal
#  0.0908 | russell
#  0.0906 | flesh
#  0.0904 | stephen
#  0.0901 | consolation
#  0.0900 | emotional
#  0.0899 | prophecies
#  0.0891 | sequence
#  0.0890 | americans
#  0.0886 | curious
#  0.0884 | grasp
#  0.0882 | summertime
#  0.0878 | machine
#  0.0874 | main
#  0.0873 | bump
#  0.0871 | leave
#  0.0864 | ensue
#  0.0862 | plotline
#  0.0861 | previous
#  0.0857 | meticulously
#  0.0856 | awfully
#  0.0852 | otherwise
#  0.0851 | wilde
#  0.0850 | advance
#  0.0850 | dong
#  0.0848 | reject
#  0.0844 | sudden
#  0.0842 | sleeper
#  0.0841 | ponderous
#  0.0841 | business
#  0.0838 | humanize
#  0.0831 | wollter
#  0.0830 | maintain
#  0.0827 | six
#  0.0825 | equal
#  0.0824 | disney
#  0.0819 | screwball
#  0.0818 | compose
#  0.0813 | manipulation
#  0.0812 | crane
#  0.0810 | cut
#  0.0807 | leather
#  0.0807 | zombie
#  0.0806 | near
#  0.0806 | xxx
#  0.0801 | re
#  0.0801 | out
#  0.0798 | this
#  0.0786 | goose
#  0.0783 | arrive
#  0.0773 | cumulative
#  0.0770 | ultimate
#  0.0769 | put
#  0.0764 | selection
#  0.0762 | nifty
#  0.0760 | everything
#  0.0759 | unite
#  0.0754 | characterizations
#  0.0751 | piccoli
#  0.0751 | there
#  0.0749 | series
#  0.0748 | suburban
#  0.0746 | squeeze
#  0.0742 | shorter
#  0.0740 | hook
#  0.0737 | meal
#  0.0735 | repeatedly
#  0.0735 | eerily
#  0.0735 | beg
#  0.0734 | arty
#  0.0731 | pepper
#  0.0730 | dullest
#  0.0730 | evil
#  0.0727 | alas
#  0.0724 | remain
#  0.0717 | question
#  0.0713 | inside
#  0.0711 | manners
#  0.0706 | allusions
#  0.0701 | rely
#  0.0700 | horrors
#  0.0699 | twice
#  0.0698 | topic
#  0.0696 | glare
#  0.0694 | valiantly
#  0.0692 | loss
#  0.0692 | airless
#  0.0691 | roman
#  0.0691 | strand
#  0.0689 | rah
#  0.0688 | 3
#  0.0687 | shakespeare
#  0.0687 | behind
#  0.0686 | mix
#  0.0682 | brit
#  0.0681 | slick
#  0.0677 | cautionary
#  0.0677 | shadowy
#  0.0676 | manner
#  0.0672 | pathos
#  0.0671 | rough
#  0.0670 | scooby
#  0.0668 | could
#  0.0668 | talent
#  0.0663 | reference
#  0.0662 | nettelbeck
#  0.0661 | learn
#  0.0656 | resonance
#  0.0653 | conscious
#  0.0651 | adage
#  0.0648 | turn
#  0.0646 | hawn
#  0.0644 | youth
#  0.0641 | credibility
#  0.0641 | mouth
#  0.0638 | splash
#  0.0634 | photo
#  0.0632 | dimensional
#  0.0628 | everybody
#  0.0625 | rewrite
#  0.0625 | row
#  0.0623 | portray
#  0.0622 | henry
#  0.0617 | gore
#  0.0610 | grind
#  0.0604 | eddie
#  0.0602 | contest
#  0.0600 | carpenter
#  0.0599 | ve
#  0.0598 | tout
#  0.0595 | befuddle
#  0.0591 | lecture
#  0.0591 | comprehension
#  0.0589 | payami
#  0.0588 | stevens
#  0.0586 | iii
#  0.0583 | positively
#  0.0582 | sci
#  0.0582 | fi
#  0.0582 | indictment
#  0.0576 | further
#  0.0567 | shots
#  0.0566 | hill
#  0.0565 | agent
#  0.0561 | tuck
#  0.0561 | cynicism
#  0.0557 | quirk
#  0.0550 | brilliance
#  0.0548 | abandon
#  0.0547 | avoid
#  0.0547 | actress
#  0.0543 | program
#  0.0542 | solaris
#  0.0541 | apted
#  0.0540 | innuendo
#  0.0530 | cheat
#  0.0527 | directorial
#  0.0526 | surf
#  0.0521 | notion
#  0.0517 | haneke
#  0.0512 | proportion
#  0.0512 | satisfactory
#  0.0510 | incorporate
#  0.0508 | window
#  0.0508 | cheesy
#  0.0507 | twenty
#  0.0504 | train
#  0.0501 | actual
#  0.0500 | silliness
#  0.0499 | sentimentality
#  0.0498 | pearl
#  0.0494 | upbeat
#  0.0494 | unbearable
#  0.0491 | address
#  0.0489 | vanity
#  0.0488 | witted
#  0.0487 | least
#  0.0486 | single
#  0.0484 | information
#  0.0482 | conjure
#  0.0472 | diane
#  0.0471 | autobiographical
#  0.0466 | hanks
#  0.0462 | media
#  0.0458 | anthony
#  0.0458 | chew
#  0.0453 | mannered
#  0.0446 | largely
#  0.0437 | dot
#  0.0436 | solutions
#  0.0432 | noise
#  0.0431 | message
#  0.0429 | design
#  0.0429 | burn
#  0.0429 | condense
#  0.0428 | catch
#  0.0427 | wave
#  0.0427 | molly
#  0.0425 | siegel
#  0.0424 | thoroughly
#  0.0422 | awareness
#  0.0420 | wisdom
#  0.0420 | philosophical
#  0.0415 | grandeur
#  0.0414 | spin
#  0.0411 | risk
#  0.0411 | messy
#  0.0408 | randall
#  0.0407 | terminally
#  0.0404 | cover
#  0.0403 | devastate
#  0.0402 | audacious
#  0.0401 | sell
#  0.0399 | bielinsky
#  0.0398 | santa
#  0.0395 | impressions
#  0.0395 | stitch
#  0.0394 | lush
#  0.0394 | able
#  0.0391 | hang
#  0.0391 | american
#  0.0387 | swear
#  0.0385 | generally
#  0.0384 | collision
#  0.0383 | j
#  0.0382 | narratively
#  0.0382 | margarita
#  0.0382 | u
#  0.0378 | last
#  0.0377 | contradictory
#  0.0376 | perform
#  0.0375 | monty
#  0.0374 | describe
#  0.0374 | fourth
#  0.0372 | monsters
#  0.0368 | display
#  0.0368 | kim
#  0.0365 | ready
#  0.0359 | development
#  0.0355 | events
#  0.0354 | predecessors
#  0.0352 | verve
#  0.0351 | 101
#  0.0350 | sympathy
#  0.0349 | ourselves
#  0.0339 | basic
#  0.0335 | break
#  0.0332 | jagger
#  0.0332 | uncomfortable
#  0.0325 | runner
#  0.0319 | lopez
#  0.0314 | zealand
#  0.0309 | pit
#  0.0309 | insecure
#  0.0308 | profane
#  0.0307 | ripe
#  0.0305 | darker
#  0.0297 | indians
#  0.0291 | excite
#  0.0290 | potentially
#  0.0290 | ears
#  0.0288 | lark
#  0.0287 | sense
#  0.0284 | environmental
#  0.0282 | caper
#  0.0281 | sisterhood
#  0.0281 | handsome
#  0.0278 | vampires
#  0.0278 | exceptionally
#  0.0278 | gay
#  0.0276 | coppola
#  0.0275 | swim
#  0.0274 | esque
#  0.0272 | humans
#  0.0272 | should
#  0.0263 | anybody
#  0.0263 | flashy
#  0.0263 | dreadful
#  0.0262 | connection
#  0.0256 | watch
#  0.0254 | artifice
#  0.0253 | cleverly
#  0.0251 | mothman
#  0.0248 | death
#  0.0248 | marry
#  0.0244 | narrator
#  0.0243 | chou
#  0.0241 | marvelous
#  0.0241 | audience
#  0.0238 | academy
#  0.0238 | ooze
#  0.0237 | friends
#  0.0232 | calm
#  0.0231 | tambor
#  0.0228 | ichi
#  0.0228 | classify
#  0.0224 | bale
#  0.0224 | your
#  0.0223 | dozen
#  0.0221 | menace
#  0.0220 | appropriate
#  0.0215 | offend
#  0.0215 | dopey
#  0.0214 | dangerous
#  0.0203 | warfare
#  0.0189 | themselves
#  0.0189 | ralph
#  0.0188 | jennifer
#  0.0186 | fearless
#  0.0183 | dean
#  0.0183 | brash
#  0.0181 | rocket
#  0.0179 | elling
#  0.0177 | bio
#  0.0176 | drum
#  0.0174 | scheme
#  0.0172 | killer
#  0.0170 | entirely
#  0.0168 | sinister
#  0.0167 | fabric
#  0.0166 | trouble
#  0.0164 | artistry
#  0.0163 | irony
#  0.0163 | circus
#  0.0160 | outsiders
#  0.0157 | entry
#  0.0156 | innocent
#  0.0155 | sensibilities
#  0.0153 | <pad>
#  0.0153 | <unk>
#  0.0151 | astute
#  0.0147 | enter
#  0.0142 | attractive
#  0.0139 | substitute
#  0.0138 | psychopathic
#  0.0136 | retool
#  0.0135 | she
#  0.0134 | earth
#  0.0134 | exaggerate
#  0.0129 | auteur
#  0.0127 | wander
#  0.0124 | presentation
#  0.0124 | credible
#  0.0123 | matter
#  0.0121 | harris
#  0.0120 | father
#  0.0119 | jerry
#  0.0116 | palestinian
#  0.0115 | pratfalls
#  0.0114 | map
#  0.0113 | hyper
#  0.0109 | kline
#  0.0108 | legacy
#  0.0108 | satin
#  0.0108 | subplots
#  0.0107 | personal
#  0.0106 | technical
#  0.0106 | afternoon
#  0.0105 | distance
#  0.0103 | historically
#  0.0101 | macabre
#  0.0097 | brother
#  0.0095 | awaken
#  0.0093 | admirably
#  0.0090 | pretensions
#  0.0089 | con
#  0.0088 | blank
#  0.0084 | atlantic
#  0.0083 | sensuality
#  0.0077 | thumb
#  0.0075 | compare
#  0.0073 | epic
#  0.0073 | act
#  0.0072 | glass
#  0.0067 | imaginative
#  0.0061 | flash
#  0.0059 | highest
#  0.0052 | gondry
#  0.0052 | cruel
#  0.0047 | admittedly
#  0.0047 | consistent
#  0.0044 | q
#  0.0036 | frida
#  0.0034 | actor
#  0.0033 | raymond
#  0.0032 | hopkins
#  0.0027 | african
#  0.0022 | lodge
#  0.0019 | technique
#  0.0014 | upper
#  0.0012 | legged
#  0.0004 | --
#  0.0002 | sane
#  0.0000 | narrative
# -0.0000 | stage
# -0.0003 | bake
# -0.0004 | handle
# -0.0008 | hunter
# -0.0018 | mcgrath
# -0.0021 | productions
# -0.0025 | belly
# -0.0025 | obsession
# -0.0027 | blame
# -0.0028 | finale
# -0.0028 | about
# -0.0037 | south
# -0.0038 | employ
# -0.0038 | sequels
# -0.0041 | reduce
# -0.0043 | spontaneity
# -0.0043 | clear
# -0.0048 | sentimental
# -0.0050 | combat
# -0.0051 | post
# -0.0053 | again
# -0.0056 | represent
# -0.0058 | sure
# -0.0061 | degrade
# -0.0062 | phrase
# -0.0064 | amy
# -0.0069 | ''
# -0.0070 | improvisation
# -0.0074 | sons
# -0.0076 | infantile
# -0.0078 | par
# -0.0079 | porn
# -0.0082 | monsoon
# -0.0083 | boldly
# -0.0085 | falter
# -0.0088 | blaxploitation
# -0.0089 | comfort
# -0.0094 | .
# -0.0094 | lifestyle
# -0.0094 | definition
# -0.0094 | sentimentalize
# -0.0096 | somber
# -0.0098 | weighty
# -0.0099 | begin
# -0.0100 | dumbed
# -0.0103 | bitter
# -0.0106 | general
# -0.0107 | characterize
# -0.0109 | cherish
# -0.0112 | sag
# -0.0112 | aloof
# -0.0113 | fairy
# -0.0116 | pink
# -0.0117 | sanctimony
# -0.0120 | showcase
# -0.0121 | school
# -0.0124 | endure
# -0.0126 | shout
# -0.0129 | cletis
# -0.0135 | top
# -0.0136 | arts
# -0.0138 | perceptive
# -0.0138 | bigelow
# -0.0139 | burger
# -0.0139 | edgy
# -0.0140 | lion
# -0.0144 | darkness
# -0.0145 | icon
# -0.0146 | period
# -0.0147 | reflection
# -0.0148 | filmmaker
# -0.0149 | grisly
# -0.0149 | kiddie
# -0.0156 | theatre
# -0.0158 | bollywood
# -0.0158 | lyrical
# -0.0158 | apply
# -0.0163 | pack
# -0.0163 | plague
# -0.0170 | staggeringly
# -0.0172 | sight
# -0.0174 | accident
# -0.0178 | colour
# -0.0179 | noyce
# -0.0181 | destruction
# -0.0187 | fault
# -0.0188 | danny
# -0.0189 | chick
# -0.0190 | look
# -0.0190 | survival
# -0.0194 | terrify
# -0.0196 | compassion
# -0.0198 | communicate
# -0.0199 | ask
# -0.0206 | signal
# -0.0206 | seat
# -0.0207 | adventure
# -0.0208 | ticket
# -0.0209 | music
# -0.0211 | non
# -0.0213 | controversy
# -0.0213 | quasi
# -0.0217 | evelyn
# -0.0217 | cloy
# -0.0222 | downward
# -0.4710 | bank
# -0.4710 | job
# -0.4714 | lay
# -0.4716 | ballot
# -0.4716 | chamber
# -0.4716 | sear
# -0.4718 | warmth
# -0.4719 | proud
# -0.4721 | challenge
# -0.4722 | fantastic
# -0.4724 | struggle
# -0.4727 | gory
# -0.4728 | undeniable
# -0.4730 | hilarity
# -0.4732 | literate
# -0.4732 | barbershop
# -0.4742 | souls
# -0.4746 | 60s
# -0.4758 | forceful
# -0.4759 | kosminsky
# -0.4768 | motivations
# -0.4772 | whose
# -0.4782 | individual
# -0.4784 | full
# -0.4785 | spell
# -0.4794 | marvel
# -0.4797 | contrivances
# -0.4801 | delicious
# -0.4801 | korea
# -0.4803 | smartly
# -0.4809 | greatness
# -0.4810 | theme
# -0.4814 | storyline
# -0.4814 | mamet
# -0.4818 | unusual
# -0.4828 | ghetto
# -0.4829 | believable
# -0.4830 | mention
# -0.4832 | absorb
# -0.4836 | piece
# -0.4837 | delightfully
# -0.4843 | campanella
# -0.4848 | resonant
# -0.4852 | jealousy
# -0.4859 | roll
# -0.4863 | sweetly
# -0.4864 | slightly
# -0.4867 | deep
# -0.4870 | infuse
# -0.4881 | moments
# -0.4882 | if
# -0.4886 | boost
# -0.4887 | suitably
# -0.4891 | saturday
# -0.4895 | meditative
# -0.4898 | integrity
# -0.4909 | allow
# -0.4912 | impeccable
# -0.4913 | subtly
# -0.4919 | downtown
# -0.4920 | strong
# -0.4928 | reminiscent
# -0.4929 | surreal
# -0.4933 | bride
# -0.4935 | popular
# -0.4941 | center
# -0.4951 | openness
# -0.4951 | ways
# -0.4952 | culture
# -0.4954 | observant
# -0.4958 | comfortable
# -0.4963 | storytelling
# -0.4969 | tender
# -0.4986 | date
# -0.4994 | establish
# -0.5004 | execute
# -0.5023 | reno
# -0.5025 | treasure
# -0.5036 | subtle
# -0.5037 | experiment
# -0.5043 | excel
# -0.5044 | dismiss
# -0.5044 | anguish
# -0.5045 | huppert
# -0.5046 | impressively
# -0.5060 | recommend
# -0.5060 | acknowledge
# -0.5062 | passionate
# -0.5070 | ingenious
# -0.5071 | melancholy
# -0.5072 | twohy
# -0.5074 | chabrol
# -0.5074 | incredible
# -0.5084 | life
# -0.5086 | jessica
# -0.5087 | permeate
# -0.5088 | elevate
# -0.5088 | banter
# -0.5091 | gentle
# -0.5093 | alice
# -0.5094 | gut
# -0.5114 | protagonist
# -0.5119 | fest
# -0.5131 | poignant
# -0.5132 | big
# -0.5140 | 20th
# -0.5149 | rapid
# -0.5150 | caine
# -0.5154 | incident
# -0.5164 | hold
# -0.5165 | finely
# -0.5169 | lanes
# -0.5174 | saga
# -0.5175 | avert
# -0.5177 | quieter
# -0.5178 | joyous
# -0.5182 | sophisticate
# -0.5191 | gosford
# -0.5199 | easily
# -0.5200 | primary
# -0.5205 | weeks
# -0.5207 | exceed
# -0.5207 | proceed
# -0.5221 | sorvino
# -0.5224 | hear
# -0.5233 | office
# -0.5242 | adventurous
# -0.5247 | cast
# -0.5266 | woman
# -0.5273 | thornberrys
# -0.5277 | complaint
# -0.5278 | schmidt
# -0.5280 | format
# -0.5281 | assassin
# -0.5294 | ride
# -0.5296 | duvall
# -0.5303 | relief
# -0.5309 | strange
# -0.5312 | blend
# -0.5322 | spike
# -0.5330 | effortlessly
# -0.5336 | miller
# -0.5336 | cho
# -0.5361 | conspiracy
# -0.5364 | gosling
# -0.5367 | provide
# -0.5376 | canny
# -0.5401 | we
# -0.5422 | sensual
# -0.5424 | damon
# -0.5431 | edge
# -0.5433 | hope
# -0.5433 | color
# -0.5434 | industry
# -0.5436 | wide
# -0.5437 | sympathetic
# -0.5439 | white
# -0.5443 | thick
# -0.5444 | genuine
# -0.5444 | step
# -0.5447 | immediacy
# -0.5452 | class
# -0.5453 | role
# -0.5459 | also
# -0.5459 | dude
# -0.5473 | nicholas
# -0.5485 | creative
# -0.5489 | tour
# -0.5490 | ,
# -0.5498 | english
# -0.5501 | birthday
# -0.5506 | rich
# -0.5524 | deliciously
# -0.5530 | dance
# -0.5534 | romp
# -0.5537 | bittersweet
# -0.5542 | quirky
# -0.5553 | art
# -0.5558 | astound
# -0.5563 | gently
# -0.5564 | nicholson
# -0.5572 | destine
# -0.5572 | right
# -0.5581 | gorgeous
# -0.5586 | lesser
# -0.5592 | stimulate
# -0.5594 | child
# -0.5599 | a
# -0.5607 | urgency
# -0.5620 | beat
# -0.5621 | heartbreaking
# -0.5645 | actors
# -0.5662 | poem
# -0.5664 | lightly
# -0.5668 | smith
# -0.5669 | cool
# -0.5670 | receive
# -0.5672 | astonish
# -0.5674 | tsai
# -0.5675 | possess
# -0.5681 | road
# -0.5686 | hopeful
# -0.5693 | hoot
# -0.5696 | encounter
# -0.5711 | silver
# -0.5716 | ramsay
# -0.5723 | construct
# -0.5732 | bits
# -0.5733 | vitality
# -0.5733 | stun
# -0.5737 | protect
# -0.5750 | tragic
# -0.5765 | ai
# -0.5788 | illustrate
# -0.5816 | certain
# -0.5836 | uplift
# -0.5839 | amuse
# -0.5844 | roles
# -0.5865 | quietly
# -0.5866 | memento
# -0.5877 | realism
# -0.5877 | evocative
# -0.5883 | tragedy
# -0.5888 | compulsively
# -0.5924 | overwhelm
# -0.5930 | because
# -0.5938 | predecessor
# -0.5939 | burst
# -0.5941 | bond
# -0.5945 | diversion
# -0.5948 | playful
# -0.5956 | fessenden
# -0.5958 | detail
# -0.5964 | unforced
# -0.5985 | slight
# -0.5992 | elegantly
# -0.6042 | children
# -0.6042 | gloriously
# -0.6051 | year
# -0.6055 | bend
# -0.6073 | twist
# -0.6077 | amaze
# -0.6078 | breathe
# -0.6084 | tune
# -0.6098 | via
# -0.6101 | peek
# -0.6106 | dickens
# -0.6126 | waydowntown
# -0.6141 | foremost
# -0.6145 | give
# -0.6167 | america
# -0.6171 | encourage
# -0.6204 | wry
# -0.6204 | merge
# -0.6208 | moonlight
# -0.6210 | debate
# -0.6215 | son
# -0.6217 | kubrick
# -0.6219 | simple
# -0.6219 | buff
# -0.6225 | days
# -0.6227 | constant
# -0.6239 | see
# -0.6274 | humanity
# -0.6277 | faith
# -0.6279 | undeniably
# -0.6283 | succeed
# -0.6285 | meaningful
# -0.6290 | paxton
# -0.6300 | funniest
# -0.6306 | sly
# -0.6315 | enormous
# -0.6316 | baby
# -0.6325 | cat
# -0.6339 | enjoyment
# -0.6343 | undoubtedly
# -0.6350 | honest
# -0.6357 | imagery
# -0.6358 | especially
# -0.6370 | behold
# -0.6386 | plunge
# -0.6402 | sadness
# -0.6404 | spot
# -0.6407 | goofball
# -0.6426 | conservative
# -0.6432 | positive
# -0.6435 | score
# -0.6442 | mark
# -0.6480 | popcorn
# -0.6482 | remarkably
# -0.6485 | tomorrow
# -0.6487 | russian
# -0.6493 | colorful
# -0.6494 | sparkle
# -0.6499 | indian
# -0.6501 | whimsical
# -0.6504 | energetic
# -0.6513 | universal
# -0.6514 | stuart
# -0.6537 | frailty
# -0.6581 | department
# -0.6583 | nice
# -0.6586 | bill
# -0.6587 | real
# -0.6590 | delicately
# -0.6596 | huge
# -0.6619 | pleasures
# -0.6625 | hearts
# -0.6633 | unnerve
# -0.6643 | authority
# -0.6645 | pure
# -0.6653 | carmen
# -0.6664 | cheek
# -0.6670 | grip
# -0.6693 | highly
# -0.6694 | recent
# -0.6700 | deny
# -0.6707 | idiosyncratic
# -0.6710 | grace
# -0.6710 | ache
# -0.6719 | shakespearean
# -0.6731 | form
# -0.6749 | polanski
# -0.6755 | record
# -0.6765 | vibrant
# -0.6801 | lovely
# -0.6806 | sensational
# -0.6810 | successful
# -0.6814 | live
# -0.6818 | superbly
# -0.6823 | pander
# -0.6852 | well
# -0.6867 | true
# -0.6885 | holocaust
# -0.6906 | age
# -0.6925 | visceral
# -0.6931 | float
# -0.6953 | !
# -0.6971 | lift
# -0.6992 | four
# -0.6994 | interview
# -0.6998 | shanghai
# -0.7001 | robert
# -0.7066 | families
# -0.7068 | marriage
# -0.7084 | laughter
# -0.7100 | joy
# -0.7104 | aware
# -0.7117 | help
# -0.7152 | overrun
# -0.7153 | nonetheless
# -0.7189 | reveal
# -0.7201 | savvy
# -0.7262 | profile
# -0.7279 | smile
# -0.7308 | chill
# -0.7318 | exhilarate
# -0.7351 | meditation
# -0.7377 | prose
# -0.7400 | breathtaking
# -0.7401 | performances
# -0.7403 | performance
# -0.7405 | submarine
# -0.7447 | surprisingly
# -0.7475 | watchable
# -0.7493 | chance
# -0.7513 | happiness
# -0.7536 | part
# -0.7545 | heartwarming
# -0.7552 | drama
# -0.7571 | extraordinary
# -0.7617 | man
# -0.7631 | crisp
# -0.7646 | layer
# -0.7676 | musical
# -0.7681 | win
# -0.7700 | appeal
# -0.7701 | keep
# -0.7702 | ability
# -0.7714 | while
# -0.7717 | measure
# -0.7763 | great
# -0.7765 | shock
# -0.7774 | satisfy
# -0.7793 | soulful
# -0.7798 | fluid
# -0.7840 | horrify
# -0.7865 | combine
# -0.7877 | conduct
# -0.7911 | mesmerize
# -0.7925 | jolt
# -0.7928 | transform
# -0.7942 | french
# -0.7943 | excellent
# -0.7947 | moral
# -0.7949 | thank
# -0.7968 | timely
# -0.7985 | freedom
