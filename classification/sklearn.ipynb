# %% [markdown]
#  See links for instructions on installation if not already installed.
#   - [NLTK](https://www.nltk.org/install.html) (tested with 3.6.7 and with 3.2.5.)
#   - [Scikit-Learn](https://scikit-learn.org/stable/install.html) (test with 1.0.2)
#   - [SciPy](https://scipy.org/install/) (tested with 1.7.3 and with 1.4.1)

# %%
# !pip install gdown
# !gdown --id 1thWkUj7uGOApr_dXRvMr9TsEHpo_H_2q -O sst2.zip
# !mkdir -p data
# !unzip sst2.zip -d data
# !rm sst2.zip

# %% [markdown]
#  # Building and Extracting features

# %%
from collections import Counter
import json
from pathlib import Path

from nltk.tokenize import WordPunctTokenizer

print("Build unigram vocab from sst2.train")
data_dir = Path('sst2/')
tokenizer = WordPunctTokenizer()
counter = Counter()
counter.update(['<pad>', '<unk>'])
data_train = open(data_dir.joinpath('sst2.train')).readlines()
print(f"Size of training data: {len(data_train)}")

token_lines = []

for line in data_train:
    lower_line = line.lower()
    token_lines.append(tokenizer.tokenize(lower_line))
    
for sentence in token_lines:
    sentence = sentence[1:]
    for word in sentence:
        counter[word] = counter.get(word, 0) + 1
        
print(f"Vocab size before frequency filtering: {len(counter)}")
        
vocab = {key: val for key, val in counter.items() if val >= 3 or key == '<pad>' or key == '<unk>'}
vocab = {key: 0 for key in vocab}
vocab.update((k, i) for i, k in enumerate(vocab))

print(f"Vocab size after frequency filtering: {len(vocab)}")
output_filepath = data_dir.joinpath('unigram_vocab.json')
json.dump(vocab, open(output_filepath, mode='w'))
# Out:
# Build unigram vocab from sst2.train
# Size of training data: 6920
# Vocab size before frequency filtering: 13850
# Vocab size after frequency filtering: 4949

# %%
# sanity check
assert (vocab['<pad>'] == 0)
assert (vocab['<unk>'] == 1)
assert (len(vocab) == 4949)

# %% [markdown]
#  ### Generate features and labels files

# %%
# Generate `npz` files of features and of labels
import json
from nltk.tokenize import WordPunctTokenizer
import numpy as np
from scipy import sparse

def extract_features(vocab, data_dir, dataset, data_type, tokenizer, feature_name):
    '''
    Extracts and saves different features based on vocab of the features
    
    Inputs:
        vocab (dict): map from the word type to the index of the word
        data_dir (path): directory of the dataset
        dataset (file): data file
        data_type (string): train, dev, or test identifier
        tokenizer (callable): tokenizer with a tokenize method to return list of tokens
        feature_name (string): name of the feature, such as unigram_binary
        
    Output: no return, saves npz files
    '''
        
    data = open(data_dir.joinpath(dataset)).readlines()
    tokenizer = WordPunctTokenizer()
    
    tokens = []
    for line in data:
        lower_line = line.lower()
        tokens.append(tokenizer.tokenize(lower_line))
        
    label_list = []
    for line in tokens:
        label = int(line[0])
        label_list.append(label)
     
    final_tokens = []
    for line in tokens:
        split_line = line[1:]
        final_tokens.append(split_line)

    label_array = np.asarray(label_list)

    data_dict = {index: {key: 0 for key in vocab.keys()} for index, value in enumerate(final_tokens)}
    for line in final_tokens:
        for word in line:
            if word in vocab.keys():
                data_dict[final_tokens.index(line)][word] = 1
            else:
                data_dict[final_tokens.index(line)]['<unk>'] = 1
    
    data_matrix = np.array([[data_dict[index][key] for key in vocab.keys()] for index, value in enumerate(final_tokens)])
    sparse_matrix = sparse.csr_matrix(data_matrix)
    
    print(("The shape of the " + data_type + " matrix is: "), data_matrix.shape)
    print(("The shape of the " + data_type + " label array is: "), label_array.shape)
    print()
        
    sparse.save_npz('sst2/' + data_type + '_' + feature_name + '_features.npz', sparse_matrix)
    np.savez('sst2/' + data_type + '_labels.npz', label_array)

# %%
extract_features(vocab, Path('sst2/'), 'sst2.train', 'train', WordPunctTokenizer(), 'unigram_binary')
extract_features(vocab, Path('sst2/'), 'sst2.dev', 'dev', WordPunctTokenizer(), 'unigram_binary')
extract_features(vocab, Path('sst2/'), 'sst2.test', 'test', WordPunctTokenizer(), 'unigram_binary')
# Out:
# The shape of the train matrix is:  (6920, 4949)
# The shape of the train label array is:  (6920,)
#
# The shape of the dev matrix is:  (872, 4949)
# The shape of the dev label array is:  (872,)
#
# The shape of the test matrix is:  (1821, 4949)
# The shape of the test label array is:  (1821,)

# %% [markdown]
#  We provide you the helper function below for feature weight analysis (1.1.2 and 1.2.2).

# %%
def print_important_weights(weights, words):
    """
    Print important pairs of weights and words.
    # Parameters
    weights : `Iterable`, required.
        Weights from a learned model.
    words : `Iterable`, required.
        Word types of the vocabulary.  
        It must be true that `len(weights) == len(words)`.
    # Returns
        `None`
    """

    def print_pairs(pairs):
        for weight, word in pairs:
            print("{: .4f} | {}".format(weight, word))

    assert len(weights) == len(words)
    pairs = list(zip(weights, words))
    pairs = sorted(pairs, key=lambda x: x[0], reverse=True)
    print("Most positive words:")
    print_pairs(pairs[:10])
    print("\nMost negative words:")
    print_pairs(reversed(pairs[-10:]))

    pairs = list(zip(abs(weights), words))
    pairs = sorted(pairs, key=lambda x: x[0], reverse=False)
    print("\nMost neutral words:")
    print_pairs(pairs[:10])

# %% [markdown]
#  # Logistic regression with scikit-learn

# %%
train_features = sparse.load_npz('sst2/train_unigram_binary_features.npz')
train_labels = np.load('sst2/train_labels.npz')

dev_features = sparse.load_npz('sst2/dev_unigram_binary_features.npz')
dev_labels = np.load('sst2/dev_labels.npz')

test_features = sparse.load_npz('sst2/test_unigram_binary_features.npz')
test_labels = np.load('sst2/test_labels.npz')

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score

def fit_and_eval_logistic_regression(data_dir: Path,
                                     train_X, train_Y,
                                     test_X, test_Y,
                                     feature_name: str) -> LogisticRegression:
    '''
    Fits and evaluates the logistic regression model using the scikit-learn library
    
    Inputs:
        data_dir (path): the data directory
        trn_data (file): training data 
        tst_data (file): testing or dev data
        
    Output:
        model_trained (LogisticRegression): object of LogisticRegression after it is trained
    '''
    
    model = LogisticRegression()
    model.fit(train_X, train_Y['arr_0'])
    y_pred = model.predict(test_X)
    
    print("The accuracy score is: ", accuracy_score(test_Y['arr_0'], y_pred))
    print("The f1 score is: ", f1_score(test_Y['arr_0'], y_pred, average = 'weighted'))
    
    return model

# %% [markdown]
# ### dev model

# %%
print("These are the scores for dev")
print()

fit_and_eval_logistic_regression(feature_name = 'unigram_binary',
                                 train_X = train_features, train_Y = train_labels,
                                 test_X = dev_features, test_Y = dev_labels,
                                 data_dir = Path('sst2/'))
# Out:
# These are the scores for dev
#
# The accuracy score is:  0.7901376146788991
# The f1 score is:  0.790148380887179
# /usr/local/anaconda3/envs/nlp_env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ### test model

# %%
print("These are the scores for test")
print()

fit_and_eval_logistic_regression(feature_name = 'unigram_binary',
                                 train_X = train_features, train_Y = train_labels,
                                 test_X = test_features, test_Y = test_labels,
                                 data_dir = Path('sst2/'))
# Out:
# These are the scores for test
#
# The accuracy score is:  0.8039538714991763
# The f1 score is:  0.8039266727707524
# /usr/local/anaconda3/envs/nlp_env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
#  ## 1.1.2 Weights Analysis

# %%
model_trained: LogisticRegression = fit_and_eval_logistic_regression(
    feature_name='unigram_binary', train_X = train_features, train_Y = train_labels, test_X = test_features, test_Y = test_labels,data_dir=Path('data'))
weights = model_trained.coef_[0]
vocab = json.load(open(data_dir.joinpath('unigram_vocab.json')))
print_important_weights(weights=weights, words=vocab.keys())
# Out:
# The accuracy score is:  0.8039538714991763
# The f1 score is:  0.8039266727707524
# Most positive words:
#  1.9970 | solid
#  1.9597 | powerful
#  1.8592 | remarkable
#  1.8391 | enjoyable
#  1.7902 | refreshing
#  1.7346 | fun
#  1.6381 | works
#  1.6371 | appealing
#  1.6182 | hilarious
#  1.5746 | treat
#
# Most negative words:
# -2.0717 | stupid
# -1.9704 | suffers
# -1.9543 | mess
# -1.8894 | dull
# -1.8758 | worst
# -1.8209 | unfortunately
# -1.7326 | lacking
# -1.6592 | flat
# -1.6586 | bland
# -1.6217 | none
#
# Most neutral words:
#  0.0000 | <pad>
#  0.0001 | soldiers
#  0.0004 | actresses
#  0.0005 | flesh
#  0.0005 | narrator
#  0.0006 | dose
#  0.0008 | heal
#  0.0010 | borrows
#  0.0015 | daring
#  0.0015 | subplots
# /usr/local/anaconda3/envs/nlp_env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
#  ## Error Analysis

# %%
def test_errors(data_dir: Path, train_X, train_Y, test_X, test_Y, feature_name: str) -> LogisticRegression:
    '''
    Returns predicted label output for given training and testing data
    '''
    
    model = LogisticRegression()
    model.fit(train_X, train_Y['arr_0'])
    y_pred = model.predict(test_X)
    
    return y_pred

# %%
test_model = test_errors(feature_name = 'unigram_binary',
                         train_X = train_features, train_Y = train_labels,
                         test_X = test_features, test_Y = test_labels,
                         data_dir = Path('sst2/'))
# Out:
# /usr/local/anaconda3/envs/nlp_env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

def error_frame(pred_model, labels):
    '''
    Generates a pandas dataframe of mislabeled reviews
    '''
    
    label_column = pd.DataFrame(labels)
    label_column.rename(columns = {0: "True"}, inplace = True)
    model_column = pd.DataFrame(pred_model)
    model_column.rename(columns = {0: "Predicted"}, inplace = True)
    
    data_test = open(data_dir.joinpath('sst2.test')).readlines()
    tokens = []
    for line in data_test:
        lower_line = line.lower()
        tokens.append(tokenizer.tokenize(lower_line))
    
    full_frame = label_column.join(model_column)
    full_frame["Match"] = (full_frame["True"] == full_frame["Predicted"]).astype(int)
    full_frame["Line"] = tokens
    full_frame.index += 1
    
    print("The number of errors found: ", len(full_frame.loc[full_frame['Match'] == 0]))
    return full_frame.loc[full_frame['Match'] == 0]
# Out:
# /var/folders/dv/2_6b6bzd04x61zh3lkj7mmxm0000gn/T/ipykernel_46981/1375080042.py:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
error_frame(test_model, test_labels['arr_0'])
# Out:
# The number of errors found:  357
#       True  Predicted  Match  \
# 7     0     1          0
# 8     1     0          0
# 17    1     0          0
# 20    0     1          0
# 22    0     1          0
# 23    1     0          0
# 29    0     1          0
# 36    1     0          0
# 44    1     0          0
# 48    1     0          0
# 50    1     0          0
# 53    1     0          0
# 58    1     0          0
# 59    0     1          0
# 75    1     0          0
# 76    0     1          0
# 79    1     0          0
# 83    0     1          0
# 88    0     1          0
# 95    1     0          0
# 97    0     1          0
# 105   1     0          0
# 106   0     1          0
# 114   0     1          0
# 119   0     1          0
# 126   0     1          0
# 128   1     0          0
# 130   1     0          0
# 139   1     0          0
# 140   0     1          0
# 144   0     1          0
# 145   1     0          0
# 150   0     1          0
# 159   0     1          0
# 168   1     0          0
# 177   1     0          0
# 198   0     1          0
# 209   1     0          0
# 219   0     1          0
# 222   1     0          0
# 248   1     0          0
# 255   0     1          0
# 273   0     1          0
# 274   1     0          0
# 281   1     0          0
# 283   1     0          0
# 285   0     1          0
# 299   1     0          0
# 300   0     1          0
# 302   1     0          0
# 309   0     1          0
# 312   1     0          0
# 313   0     1          0
# 345   1     0          0
# 346   0     1          0
# 353   0     1          0
# 361   1     0          0
# 362   0     1          0
# 363   1     0          0
# 372   0     1          0
# 377   1     0          0
# 379   0     1          0
# 380   1     0          0
# 381   0     1          0
# 383   0     1          0
# 384   1     0          0
# 395   0     1          0
# 400   0     1          0
# 406   1     0          0
# 407   0     1          0
# 411   0     1          0
# 413   1     0          0
# 418   1     0          0
# 426   1     0          0
# 427   0     1          0
# 440   0     1          0
# 449   1     0          0
# 459   1     0          0
# 470   0     1          0
# 473   1     0          0
# 474   1     0          0
# 476   0     1          0
# 478   0     1          0
# 483   1     0          0
# 484   0     1          0
# 487   1     0          0
# 488   0     1          0
# 490   0     1          0
# 504   1     0          0
# 506   1     0          0
# 508   0     1          0
# 516   0     1          0
# 517   0     1          0
# 520   0     1          0
# 524   0     1          0
# 525   1     0          0
# 526   0     1          0
# 529   0     1          0
# 530   0     1          0
# 535   0     1          0
# 539   0     1          0
# 546   0     1          0
# 547   1     0          0
# 548   0     1          0
# 556   1     0          0
# 558   0     1          0
# 565   0     1          0
# 568   0     1          0
# 573   1     0          0
# 603   0     1          0
# 604   0     1          0
# 607   0     1          0
# 608   1     0          0
# 613   1     0          0
# 619   0     1          0
# 649   1     0          0
# 650   0     1          0
# 652   1     0          0
# 655   1     0          0
# 658   1     0          0
# 660   1     0          0
# 662   1     0          0
# 669   0     1          0
# 673   1     0          0
# 677   1     0          0
# 685   0     1          0
# 689   1     0          0
# 691   0     1          0
# 699   1     0          0
# 1352  1     0          0
# 1357  1     0          0
# 1360  0     1          0
# 1361  1     0          0
# 1372  0     1          0
# 1375  1     0          0
# 1385  0     1          0
# 1391  1     0          0
# 1395  1     0          0
# 1414  1     0          0
# 1425  0     1          0
# 1430  0     1          0
# 1435  0     1          0
# 1439  1     0          0
# 1441  1     0          0
# 1443  0     1          0
# 1448  0     1          0
# 1451  1     0          0
# 1459  0     1          0
# 1461  1     0          0
# 1464  0     1          0
# 1467  0     1          0
# 1468  1     0          0
# 1472  1     0          0
# 1481  0     1          0
# 1482  0     1          0
# 1489  0     1          0
# 1490  1     0          0
# 1492  0     1          0
# 1495  0     1          0
# 1502  0     1          0
# 1505  0     1          0
# 1528  0     1          0
# 1530  1     0          0
# 1535  1     0          0
# 1538  1     0          0
# 1542  1     0          0
# 1545  0     1          0
# 1548  0     1          0
# 1551  0     1          0
# 1558  0     1          0
# 1560  0     1          0
# 1562  0     1          0
# 1563  1     0          0
# 1568  1     0          0
# 1569  1     0          0
# 1572  1     0          0
# 1579  1     0          0
# 1586  0     1          0
# 1591  0     1          0
# 1594  1     0          0
# 1597  1     0          0
# 1601  0     1          0
# 1608  0     1          0
# 1609  1     0          0
# 1614  1     0          0
# 1625  0     1          0
# 1629  0     1          0
# 1633  0     1          0
# 1640  0     1          0
# 1650  1     0          0
# 1656  1     0          0
# 1658  0     1          0
# 1665  0     1          0
# 1683  0     1          0
# 1685  1     0          0
# 1686  1     0          0
# 1691  1     0          0
# 1695  0     1          0
# 1700  1     0          0
# 1706  1     0          0
# 1711  0     1          0
# 1728  0     1          0
# 1730  1     0          0
# 1736  1     0          0
# 1753  1     0          0
# 1761  0     1          0
# 1768  0     1          0
# 1788  0     1          0
# 1790  0     1          0
# 1801  0     1          0
# 1819  0     1          0
# 1820  0     1          0
# 1821  0     1          0
#
#                                                                                                                                                                                                                                                                                                                                 Line
# 7     [0, acting, ,, particularly, by, tambor, ,, almost, makes, ``, never, again, '', worthwhile, ,, but, -, lrb, -, writer, \/, director, -, rrb, -, schaeffer, should, follow, his, titular, advice]
# 8     [1, the, movie, exists, for, its, soccer, action, and, its, fine, acting, .]
# 17    [1, if, your, senses, have, n, ', t, been, dulled, by, slasher, films, and, gorefests, ,, if, you, ', re, a, connoisseur, of, psychological, horror, ,, this, is, your, ticket, .]
# 20    [0, those, who, managed, to, avoid, the, deconstructionist, theorizing, of, french, philosopher, jacques, derrida, in, college, can, now, take, an, 85, -, minute, brush, -, up, course, with, the, documentary, derrida, .]
# 22    [0, but, what, saves, lives, on, the, freeway, does, not, necessarily, make, for, persuasive, viewing, .]
# 23    [1, steve, irwin, ', s, method, is, ernest, hemmingway, at, accelerated, speed, and, volume, .]
# 29    [0, the, premise, for, this, kegger, comedy, probably, sounded, brilliant, four, six, -, packs, and, a, pitcher, of, margaritas, in, ,, but, the, film, must, have, been, written, ..., in, the, thrall, of, a, vicious, hangover, .]
# 36    [1, haneke, challenges, us, to, confront, the, reality, of, sexual, aberration, .]
# 1730  [1, if, this, movie, were, a, book, ,, it, would, be, a, page, -, turner, ,, you, ca, n, ', t, wait, to, see, what, happens, next, .]
# 1736  [1, for, benigni, it, was, n, ', t, shakespeare, whom, he, wanted, to, define, his, career, with, but, pinocchio, .]
# 1753  [1, steers, turns, in, a, snappy, screenplay, that, curls, at, the, edges, ;, it, ', s, so, clever, you, want, to, hate, it, .]
# 1761  [0, ..., a, haunting, vision, ,, with, images, that, seem, more, like, disturbing, hallucinations, .]
# 1768  [0, an, afterschool, special, without, the, courage, of, its, convictions, .]
# 1788  [0, my, response, to, the, film, is, best, described, as, lukewarm, .]
# 1790  [0, drags, along, in, a, dazed, and, enervated, ,, drenched, -, in, -, the, -, past, numbness, .]
# 1801  [0, or, some, damn, thing, .]
# 1819  [0, safe, conduct, ,, however, ambitious, and, well, -, intentioned, ,, fails, to, hit, the, entertainment, bull, ', s, -, eye, .]
# 1820  [0, a, film, made, with, as, little, wit, ,, interest, ,, and, professionalism, as, artistically, possible, for, a, slummy, hollywood, caper, flick, .]
# 1821  [0, but, here, ', s, the, real, damn, :, it, is, n, ', t, funny, ,, either, .]

# %%
def print_weight(weights, words):
    """
    Prints all word-weight pairs for given data and vocabulary
    """

    def print_pairs(pairs):
        for weight, word in pairs:
            print("{: .4f} | {}".format(weight, word))

    assert len(weights) == len(words)
    pairs = list(zip(weights, words))
    pairs = sorted(pairs, key=lambda x: x[0], reverse=True)
    print_pairs(pairs)

# %%
print_weight(weights = weights, words=vocab.keys())
# Out:
#  1.9970 | solid
#  1.9597 | powerful
#  1.8592 | remarkable
#  1.8391 | enjoyable
#  1.7902 | refreshing
#  1.7346 | fun
#  1.6381 | works
#  1.6371 | appealing
#  1.6182 | hilarious
#  1.5746 | treat
#  1.5637 | fascinating
#  1.5539 | charming
#  1.4961 | wonderful
#  1.4882 | entertaining
#  1.4869 | terrific
#  1.4790 | brilliant
#  1.4376 | beautifully
#  1.4329 | assured
#  1.4079 | eyes
#  1.4027 | fashioned
#  1.3845 | definitely
#  1.3805 | follow
#  1.3774 | manages
#  1.3471 | years
#  1.3393 | unexpected
#  1.3380 | always
#  1.3377 | summer
#  1.3295 | heart
#  1.3088 | smarter
#  1.2976 | best
#  1.2939 | delivers
#  1.2893 | imax
#  1.2803 | damn
#  1.2786 | masterpiece
#  1.2763 | resist
#  1.2675 | deeply
#  1.2664 | rare
#  1.2628 | provides
#  1.2468 | human
#  1.2438 | refreshingly
#  1.2418 | spirit
#  1.2157 | delightful
#  1.2128 | genre
#  1.2106 | engrossing
#  1.2058 | somewhat
#  1.2048 | fast
#  1.1871 | cinema
#  1.1838 | perfectly
#  1.1685 | worth
#  1.1673 | pleasing
#  1.1607 | charmer
#  1.1584 | portrait
#  1.1514 | funny
#  1.1509 | rewarding
#  1.1500 | foster
#  1.1461 | inventive
#  1.1438 | delight
#  1.1415 | delicate
#  1.1410 | strangely
#  1.1335 | wonderfully
#  1.1329 | impressive
#  1.1325 | spielberg
#  1.1313 | enjoy
#  1.1273 | enjoyed
#  1.1273 | thoughtful
#  1.1200 | witty
#  1.1152 | horrifying
#  1.1150 | sharp
#  1.1135 | visuals
#  1.1095 | pulls
#  1.1066 | timely
#  1.1033 | love
#  1.1018 | nerves
#  1.1016 | beauty
#  1.0931 | gem
#  1.0897 | satisfying
#  1.0889 | world
#  1.0886 | unique
#  1.0850 | captures
#  1.0834 | smart
#  1.0761 | means
#  1.0726 | intelligent
#  1.0700 | beautiful
#  1.0678 | buffs
#  1.0669 | played
#  1.0621 | intoxicating
#  1.0602 | positive
#  1.0597 | miracle
#  1.0564 | sadness
#  1.0491 | provocative
#  1.0452 | warm
#  1.0427 | family
#  1.0289 | viewing
#  1.0289 | extraordinary
#  1.0260 | affection
#  1.0247 | polanski
#  1.0227 | originality
#  1.0186 | chilling
#  1.0156 | moving
#  1.0148 | changing
#  1.0147 | succeeds
#  1.0033 | baby
#  1.0006 | russian
#  0.9999 | savvy
#  0.9972 | prose
#  0.9955 | concern
#  0.9923 | exhilarating
#  0.9897 | stuart
#  0.9889 | documentary
#  0.9880 | includes
#  0.9874 | ability
#  0.9870 | breathtaking
#  0.9850 | spectacular
#  0.9820 | crisp
#  0.9786 | effective
#  0.9780 | stirring
#  0.9765 | chance
#  0.9750 | shocking
#  0.9749 | good
#  0.9696 | memorable
#  0.9652 | tomorrow
#  0.9621 | harrowing
#  0.9561 | elegant
#  0.9551 | confident
#  0.9516 | wo
#  0.9508 | happy
#  0.9500 | barry
#  0.9498 | heartfelt
#  0.9492 | performances
#  0.9489 | modest
#  0.9470 | intriguing
#  0.9377 | pure
#  0.9363 | faithful
#  0.9350 | funniest
#  0.9347 | mesmerizing
#  0.9341 | laughter
#  0.9320 | notch
#  0.9311 | secretary
#  0.9291 | skin
#  0.9291 | freedom
#  0.9281 | excellent
#  0.9239 | honest
#  0.9182 | strength
#  0.9137 | loved
#  0.9098 | our
#  0.9043 | keep
#  0.9018 | brings
#  0.9015 | usual
#  0.9011 | true
#  0.9010 | delivering
#  0.9008 | denying
#  0.8983 | ignored
#  0.8962 | layers
#  0.8956 | musical
#  0.8944 | soulful
#  0.8925 | performance
#  0.8915 | conservative
#  0.8907 | amused
#  0.8892 | submarine
#  0.8888 | smile
#  0.8886 | grace
#  0.8880 | happiness
#  0.8880 | compulsively
#  0.8869 | vividly
#  0.8863 | measured
#  0.8856 | dazzling
#  0.8851 | thick
#  0.8835 | realism
#  0.8814 | part
#  0.8800 | overwhelming
#  0.8793 | constructed
#  0.8764 | based
#  0.8729 | visceral
#  0.8715 | existential
#  0.8713 | via
#  0.8673 | allows
#  0.8650 | robert
#  0.8618 | help
#  0.8608 | humanity
#  0.8599 | wide
#  0.8590 | faith
#  0.8584 | bringing
#  0.8580 | builds
#  0.8580 | odds
#  0.8568 | answers
#  0.8563 | born
#  0.8549 | remarkably
#  0.8545 | captivating
#  0.8543 | piece
#  0.8528 | riveting
#  0.8524 | different
#  0.8522 | touch
#  0.8519 | absorbing
#  0.8514 | bring
#  0.8513 | aware
#  0.8503 | places
#  0.8497 | marks
#  0.8494 | roll
#  0.8479 | accomplished
#  0.8464 | sparkling
#  0.8439 | compelling
#  0.8413 | meditation
#  0.8411 | sweet
#  0.8391 | haunting
#  0.8382 | goofball
#  0.8379 | man
#  0.8363 | undoubtedly
#  0.8362 | weeks
#  0.8356 | meaningful
#  0.8340 | imagery
#  0.8333 | duvall
#  0.8323 | observant
#  0.8310 | embrace
#  0.8273 | department
#  0.8254 | sustains
#  0.8193 | heartwarming
#  0.8187 | genuine
#  0.8174 | unforced
#  0.8174 | peek
#  0.8164 | engagingly
#  0.8161 | deliciously
#  0.8140 | watchable
#  0.8130 | animated
#  0.8105 | force
#  0.8097 | ages
#  0.8082 | group
#  0.8082 | hearts
#  0.8072 | french
#  0.8068 | ambitious
#  0.8062 | ai
#  0.8057 | cool
#  0.8056 | smith
#  0.8043 | fluid
#  0.8033 | guessing
#  0.8027 | !
#  0.8023 | days
#  0.8023 | going
#  0.8004 | drama
#  0.7976 | nice
#  0.7946 | child
#  0.7932 | sympathetic
#  0.7883 | profile
#  0.7879 | thought
#  0.7818 | wonders
#  0.7815 | entertain
#  0.7810 | four
#  0.7789 | fellow
#  0.7777 | score
#  0.7775 | liked
#  0.7774 | complaint
#  0.7763 | saves
#  0.7759 | conduct
#  0.7757 | likable
#  0.7743 | carmen
#  0.7713 | highly
#  0.7684 | heartbreaking
#  0.7683 | role
#  0.7680 | shrek
#  0.7679 | comfortable
#  0.7677 | indian
#  0.7667 | record
#  0.7662 | wry
#  0.7621 | while
#  0.7613 | poem
#  0.7599 | lets
#  0.7575 | moonlight
#  0.7535 | immediacy
#  0.7533 | received
#  0.7529 | offers
#  0.7514 | unnerving
#  0.7507 | flop
#  0.7493 | rubbo
#  0.7477 | touching
#  0.7477 | living
#  0.7472 | stand
#  0.7435 | ride
#  0.7430 | energetic
#  0.7423 | idiosyncratic
#  0.7418 | miyazaki
#  0.7403 | spirited
#  0.7403 | banter
#  0.7401 | cops
#  0.7389 | handling
#  0.7379 | vibrant
#  0.7376 | engaging
#  0.7332 | lies
#  0.7331 | ways
#  0.7328 | real
#  0.7328 | evocative
#  0.7326 | holocaust
#  0.7315 | breathes
#  0.7313 | debate
#  0.7303 | bond
#  0.7300 | fantastic
#  0.7290 | delicately
#  0.7282 | cat
#  0.7278 | topics
#  0.7276 | memento
#  0.7276 | twists
#  0.7274 | thornberrys
#  0.7267 | amazing
#  0.7262 | hoot
#  0.7252 | also
#  0.7245 | culture
#  0.7231 | pleasures
#  0.7229 | stroke
#  0.7223 | twohy
#  0.7220 | rocks
#  0.7171 | reveal
#  0.7171 | sensational
#  0.7167 | lesser
#  0.7166 | overrun
#  0.7160 | hope
#  0.7160 | joyous
#  0.7160 | gives
#  0.7145 | shanghai
#  0.7141 | son
#  0.7133 | canny
#  0.7117 | delightfully
#  0.7112 | art
#  0.7104 | whimsical
#  0.7097 | rich
#  0.7097 | adventurous
#  0.7077 | neo
#  0.7065 | bits
#  0.7065 | tsai
#  0.7059 | look
#  0.7047 | year
#  0.7044 | elegantly
#  0.7040 | lovely
#  0.7023 | tragedy
#  0.7017 | joy
#  0.7009 | surprisingly
#  0.7007 | authority
#  0.6997 | thanks
#  0.6995 | transforms
#  0.6990 | pace
#  0.6978 | frailty
#  0.6971 | miller
#  0.6958 | sexy
#  0.6953 | incident
#  0.6941 | primary
#  0.6941 | dude
#  0.6930 | fest
#  0.6920 | diversion
#  0.6919 | encouraging
#  0.6917 | belongs
#  0.6908 | steal
#  0.6896 | tasty
#  0.6888 | charismatic
#  0.6886 | tears
#  0.6885 | simple
#  0.6874 | possess
#  0.6872 | constant
#  0.6866 | spot
#  0.6865 | america
#  0.6863 | nonetheless
#  0.6849 | children
#  0.6849 | spell
#  0.6847 | taking
#  0.6821 | heat
#  0.6812 | cho
#  0.6812 | parts
#  0.6812 | reminiscent
#  0.6809 | quirky
#  0.6807 | destined
#  0.6806 | holds
#  0.6804 | respect
#  0.6797 | speaks
#  0.6794 | literate
#  0.6784 | fessenden
#  0.6778 | ache
#  0.6756 | hilarity
#  0.6748 | undeniably
#  0.6747 | impeccable
#  0.6746 | sly
#  0.6745 | strip
#  0.6734 | provoking
#  0.6727 | sisters
#  0.6725 | colorful
#  0.6717 | creative
#  0.6704 | greatness
#  0.6689 | quieter
#  0.6683 | tuned
#  0.6678 | hopeful
#  0.6663 | told
#  0.6656 | beings
#  0.6654 | history
#  0.6645 | format
#  0.6633 | difference
#  0.6621 | unlike
#  0.6615 | deserves
#  0.6612 | cult
#  0.6605 | uplifting
#  0.6590 | gloriously
#  0.6586 | loneliness
#  0.6580 | manage
#  0.6566 | strange
#  0.6560 | waydowntown
#  0.6555 | end
#  0.6552 | centered
#  0.6533 | ramsay
#  0.6523 | impact
#  0.6520 | especially
#  0.6511 | marriage
#  0.6511 | right
#  0.6508 | successful
#  0.6494 | souls
#  0.6486 | jealousy
#  0.6486 | take
#  0.6469 | quietly
#  0.6453 | chaos
#  0.6449 | vintage
#  0.6433 | france
#  0.6422 | sweetness
#  0.6411 | decades
#  0.6409 | pleasure
#  0.6408 | creates
#  0.6389 | ended
#  0.6387 | ben
#  0.6378 | huppert
#  0.6377 | mamet
#  0.6363 | throughout
#  0.6356 | charm
#  0.6342 | washington
#  0.6334 | consuming
#  0.6333 | permeates
#  0.6329 | foremost
#  0.6327 | adequately
#  0.6325 | bard
#  0.6312 | darned
#  0.6311 | anderson
#  0.6311 | nation
#  0.6310 | lord
#  0.6307 | steals
#  0.6305 | rewards
#  0.6301 | let
#  0.6300 | explore
#  0.6300 | vitality
#  0.6296 | lightly
#  0.6295 | gripping
#  0.6283 | shakespearean
#  0.6280 | woman
#  0.6254 | roles
#  0.6252 | silver
#  0.6248 | speculation
#  0.6235 | delights
#  0.6230 | you
#  0.6229 | romances
#  0.6227 | breaking
#  0.6227 | families
#  0.6220 | everyday
#  0.6213 | assembled
#  0.6199 | great
#  0.6197 | excels
#  0.6196 | acted
#  0.6192 | guts
#  0.6181 | sophisticated
#  0.6180 | gory
#  0.6167 | nicholson
#  0.6156 | blend
#  0.6153 | stunning
#  0.6148 | supremely
#  0.6143 | light
#  0.6138 | huge
#  0.6128 | seeing
#  0.6126 | universal
#  0.6113 | road
#  0.6110 | subtle
#  0.6100 | done
#  0.6095 | bride
#  0.6095 | john
#  0.6092 | leaving
#  0.6084 | reassuring
#  0.6082 | chinese
#  0.6081 | sensual
#  0.6077 | laughed
#  0.6067 | surprising
#  0.6059 | bartlett
#  0.6049 | oddly
#  0.6035 | meditative
#  0.6029 | dickens
#  0.6026 | masterfully
#  0.6025 | gently
#  0.6025 | space
#  0.6024 | cheer
#  0.6009 | openness
#  0.6006 | minds
#  0.6002 | paxton
#  0.6001 | please
#  0.5997 | ingenious
#  0.5991 | hearted
#  0.5984 | office
#  0.5977 | melancholy
#  0.5974 | modern
#  0.5968 | playful
#  0.5964 | combines
#  0.5956 | reminded
#  0.5950 | campanella
#  0.5945 | slight
#  0.5939 | work
#  0.5938 | hold
#  0.5927 | cheek
#  0.5917 | revelatory
#  0.5911 | believer
#  0.5909 | treasure
#  0.5904 | double
#  0.5900 | 80
#  0.5893 | spirits
#  0.5888 | trap
#  0.5884 | believable
#  0.5881 | well
#  0.5867 | considerable
#  0.5856 | landmark
#  0.5836 | rank
#  0.5836 | suitably
#  0.5834 | certain
#  0.5818 | juicy
#  0.5795 | reno
#  0.5786 | color
#  0.5783 | red
#  0.5781 | proud
#  0.5774 | neil
#  0.5762 | protagonist
#  0.5762 | study
#  0.5760 | saga
#  0.5749 | driven
#  0.5745 | tender
#  0.5744 | power
#  0.5744 | live
#  0.5740 | credit
#  0.5734 | discovery
#  0.5733 | individual
#  0.5732 | becoming
#  0.5731 | uncompromising
#  0.5729 | dismissed
#  0.5729 | cop
#  0.5728 | managed
#  0.5724 | freshness
#  0.5722 | am
#  0.5720 | franklin
#  0.5711 | farts
#  0.5708 | insane
#  0.5702 | forceful
#  0.5700 | superbly
#  0.5686 | metaphorical
#  0.5680 | subtly
#  0.5676 | executed
#  0.5674 | absolutely
#  0.5674 | chamber
#  0.5674 | variety
#  0.5666 | english
#  0.5665 | slightly
#  0.5663 | charlotte
#  0.5661 | feeling
#  0.5644 | bourne
#  0.5642 | guaranteed
#  0.5641 | polished
#  0.5637 | experiment
#  0.5637 | cute
#  0.5633 | surreal
#  0.5627 | popcorn
#  0.5623 | nicholas
#  0.5615 | nerve
#  0.5605 | form
#  0.5590 | effortlessly
#  0.5588 | martin
#  0.5584 | knows
#  0.5584 | elevates
#  0.5576 | reduced
#  0.5574 | grew
#  0.5571 | behold
#  0.5570 | satisfies
#  0.5568 | fascinate
#  0.5560 | pretty
#  0.5559 | society
#  0.5556 | shocks
#  0.5556 | puts
#  0.5553 | exploring
#  0.5549 | motivations
#  0.5542 | celebrates
#  0.5538 | richer
#  0.5533 | unconventional
#  0.5530 | worry
#  0.5528 | dream
#  0.5522 | ballot
#  0.5517 | breath
#  0.5513 | ghetto
#  0.5513 | moments
#  0.5503 | shines
#  0.5502 | damned
#  0.5495 | win
#  0.5493 | manhattan
#  0.5488 | white
#  0.5466 | life
#  0.5459 | pleaser
#  0.5453 | passionate
#  0.5452 | undisputed
#  0.5444 | verbal
#  0.5441 | check
#  0.5436 | marvel
#  0.5427 | together
#  0.5419 | dragon
#  0.5414 | kubrick
#  0.5407 | complicated
#  0.5405 | greek
#  0.5405 | moral
#  0.5397 | whose
#  0.5386 | within
#  0.5385 | return
#  0.5380 | keeps
#  0.5377 | chord
#  0.5373 | gosling
#  0.5358 | extended
#  0.5353 | storytelling
#  0.5352 | packed
#  0.5346 | sorvino
#  0.5345 | personalities
#  0.5345 | moviemaking
#  0.5341 | sprightly
#  0.5334 | impressively
#  0.5332 | endearing
#  0.5330 | alice
#  0.5325 | astonishing
#  0.5319 | austin
#  0.5317 | blade
#  0.5310 | hypnotic
#  0.5309 | got
#  0.5308 | lucas
#  0.5303 | interview
#  0.5301 | improvement
#  0.5300 | cast
#  0.5300 | saturday
#  0.5298 | lot
#  0.5294 | enormous
#  0.5293 | popular
#  0.5293 | reminder
#  0.5290 | arresting
#  0.5281 | layered
#  0.5281 | skillful
#  0.5280 | kwan
#  0.5273 | pleasant
#  0.5267 | lonely
#  0.5259 | rarely
#  0.5256 | stuff
#  0.5255 | comedies
#  0.5254 | way
#  0.5253 | birthday
#  0.5251 | norton
#  0.5250 | damon
#  0.5250 | smartly
#  0.5246 | scorsese
#  0.5244 | existed
#  0.5240 | century
#  0.5239 | strong
#  0.5231 | welsh
#  0.5226 | trashy
#  0.5223 | finely
#  0.5221 | peter
#  0.5207 | predecessor
#  0.5187 | resonate
#  0.5183 | drug
#  0.5181 | gorgeous
#  0.5181 | taut
#  0.5180 | grand
#  0.5175 | unusual
#  0.5174 | raw
#  0.5174 | shattering
#  0.5168 | relief
#  0.5158 | step
#  0.5143 | urban
#  0.5135 | broomfield
#  0.5134 | haynes
#  0.5132 | winning
#  0.5132 | bittersweet
#  0.5131 | intimate
#  0.5116 | jessica
#  0.5105 | detail
#  0.5102 | beat
#  0.5101 | immediate
#  0.5097 | big
#  0.5095 | integrity
#  0.5091 | enjoyment
#  0.5082 | educational
#  0.5076 | graham
#  0.5076 | dumas
#  0.5074 | movies
#  0.5074 | superb
#  0.5062 | urgency
#  0.5053 | tremendous
#  0.5046 | embracing
#  0.5043 | thrill
#  0.5042 | spare
#  0.5033 | caine
#  0.5032 | section
#  0.5032 | job
#  0.5025 | masterful
#  0.5023 | luster
#  0.5022 | versus
#  0.5008 | uniquely
#  0.5006 | neighborhood
#  0.5006 | deft
#  0.5006 | open
#  0.5004 | wrenching
#  0.5002 | nair
#  0.5001 | walter
#  0.4998 | resonant
#  0.4998 | singing
#  0.4994 | stunts
#  0.4993 | realistic
#  0.4991 | national
#  0.4986 | artist
#  0.4980 | wit
#  0.4978 | age
#  0.4977 | iranian
#  0.4977 | wing
#  0.4976 | longer
#  0.4973 | touched
#  0.4969 | tough
#  0.4967 | added
#  0.4966 | downtown
#  0.4961 | experience
#  0.4961 | intense
#  0.4960 | tragic
#  0.4955 | damaged
#  0.4940 | surface
#  0.4936 | pacino
#  0.4934 | interaction
#  0.4933 | filling
#  0.4930 | famous
#  0.4918 | glorious
#  0.4908 | us
#  0.4905 | korea
#  0.4904 | embraces
#  0.4903 | easily
#  0.4898 | since
#  0.4895 | quiet
#  0.4894 | muccino
#  0.4893 | clever
#  0.4893 | conspiracy
#  0.4893 | nachtwey
#  0.4891 | bold
#  0.4884 | recent
#  0.4871 | transcends
#  0.4867 | according
#  0.4861 | richly
#  0.4850 | chief
#  0.4848 | hugh
#  0.4844 | carries
#  0.4843 | hear
#  0.4838 | proceedings
#  0.4824 | malkovich
#  0.4820 | still
#  0.4806 | perfect
#  0.4806 | buñuel
#  0.4803 | poetry
#  0.4800 | prism
#  0.4797 | locations
#  0.4781 | alluring
#  0.4781 | bowling
#  0.4762 | curves
#  0.4760 | adds
#  0.4759 | fly
#  0.4757 | band
#  0.4755 | startling
#  0.4747 | convincing
#  0.4733 | undeniable
#  0.4730 | simone
#  0.4725 | actors
#  0.4723 | betrayal
#  0.4718 | certainly
#  0.4712 | handed
#  0.4709 | bogdanovich
#  0.4707 | ideal
#  0.4707 | detailed
#  0.4705 | count
#  0.4703 | sweetly
#  0.4703 | gentle
#  0.4702 | wild
#  0.4698 | slightest
#  0.4693 | nervy
#  0.4684 | lived
#  0.4671 | psycho
#  0.4667 | willis
#  0.4666 | understated
#  0.4664 | humorous
#  0.4660 | see
#  0.4656 | intact
#  0.4651 | uses
#  0.4642 | christian
#  0.4629 | transformation
#  0.4625 | psychologically
#  0.4624 | yarn
#  0.4624 | sneaks
#  0.4619 | obstacles
#  0.4613 | element
#  0.4603 | bridge
#  0.4594 | crack
#  0.4586 | notice
#  0.4586 | powerpuff
#  0.4582 | spectacle
#  0.4568 | em
#  0.4564 | vietnam
#  0.4564 | morvern
#  0.4561 | unpretentious
#  0.4555 | infectious
#  0.4549 | heroic
#  0.4549 | scotland
#  0.4546 | gangs
#  0.4542 | dark
#  0.4541 | wonder
#  0.4538 | distinctive
#  0.4523 | complex
#  0.4522 | spider
#  0.4522 | examination
#  0.4511 | their
#  0.4506 | patient
#  0.4503 | spoof
#  0.4499 | heartbreak
#  0.4498 | benefit
#  0.4490 | canon
#  0.4488 | reggio
#  0.4482 | wanted
#  0.4479 | adaptation
#  0.4476 | poignant
#  0.4475 | visit
#  0.4472 | music
#  0.4469 | unfolds
#  0.4468 | chabrol
#  0.4456 | industry
#  0.4454 | rouge
#  0.4454 | incredible
#  0.4449 | recommend
#  0.4444 | doo
#  0.4439 | using
#  0.4438 | clarity
#  0.4437 | delicious
#  0.4430 | ahead
#  0.4428 | realistically
#  0.4425 | questions
#  0.4420 | deftly
#  0.4414 | skill
#  0.4412 | deep
#  0.4412 | kosminsky
#  0.4408 | kinnear
#  0.4408 | directed
#  0.4406 | immensely
#  0.4402 | jacquot
#  0.4399 | mention
#  0.4394 | examines
#  0.4394 | enormously
#  0.4393 | members
#  0.4385 | rapid
#  0.4381 | early
#  0.4380 | many
#  0.4379 | nemesis
#  0.4372 | course
#  0.4368 | napoleon
#  0.4364 | resistance
#  0.4364 | lip
#  0.4358 | tell
#  0.4355 | portray
#  0.4353 | antwone
#  0.4348 | beast
#  0.4344 | ponder
#  0.4342 | grant
#  0.4341 | gave
#  0.4341 | woven
#  0.4338 | images
#  0.4336 | vincent
#  0.4336 | plenty
#  0.4335 | native
#  0.4326 | breezy
#  0.4321 | establishes
#  0.4318 | succeeded
#  0.4315 | clooney
#  0.4314 | appear
#  0.4314 | e
#  0.4311 | vivid
#  0.4310 | spiced
#  0.4310 | isolation
#  0.4306 | leigh
#  0.4303 | bombastic
#  0.4301 | did
#  0.4301 | with
#  0.4298 | happily
#  0.4298 | brave
#  0.4298 | jolts
#  0.4290 | bound
#  0.4284 | backdrop
#  0.4277 | oscar
#  0.4276 | style
#  0.4272 | allow
#  0.4271 | kahlo
#  0.4264 | tea
#  0.4264 | hopefully
#  0.4263 | composition
#  0.4260 | imamura
#  0.4252 | demons
#  0.4248 | diverse
#  0.4248 | flourishes
#  0.4245 | thousands
#  0.4243 | field
#  0.4240 | adult
#  0.4239 | gritty
#  0.4234 | city
#  0.4234 | give
#  0.4233 | kissing
#  0.4231 | c
#  0.4231 | trenchant
#  0.4227 | worthwhile
#  0.4223 | renner
#  0.4222 | tour
#  0.4218 | above
#  0.4217 | due
#  0.4217 | bracing
#  0.4216 | undercurrent
#  0.4214 | fierce
#  0.4211 | mel
#  0.4209 | matinee
#  0.4205 | stein
#  0.4203 | filmmaker
#  0.4201 | testament
#  0.4200 | fragile
#  0.4199 | escapist
#  0.4197 | demands
#  0.4195 | candy
#  0.4193 | class
#  0.4191 | seen
#  0.4189 | wow
#  0.4188 | weep
#  0.4187 | 20th
#  0.4187 | lanes
#  0.4183 | reign
#  0.4181 | insightfully
#  0.4180 | salton
#  0.4179 | throwback
#  0.4179 | korean
#  0.4178 | warmth
#  0.4177 | strikes
#  0.4175 | unpredictable
#  0.4166 | likeable
#  0.4162 | films
#  0.4149 | godard
#  0.4148 | event
#  0.4146 | confidence
#  0.4143 | grief
#  0.4143 | camera
#  0.4137 | midnight
#  0.4134 | eat
#  0.4132 | yes
#  0.4131 | creations
#  0.4131 | adrenaline
#  0.4129 | edge
#  0.4127 | sumptuous
#  0.4126 | determined
#  0.4123 | boobs
#  0.4122 | insightful
#  0.4120 | timeless
#  0.4117 | understands
#  0.4117 | inviting
#  0.4113 | stylistic
#  0.4099 | narc
#  0.4097 | sobering
#  0.4096 | allen
#  0.4091 | israeli
#  0.4079 | cerebral
#  0.4078 | theme
#  0.4076 | company
#  0.4072 | view
#  0.4064 | design
#  0.4061 | michel
#  0.4055 | home
#  0.4050 | austerity
#  0.4034 | inner
#  0.4031 | captivates
#  0.4031 | olivier
#  0.4024 | justice
#  0.4023 | heaven
#  0.4022 | achievement
#  0.4020 | bit
#  0.4017 | jumbo
#  0.4009 | meat
#  0.4003 | marshall
#  0.4001 | document
#  0.3988 | extraordinarily
#  0.3986 | deadpan
#  0.3986 | pathology
#  0.3985 | committed
#  0.3985 | ones
#  0.3980 | holofcener
#  0.3973 | splendid
#  0.3972 | kidman
#  0.3970 | neat
#  0.3969 | odyssey
#  0.3968 | minor
#  0.3968 | late
#  0.3966 | burst
#  0.3966 | skins
#  0.3961 | keeping
#  0.3959 | sets
#  0.3952 | distinguished
#  0.3948 | searing
#  0.3945 | tavernier
#  0.3942 | rhythms
#  0.3940 | straightforward
#  0.3936 | angel
#  0.3932 | makes
#  0.3931 | avoids
#  0.3929 | scott
#  0.3925 | each
#  0.3924 | blue
#  0.3924 | fairly
#  0.3922 | values
#  0.3919 | anne
#  0.3916 | subversive
#  0.3914 | perspective
#  0.3900 | connect
#  0.3897 | measure
#  0.3896 | side
#  0.3892 | unblinking
#  0.3891 | stark
#  0.3891 | binoche
#  0.3890 | yiddish
#  0.3890 | uniformly
#  0.3888 | claude
#  0.3883 | perdition
#  0.3883 | bloody
#  0.3880 | biopic
#  0.3879 | reveals
#  0.3876 | day
#  0.3873 | 1970s
#  0.3871 | dutiful
#  0.3871 | breadth
#  0.3868 | exploration
#  0.3866 | satisfyingly
#  0.3866 | stylized
#  0.3865 | dancing
#  0.3856 | unable
#  0.3855 | appreciate
#  0.3851 | seat
#  0.3850 | flavor
#  0.3850 | 60s
#  0.3847 | minority
#  0.3845 | awards
#  0.3844 | mark
#  0.3841 | lends
#  0.3832 | my
#  0.3826 | portrayal
#  0.3824 | crisis
#  0.3823 | bitten
#  0.3821 | giddy
#  0.3818 | revolution
#  0.3816 | specifically
#  0.3811 | standards
#  0.3808 | roger
#  0.3805 | extravagant
#  0.3801 | capturing
#  0.3793 | hilariously
#  0.3792 | relies
#  0.3790 | donovan
#  0.3789 | sexual
#  0.3789 | crammed
#  0.3787 | tempting
#  0.3785 | spike
#  0.3785 | talk
#  0.3784 | schmidt
#  0.3784 | argue
#  0.3780 | lives
#  0.3780 | throws
#  0.3776 | although
#  0.3773 | ear
#  0.3772 | soderbergh
#  0.3768 | inspirational
#  0.3762 | timing
#  0.3762 | recommended
#  0.3754 | terror
#  0.3752 | bank
#  0.3751 | china
#  0.3746 | towards
#  0.3740 | land
#  0.3737 | todd
#  0.3731 | happening
#  0.3729 | heard
#  0.3726 | providing
#  0.3725 | cup
#  0.3724 | presence
#  0.3724 | michael
#  0.3723 | face
#  0.3723 | shyamalan
#  0.3721 | suspenseful
#  0.3720 | brilliantly
#  0.3719 | share
#  0.3717 | mysteries
#  0.3716 | 50s
#  0.3714 | bruce
#  0.3713 | fan
#  0.3713 | spectacularly
#  0.3709 | kids
#  0.3705 | mood
#  0.3701 | intelligently
#  0.3701 | balance
#  0.3696 | listen
#  0.3695 | intrigue
#  0.3695 | learning
#  0.3694 | we
#  0.3691 | resourceful
#  0.3675 | nuanced
#  0.3670 | visually
#  0.3668 | journey
#  0.3667 | terry
#  0.3665 | animals
#  0.3662 | likely
#  0.3652 | picture
#  0.3650 | significantly
#  0.3649 | gosford
#  0.3648 | breakthrough
#  0.3647 | mind
#  0.3646 | couple
#  0.3645 | loves
#  0.3638 | fills
#  0.3638 | faster
#  0.3637 | craig
#  0.3635 | assayas
#  0.3634 | salma
#  0.3631 | \*\*\*
#  0.3628 | employs
#  0.3619 | 84
#  0.3616 | chuckle
#  0.3614 | solidly
#  0.3613 | grown
#  0.3607 | earnest
#  0.3605 | full
#  0.3599 | ca
#  0.3594 | because
#  0.3593 | pokemon
#  0.3590 | filmmaking
#  0.3586 | specimen
#  0.3585 | wang
#  0.3580 | slowly
#  0.3579 | dogtown
#  0.3579 | and
#  0.3577 | powerfully
#  0.3574 | gorgeously
#  0.3573 | glimpse
#  0.3566 | cartoons
#  0.3565 | brothers
#  0.3565 | truthful
#  0.3562 | dover
#  0.3562 | kosashvili
#  0.3558 | often
#  0.3553 | terrifying
#  0.3550 | revenge
#  0.3550 | infuses
#  0.3549 | hair
#  0.3549 | successfully
#  0.3548 | authentic
#  0.3546 | analyze
#  0.3545 | pulling
#  0.3541 | if
#  0.3539 | showcases
#  0.3536 | defies
#  0.3534 | assassin
#  0.3530 | storyline
#  0.3530 | de
#  0.3530 | albeit
#  0.3526 | relevant
#  0.3525 | enthusiastic
#  0.3519 | politically
#  0.3514 | unusually
#  0.3513 | pride
#  0.3507 | challenges
#  0.3502 | directors
#  0.3502 | contemporary
#  0.3501 | teenage
#  0.3500 | appeal
#  0.3492 | relationship
#  0.3492 | punk
#  0.3488 | unexpectedly
#  0.3485 | persona
#  0.3484 | arnold
#  0.3481 | what
#  0.3472 | wedding
#  0.3471 | lie
#  0.3468 | creepy
#  0.3463 | boys
#  0.3461 | finish
#  0.3460 | recovery
#  0.3454 | anger
#  0.3446 | irresistible
#  0.3443 | villains
#  0.3442 | prospect
#  0.3441 | enduring
#  0.3437 | scale
#  0.3436 | explores
#  0.3436 | lips
#  0.3436 | western
#  0.3435 | interpretation
#  0.3433 | compared
#  0.3431 | sad
#  0.3428 | oriented
#  0.3424 | boisterous
#  0.3419 | expressive
#  0.3418 | community
#  0.3417 | foreign
#  0.3417 | political
#  0.3413 | levels
#  0.3413 | direct
#  0.3412 | lines
#  0.3410 | craft
#  0.3410 | runs
#  0.3407 | disappoint
#  0.3405 | sides
#  0.3402 | starting
#  0.3401 | alien
#  0.3401 | palpable
#  0.3391 | mr
#  0.3390 | both
#  0.3389 | barbershop
#  0.3389 | insomnia
#  0.3387 | radiant
#  0.3384 | themes
#  0.3381 | web
#  0.3380 | sublime
#  0.3379 | parade
#  0.3379 | tearjerker
#  0.3377 | revelation
#  0.3376 | use
#  0.3375 | draws
#  0.3374 | film
#  0.3371 | slice
#  0.3370 | taps
#  0.3368 | warrior
#  0.3368 | island
#  0.3367 | bang
#  0.3366 | cleverness
#  0.3360 | disquieting
#  0.3357 | exceptional
#  0.3351 | master
#  0.3349 | darling
#  0.3345 | amiable
#  0.3344 | gloss
#  0.3341 | suspense
#  0.3339 | fans
#  0.3335 | something
#  0.3331 | rhythm
#  0.3329 | cultural
#  0.3325 | labute
#  0.3320 | across
#  0.3318 | panache
#  0.3318 | parents
#  0.3316 | unconditional
#  0.3313 | sarandon
#  0.3312 | honesty
#  0.3307 | unforgettable
#  0.3306 | casting
#  0.3300 | justify
#  0.3298 | uncanny
#  0.3297 | giant
#  0.3296 | mouth
#  0.3292 | ideas
#  0.3284 | unknown
#  0.3279 | spooky
#  0.3274 | cultures
#  0.3272 | sincerity
#  0.3265 | metaphor
#  0.3263 | confessions
#  0.3261 | moviegoing
#  0.3259 | sequence
#  0.3245 | landscape
#  0.3239 | compellingly
#  0.3236 | kid
#  0.3234 | reel
#  0.3233 | endlessly
#  0.3232 | whale
#  0.3227 | p
#  0.3223 | frequent
#  0.3217 | goofy
#  0.3216 | enjoyably
#  0.3215 | bill
#  0.3215 | adventure
#  0.3214 | takes
#  0.3211 | marvelously
#  0.3207 | boasting
#  0.3207 | thankfully
#  0.3206 | read
#  0.3206 | crowd
#  0.3206 | who
#  0.3204 | courage
#  0.3201 | enthusiasm
#  0.3195 | deeds
#  0.3192 | fate
#  0.3184 | rose
#  0.3183 | bible
#  0.3183 | mixture
#  0.3180 | war
#  0.3177 | derrida
#  0.3167 | shows
#  0.3160 | primarily
#  0.3159 | discover
#  0.3155 | convey
#  0.3152 | bravery
#  0.3152 | comedic
#  0.3142 | chouraqui
#  0.3133 | wholesome
#  0.3132 | slapstick
#  0.3131 | encounter
#  0.3131 | stone
#  0.3127 | distinct
#  0.3125 | era
#  0.3123 | award
#  0.3123 | duration
#  0.3120 | schrader
#  0.3116 | interested
#  0.3115 | gradually
#  0.3111 | those
#  0.3111 | brutal
#  0.3107 | knack
#  0.3104 | sun
#  0.3104 | classics
#  0.3103 | mental
#  0.3096 | strangeness
#  0.3091 | screen
#  0.3091 | success
#  0.3090 | edges
#  0.3082 | metropolis
#  0.3076 | hybrid
#  0.3074 | merits
#  0.3071 | generous
#  0.3061 | seams
#  0.3059 | pertinent
#  0.3058 | squeeze
#  0.3057 | research
#  0.3057 | rodriguez
#  0.3053 | gary
#  0.3051 | striking
#  0.3047 | honor
#  0.3046 | exquisite
#  0.3043 | flick
#  0.3039 | tribute
#  0.3038 | returns
#  0.3036 | expected
#  0.3031 | chiller
#  0.3026 | carry
#  0.3025 | strongest
#  0.3025 | subculture
#  0.3011 | brightly
#  0.3011 | delivered
#  0.3007 | brown
#  0.3003 | frequently
#  0.3003 | landscapes
#  0.3003 | soul
#  0.3001 | downbeat
#  0.2992 | enveloping
#  0.2991 | thriller
#  0.2990 | bettany
#  0.2990 | scope
#  0.2986 | intimacy
#  0.2985 | outstanding
#  0.2984 | dynamics
#  0.2981 | climactic
#  0.2977 | singer
#  0.2974 | paul
#  0.2968 | will
#  0.2968 | skillfully
#  0.2965 | enough
#  0.2964 | task
#  0.2961 | detective
#  0.2960 | valuable
#  0.2960 | accept
#  0.2959 | familial
#  0.2956 | racial
#  0.2955 | fresh
#  0.2954 | documentaries
#  0.2953 | tongue
#  0.2943 | divine
#  0.2938 | easy
#  0.2938 | capable
#  0.2936 | nomination
#  0.2935 | rohmer
#  0.2934 | conversations
#  0.2931 | furiously
#  0.2924 | drew
#  0.2923 | aficionados
#  0.2923 | helped
#  0.2918 | moore
#  0.2916 | exists
#  0.2911 | liberating
#  0.2911 | mythic
#  0.2910 | daily
#  0.2908 | exotic
#  0.2908 | proof
#  0.2907 | relationships
#  0.2906 | carried
#  0.2906 | christmas
#  0.2903 | capacity
#  0.2900 | decent
#  0.2900 | established
#  0.2898 | saving
#  0.2897 | multi
#  0.2894 | written
#  0.2893 | literary
#  0.2891 | songs
#  0.2890 | deliver
#  0.2889 | extent
#  0.2889 | poetic
#  0.2888 | higher
#  0.2887 | toes
#  0.2885 | crafted
#  0.2884 | filmed
#  0.2882 | jolt
#  0.2878 | others
#  0.2873 | turn
#  0.2869 | shortcomings
#  0.2863 | education
#  0.2863 | flair
#  0.2861 | comics
#  0.2860 | fare
#  0.2858 | 70s
#  0.2854 | rely
#  0.2852 | quaid
#  0.2849 | lane
#  0.2847 | laid
#  0.2839 | depiction
#  0.2838 | capability
#  0.2836 | felt
#  0.2832 | promises
#  0.2831 | dazzle
#  0.2830 | lady
#  0.2829 | reminds
#  0.2829 | stays
#  0.2818 | payne
#  0.2816 | when
#  0.2815 | waiting
#  0.2807 | caught
#  0.2805 | tiny
#  0.2801 | doubt
#  0.2798 | languorous
#  0.2796 | aspects
#  0.2794 | sheer
#  0.2788 | bogged
#  0.2785 | treatment
#  0.2781 | accurately
#  0.2774 | having
#  0.2772 | collectively
#  0.2767 | pushes
#  0.2766 | commercialism
#  0.2766 | features
#  0.2764 | harsh
#  0.2761 | supernatural
#  0.2756 | comedian
#  0.2751 | shenanigans
#  0.2742 | interviews
#  0.2735 | blast
#  0.2735 | grind
#  0.2735 | ocean
#  0.2733 | emerges
#  0.2732 | energy
#  0.2729 | hidden
#  0.2728 | anguish
#  0.2728 | ian
#  0.2724 | jolie
#  0.2722 | fantasies
#  0.2720 | hitting
#  0.2719 | totally
#  0.2716 | debut
#  0.2714 | proves
#  0.2712 | biting
#  0.2705 | dreams
#  0.2703 | girl
#  0.2702 | objectivity
#  0.2701 | tale
#  0.2697 | lifts
#  0.2694 | chaplin
#  0.2693 | yet
#  0.2692 | expertly
#  0.2690 | fascination
#  0.2690 | potent
#  0.2682 | showtime
#  0.2680 | ichi
#  0.2677 | daytime
#  0.2676 | phenomenal
#  0.2675 | competition
#  0.2671 | accessible
#  0.2668 | ring
#  0.2663 | trick
#  0.2659 | top
#  0.2659 | freeman
#  0.2655 | charms
#  0.2655 | ably
#  0.2654 | black
#  0.2653 | uncommonly
#  0.2651 | darkly
#  0.2649 | service
#  0.2643 | crossover
#  0.2642 | tortured
#  0.2619 | evokes
#  0.2617 | diesel
#  0.2614 | 21st
#  0.2614 | duke
#  0.2613 | 12
#  0.2610 | determination
#  0.2609 | spend
#  0.2608 | once
#  0.2605 | organic
#  0.2602 | obsessions
#  0.2598 | battle
#  0.2596 | plus
#  0.2593 | complexity
#  0.2589 | nicole
#  0.2586 | ,
#  0.2585 | recipe
#  0.2582 | including
#  0.2580 | wilco
#  0.2580 | potential
#  0.2575 | admission
#  0.2574 | asian
#  0.2568 | artful
#  0.2567 | continues
#  0.2559 | handsomely
#  0.2559 | rate
#  0.2558 | refusal
#  0.2558 | familiar
#  0.2557 | vietnamese
#  0.2552 | addition
#  0.2552 | distance
#  0.2550 | contrivances
#  0.2550 | allowing
#  0.2547 | wise
#  0.2545 | neatly
#  0.2539 | blockbuster
#  0.2539 | holm
#  0.2528 | 95
#  0.2528 | push
#  0.2527 | murder
#  0.2525 | eventual
#  0.2501 | villain
#  0.2499 | chilly
#  0.2499 | emperor
#  0.2499 | club
#  0.2498 | tosca
#  0.2494 | garcia
#  0.2493 | alert
#  0.2484 | impressed
#  0.2483 | feces
#  0.2482 | paints
#  0.2481 | standard
#  0.2480 | men
#  0.2478 | truth
#  0.2477 | subtitles
#  0.2477 | pointed
#  0.2476 | thirteen
#  0.2475 | romp
#  0.2473 | lee
#  0.2462 | collaboration
#  0.2461 | insider
#  0.2458 | meyjes
#  0.2457 | bullock
#  0.2451 | scratch
#  0.2450 | outing
#  0.2441 | carol
#  0.2430 | riot
#  0.2429 | rolling
#  0.2427 | penetrating
#  0.2425 | stretches
#  0.2425 | displays
#  0.2424 | shadows
#  0.2421 | background
#  0.2420 | entertainment
#  0.2411 | hall
#  0.2407 | expect
#  0.2399 | small
#  0.2394 | thrillers
#  0.2392 | admirable
#  0.2389 | janice
#  0.2382 | diverting
#  0.2377 | australia
#  0.2377 | ironic
#  0.2377 | elegance
#  0.2376 | friendly
#  0.2373 | lewis
#  0.2373 | martha
#  0.2371 | super
#  0.2371 | frightening
#  0.2370 | religious
#  0.2370 | aliens
#  0.2369 | welcome
#  0.2364 | weirdly
#  0.2362 | icon
#  0.2361 | kennedy
#  0.2360 | gifts
#  0.2360 | catch
#  0.2359 | outrageous
#  0.2357 | pop
#  0.2356 | amusing
#  0.2352 | soaked
#  0.2351 | cuts
#  0.2350 | jane
#  0.2350 | workplace
#  0.2348 | bodied
#  0.2346 | alive
#  0.2346 | christopher
#  0.2344 | flashes
#  0.2341 | longing
#  0.2340 | beach
#  0.2339 | ego
#  0.2339 | janklowicz
#  0.2337 | hoping
#  0.2336 | despair
#  0.2322 | venice
#  0.2317 | responsibility
#  0.2317 | vein
#  0.2315 | birot
#  0.2310 | later
#  0.2306 | crew
#  0.2306 | nonstop
#  0.2305 | brosnan
#  0.2305 | revealing
#  0.2305 | spin
#  0.2302 | wickedly
#  0.2300 | yearning
#  0.2298 | disregard
#  0.2296 | page
#  0.2287 | herself
#  0.2281 | pictures
#  0.2276 | fisher
#  0.2276 | notwithstanding
#  0.2275 | along
#  0.2272 | pulpy
#  0.2271 | professionals
#  0.2270 | shakespeare
#  0.2262 | sport
#  0.2255 | know
#  0.2254 | hatred
#  0.2246 | talking
#  0.2246 | scripts
#  0.2242 | invaluable
#  0.2242 | stylish
#  0.2242 | favorite
#  0.2241 | traditional
#  0.2240 | drumline
#  0.2240 | b
#  0.2234 | amazingly
#  0.2233 | greater
#  0.2222 | jackson
#  0.2219 | sensibilities
#  0.2218 | everywhere
#  0.2216 | italian
#  0.2214 | indie
#  0.2213 | expense
#  0.2211 | zone
#  0.2209 | aimed
#  0.2206 | presents
#  0.2201 | dance
#  0.2196 | buoyant
#  0.2192 | protagonists
#  0.2192 | can
#  0.2191 | entertainingly
#  0.2190 | piercing
#  0.2185 | griffiths
#  0.2183 | daniel
#  0.2181 | thomas
#  0.2180 | upbeat
#  0.2177 | flawed
#  0.2175 | hong
#  0.2175 | kong
#  0.2173 | campy
#  0.2170 | appropriate
#  0.2169 | inclination
#  0.2168 | soon
#  0.2165 | obsessive
#  0.2164 | fuzzy
#  0.2158 | quality
#  0.2158 | esteem
#  0.2152 | school
#  0.2150 | fire
#  0.2149 | callar
#  0.2149 | flaws
#  0.2149 | serves
#  0.2147 | limits
#  0.2143 | physical
#  0.2143 | japanese
#  0.2141 | ozpetek
#  0.2137 | liberation
#  0.2133 | fits
#  0.2129 | separate
#  0.2127 | affecting
#  0.2121 | artistic
#  0.2118 | wendigo
#  0.2118 | instance
#  0.2116 | build
#  0.2106 | knowledge
#  0.2105 | room
#  0.2102 | effects
#  0.2100 | details
#  0.2098 | salt
#  0.2096 | able
#  0.2096 | respectable
#  0.2095 | burns
#  0.2093 | eloquently
#  0.2085 | mere
#  0.2085 | claustrophobic
#  0.2084 | diaries
#  0.2084 | patience
#  0.2083 | spots
#  0.2077 | tension
#  0.2076 | parker
#  0.2074 | bruckheimer
#  0.2073 | mushy
#  0.2073 | myth
#  0.2072 | deceptively
#  0.2069 | broadway
#  0.2069 | marginal
#  0.2065 | mendes
#  0.2061 | lingering
#  0.2060 | uncertain
#  0.2059 | nickleby
#  0.2057 | jonathan
#  0.2052 | enthralling
#  0.2051 | average
#  0.2050 | derived
#  0.2049 | date
#  0.2047 | secret
#  0.2045 | rendered
#  0.2044 | park
#  0.2043 | minimalist
#  0.2040 | lovers
#  0.2036 | refugees
#  0.2033 | from
#  0.2031 | suggest
#  0.2025 | h
#  0.2024 | romantic
#  0.2017 | took
#  0.2017 | base
#  0.2008 | reaction
#  0.2007 | leads
#  0.2006 | delivery
#  0.2000 | james
#  0.1995 | saw
#  0.1994 | its
#  0.1993 | steeped
#  0.1991 | flow
#  0.1987 | columbine
#  0.1981 | superior
#  0.1978 | sensitivity
#  0.1976 | downward
#  0.1973 | beats
#  0.1973 | beguiling
#  0.1972 | moved
#  0.1970 | charged
#  0.1963 | harmless
#  0.1962 | trust
#  0.1955 | technology
#  0.1950 | rival
#  0.1949 | inquisitive
#  0.1946 | young
#  0.1936 | challenging
#  0.1935 | beneath
#  0.1931 | pellington
#  0.1927 | mix
#  0.1927 | list
#  0.1926 | er
#  0.1924 | illuminating
#  0.1924 | tragically
#  0.1922 | communal
#  0.1921 | keen
#  0.1917 | food
#  0.1917 | trapped
#  0.1917 | subjects
#  0.1913 | bravado
#  0.1913 | precisely
#  0.1911 | example
#  0.1911 | intensity
#  0.1896 | functions
#  0.1895 | metaphors
#  0.1893 | ties
#  0.1891 | tackling
#  0.1888 | audiard
#  0.1887 | press
#  0.1884 | arrive
#  0.1883 | 19
#  0.1881 | provided
#  0.1881 | caper
#  0.1873 | genuinely
#  0.1871 | acts
#  0.1869 | differences
#  0.1867 | greene
#  0.1866 | influence
#  0.1866 | boredom
#  0.1865 | mib
#  0.1863 | infantile
#  0.1860 | politics
#  0.1858 | frozen
#  0.1856 | mexican
#  0.1856 | morton
#  0.1850 | front
#  0.1841 | richard
#  0.1837 | consistently
#  0.1833 | williams
#  0.1830 | hell
#  0.1830 | square
#  0.1830 | 13
#  0.1828 | illustrates
#  0.1826 | fitting
#  0.1825 | wallop
#  0.1823 | radar
#  0.1821 | sensibility
#  0.1818 | afternoon
#  0.1817 | huston
#  0.1814 | sense
#  0.1808 | east
#  0.1805 | regardless
#  0.1798 | punch
#  0.1797 | breathtakingly
#  0.1793 | finest
#  0.1789 | environment
#  0.1782 | memories
#  0.1781 | nijinsky
#  0.1781 | struck
#  0.1780 | nutty
#  0.1776 | schumacher
#  0.1775 | offer
#  0.1768 | else
#  0.1766 | fine
#  0.1757 | heady
#  0.1754 | drunk
#  0.1746 | tasteful
#  0.1745 | borders
#  0.1741 | create
#  0.1741 | gere
#  0.1731 | entertained
#  0.1730 | stitch
#  0.1729 | makers
#  0.1726 | news
#  0.1725 | rifkin
#  0.1724 | blockbusters
#  0.1722 | formed
#  0.1721 | story
#  0.1719 | hashiguchi
#  0.1716 | fight
#  0.1710 | comedy
#  0.1710 | irwin
#  0.1710 | accident
#  0.1705 | helps
#  0.1701 | sensitive
#  0.1701 | struggle
#  0.1700 | swimming
#  0.1699 | angle
#  0.1691 | cheese
#  0.1689 | surprise
#  0.1689 | scare
#  0.1689 | adolescent
#  0.1683 | amidst
#  0.1683 | intensely
#  0.1681 | don
#  0.1680 | finally
#  0.1675 | moody
#  0.1671 | production
#  0.1671 | director
#  0.1670 | series
#  0.1668 | sequels
#  0.1666 | x
#  0.1665 | rise
#  0.1660 | play
#  0.1655 | awake
#  0.1655 | disappointed
#  0.1651 | incessant
#  0.1648 | lit
#  0.1646 | eventually
#  0.1645 | generates
#  0.1644 | mainstream
#  0.1643 | spite
#  0.1640 | chemistry
#  0.1637 | photographed
#  0.1633 | dares
#  0.1633 | may
#  0.1628 | bielinsky
#  0.1625 | glass
#  0.1624 | anime
#  0.1624 | sex
#  0.1624 | exploitative
#  0.1624 | vignettes
#  0.1619 | won
#  0.1605 | bodily
#  0.1604 | ya
#  0.1604 | ripper
#  0.1598 | gut
#  0.1596 | steers
#  0.1592 | desperation
#  0.1592 | clause
#  0.1590 | dignity
#  0.1589 | bitter
#  0.1588 | eye
#  0.1587 | be
#  0.1586 | offbeat
#  0.1586 | whimsy
#  0.1584 | passions
#  0.1581 | tales
#  0.1579 | sugar
#  0.1576 | jaw
#  0.1576 | emphasizes
#  0.1575 | minute
#  0.1574 | jaglom
#  0.1571 | substantial
#  0.1570 | scenario
#  0.1569 | theories
#  0.1565 | idealism
#  0.1565 | awkwardness
#  0.1564 | german
#  0.1563 | nicks
#  0.1562 | scrooge
#  0.1557 | refuses
#  0.1553 | enhances
#  0.1551 | feature
#  0.1550 | sinister
#  0.1548 | eyed
#  0.1547 | ensemble
#  0.1547 | last
#  0.1546 | splashed
#  0.1546 | proper
#  0.1545 | biz
#  0.1544 | larger
#  0.1529 | sweeping
#  0.1529 | father
#  0.1528 | ferrara
#  0.1526 | willing
#  0.1522 | member
#  0.1521 | demonstrate
#  0.1521 | substitute
#  0.1520 | shout
#  0.1519 | stage
#  0.1516 | cheeky
#  0.1515 | effort
#  0.1509 | access
#  0.1504 | deception
#  0.1502 | photography
#  0.1502 | aside
#  0.1500 | move
#  0.1500 | pungent
#  0.1499 | paranoia
#  0.1498 | pleasantly
#  0.1486 | new
#  0.1483 | surprised
#  0.1482 | roman
#  0.1482 | tradition
#  0.1482 | noir
#  0.1481 | circumstances
#  0.1480 | maid
#  0.1477 | naughty
#  0.1476 | outcome
#  0.1475 | profound
#  0.1472 | she
#  0.1469 | image
#  0.1466 | baran
#  0.1464 | ask
#  0.1463 | survive
#  0.1461 | kiddie
#  0.1460 | bright
#  0.1460 | exceedingly
#  0.1458 | covers
#  0.1452 | medium
#  0.1452 | effectively
#  0.1452 | wondrous
#  0.1451 | fully
#  0.1449 | narrative
#  0.1449 | rewarded
#  0.1440 | talent
#  0.1439 | movement
#  0.1438 | departure
#  0.1436 | pitfalls
#  0.1432 | parent
#  0.1431 | brooding
#  0.1427 | incisive
#  0.1426 | eerie
#  0.1425 | contemplation
#  0.1423 | gong
#  0.1423 | subject
#  0.1421 | ambiguity
#  0.1421 | notorious
#  0.1418 | camp
#  0.1405 | adage
#  0.1403 | express
#  0.1402 | martial
#  0.1401 | forcefully
#  0.1393 | forgive
#  0.1392 | inject
#  0.1391 | introduction
#  0.1390 | ease
#  0.1384 | spiritual
#  0.1380 | chest
#  0.1380 | maybe
#  0.1374 | alternately
#  0.1374 | exciting
#  0.1371 | ash
#  0.1371 | wednesday
#  0.1370 | lively
#  0.1367 | gang
#  0.1366 | escapism
#  0.1366 | ode
#  0.1366 | lifetime
#  0.1364 | a
#  0.1361 | unoriginal
#  0.1361 | diggs
#  0.1360 | pants
#  0.1358 | usually
#  0.1357 | fable
#  0.1356 | illness
#  0.1345 | unsettling
#  0.1344 | an
#  0.1343 | pianist
#  0.1342 | song
#  0.1342 | matthew
#  0.1340 | knowing
#  0.1332 | burger
#  0.1330 | meets
#  0.1328 | realize
#  0.1315 | artifice
#  0.1313 | boils
#  0.1313 | two
#  0.1308 | scripting
#  0.1306 | colors
#  0.1306 | tells
#  0.1306 | schnitzler
#  0.1305 | taymor
#  0.1302 | diary
#  0.1302 | unlikely
#  0.1301 | intellect
#  0.1297 | vision
#  0.1296 | weirdness
#  0.1293 | crudup
#  0.1283 | up
#  0.1278 | affleck
#  0.1275 | unflinching
#  0.1269 | worked
#  0.1266 | 1
#  0.1261 | fair
#  0.1259 | slam
#  0.1257 | fights
#  0.1255 | enticing
#  0.1251 | dopey
#  0.1247 | though
#  0.1241 | key
#  0.1239 | tambor
#  0.1235 | reliable
#  0.1231 | natured
#  0.1229 | juan
#  0.1225 | several
#  0.1215 | ray
#  0.1214 | intelligence
#  0.1213 | thumbs
#  0.1212 | gifted
#  0.1210 | arguments
#  0.1206 | empire
#  0.1205 | sisterhood
#  0.1202 | staggeringly
#  0.1202 | tensions
#  0.1202 | dickensian
#  0.1202 | fancy
#  0.1201 | row
#  0.1199 | sentimental
#  0.1197 | eccentric
#  0.1197 | economic
#  0.1196 | bursts
#  0.1196 | shaggy
#  0.1194 | character
#  0.1194 | academy
#  0.1193 | combined
#  0.1193 | important
#  0.1193 | q
#  0.1188 | iconoclastic
#  0.1188 | lush
#  0.1186 | elusive
#  0.1183 | that
#  0.1182 | pair
#  0.1182 | ravishing
#  0.1182 | outer
#  0.1181 | themed
#  0.1181 | writer
#  0.1180 | resonance
#  0.1180 | finale
#  0.1179 | baked
#  0.1176 | system
#  0.1168 | times
#  0.1164 | they
#  0.1159 | directly
#  0.1158 | deceptions
#  0.1144 | artists
#  0.1140 | increasingly
#  0.1135 | droppingly
#  0.1128 | ralph
#  0.1122 | struggles
#  0.1121 | worthy
#  0.1120 | hunter
#  0.1119 | chase
#  0.1119 | remember
#  0.1118 | killer
#  0.1118 | solaris
#  0.1114 | destruction
#  0.1110 | 15
#  0.1106 | gift
#  0.1103 | matter
#  0.1103 | has
#  0.1101 | insurance
#  0.1094 | astute
#  0.1093 | legendary
#  0.1091 | david
#  0.1089 | suck
#  0.1086 | convince
#  0.1086 | excess
#  0.1086 | loving
#  0.1085 | fantasy
#  0.1083 | nicely
#  0.1083 | survivors
#  0.1082 | transcend
#  0.1076 | intricate
#  0.1075 | among
#  0.1069 | evelyn
#  0.1068 | purely
#  0.1068 | jerry
#  0.1067 | goods
#  0.1062 | saying
#  0.1054 | venture
#  0.1049 | catching
#  0.1042 | commercial
#  0.1041 | afraid
#  0.1040 | empowerment
#  0.1039 | otherwise
#  0.1036 | safe
#  0.1036 | demonstrates
#  0.1035 | large
#  0.1030 | surprises
#  0.1028 | go
#  0.1027 | precious
#  0.1026 | into
#  0.1023 | ranks
#  0.1018 | verve
#  0.1007 | adults
#  0.1001 | mcgrath
#  0.0999 | come
#  0.0995 | the
#  0.0993 | spice
#  0.0992 | participants
#  0.0990 | pitch
#  0.0990 | improbable
#  0.0980 | signs
#  0.0976 | deliberately
#  0.0973 | identity
#  0.0965 | struggling
#  0.0964 | possible
#  0.0963 | denied
#  0.0953 | brother
#  0.0953 | grisly
#  0.0951 | misanthropic
#  0.0950 | games
#  0.0950 | wesley
#  0.0950 | creature
#  0.0948 | lion
#  0.0946 | it
#  0.0943 | fence
#  0.0942 | retro
#  0.0940 | chris
#  0.0929 | sayles
#  0.0928 | diaz
#  0.0927 | aged
#  0.0925 | naturally
#  0.0925 | suitable
#  0.0924 | laughing
#  0.0923 | hopkins
#  0.0923 | ever
#  0.0920 | smoking
#  0.0920 | barrels
#  0.0920 | revealed
#  0.0918 | offend
#  0.0914 | unbelievable
#  0.0913 | antonia
#  0.0908 | blame
#  0.0907 | shock
#  0.0905 | tackles
#  0.0905 | flicks
#  0.0901 | nifty
#  0.0896 | relaxed
#  0.0895 | pathos
#  0.0894 | backstage
#  0.0892 | powers
#  0.0891 | window
#  0.0887 | obsession
#  0.0887 | public
#  0.0873 | vital
#  0.0870 | involve
#  0.0869 | but
#  0.0868 | free
#  0.0867 | brought
#  0.0858 | sounding
#  0.0858 | twisting
#  0.0854 | theatre
#  0.0854 | advised
#  0.0850 | wisdom
#  0.0849 | drawing
#  0.0846 | her
#  0.0843 | hey
#  0.0840 | sanctimony
#  0.0838 | bodice
#  0.0835 | survival
#  0.0834 | miss
#  0.0827 | bullets
#  0.0826 | bear
#  0.0824 | mira
#  0.0823 | one
#  0.0821 | events
#  0.0815 | passing
#  0.0815 | cumulative
#  0.0809 | narratively
#  0.0807 | most
#  0.0804 | surf
#  0.0800 | pays
#  0.0797 | believing
#  0.0796 | never
#  0.0791 | topic
#  0.0786 | cyber
#  0.0781 | fabric
#  0.0780 | crackle
#  0.0777 | charles
#  0.0767 | trailer
#  0.0758 | destructive
#  0.0758 | definition
#  0.0758 | informative
#  0.0755 | started
#  0.0752 | disney
#  0.0745 | specific
#  0.0745 | ham
#  0.0745 | hit
#  0.0742 | savage
#  0.0740 | accents
#  0.0740 | hayek
#  0.0737 | porn
#  0.0736 | nettelbeck
#  0.0736 | château
#  0.0735 | folly
#  0.0734 | scherfig
#  0.0732 | enigmatic
#  0.0731 | edited
#  0.0722 | messages
#  0.0721 | alike
#  0.0713 | poignancy
#  0.0712 | legal
#  0.0712 | nuance
#  0.0710 | unsentimental
#  0.0708 | schepisi
#  0.0708 | clothes
#  0.0708 | cell
#  0.0701 | walk
#  0.0699 | kim
#  0.0696 | rob
#  0.0696 | inside
#  0.0695 | similarly
#  0.0692 | locales
#  0.0691 | 2
#  0.0685 | dirty
#  0.0682 | auteuil
#  0.0682 | bite
#  0.0679 | technique
#  0.0677 | program
#  0.0674 | sacrifice
#  0.0670 | non
#  0.0668 | raised
#  0.0662 | changes
#  0.0659 | chou
#  0.0658 | attitude
#  0.0657 | cuteness
#  0.0657 | testimony
#  0.0656 | closing
#  0.0656 | titles
#  0.0655 | show
#  0.0653 | choice
#  0.0649 | special
#  0.0647 | predict
#  0.0645 | brilliance
#  0.0644 | cletis
#  0.0643 | finds
#  0.0643 | seven
#  0.0639 | comic
#  0.0638 | articulate
#  0.0637 | produced
#  0.0635 | he
#  0.0635 | sure
#  0.0633 | 101
#  0.0632 | watch
#  0.0630 | reluctant
#  0.0623 | sits
#  0.0622 | dawson
#  0.0622 | kaufman
#  0.0621 | \/
#  0.0616 | smoother
#  0.0612 | lyrical
#  0.0612 | wife
#  0.0605 | improvisation
#  0.0604 | husband
#  0.0601 | innocence
#  0.0599 | poverty
#  0.0599 | anomie
#  0.0599 | develops
#  0.0596 | besson
#  0.0594 | stops
#  0.0592 | opportunities
#  0.0590 | his
#  0.0589 | zombie
#  0.0588 | somber
#  0.0587 | excitement
#  0.0586 | again
#  0.0584 | kick
#  0.0582 | beginning
#  0.0578 | peak
#  0.0575 | screens
#  0.0574 | grim
#  0.0574 | construct
#  0.0574 | sort
#  0.0573 | stately
#  0.0572 | held
#  0.0565 | wind
#  0.0564 | issue
#  0.0562 | devices
#  0.0558 | &
#  0.0556 | murphy
#  0.0552 | signals
#  0.0550 | these
#  0.0550 | .
#  0.0547 | break
#  0.0546 | cuban
#  0.0539 | israel
#  0.0531 | credibility
#  0.0529 | function
#  0.0529 | youthful
#  0.0528 | recognize
#  0.0524 | noise
#  0.0524 | general
#  0.0523 | original
#  0.0522 | cover
#  0.0519 | practice
#  0.0517 | realized
#  0.0516 | dramas
#  0.0512 | innovative
#  0.0511 | s
#  0.0510 | complexities
#  0.0508 | morality
#  0.0508 | arty
#  0.0507 | auteur
#  0.0506 | wrote
#  0.0505 | york
#  0.0504 | truly
#  0.0499 | pushed
#  0.0495 | drink
#  0.0493 | reasonably
#  0.0491 | jewish
#  0.0490 | hollywood
#  0.0490 | hoffman
#  0.0489 | awareness
#  0.0487 | than
#  0.0486 | celebrity
#  0.0478 | projects
#  0.0477 | sting
#  0.0475 | pleasurable
#  0.0475 | ourselves
#  0.0474 | bump
#  0.0474 | rollicking
#  0.0472 | notable
#  0.0469 | mothman
#  0.0468 | jones
#  0.0467 | extravaganza
#  0.0464 | dana
#  0.0460 | sons
#  0.0451 | steven
#  0.0445 | momentum
#  0.0443 | equal
#  0.0443 | ancient
#  0.0443 | shining
#  0.0441 | boldly
#  0.0436 | bio
#  0.0435 | sacrificing
#  0.0432 | ryan
#  0.0431 | least
#  0.0430 | arrest
#  0.0426 | folk
#  0.0425 | drop
#  0.0424 | casts
#  0.0422 | back
#  0.0417 | cleverly
#  0.0417 | allusions
#  0.0413 | humans
#  0.0407 | panoramic
#  0.0406 | mattei
#  0.0405 | digs
#  0.0401 | nails
#  0.0401 | productions
#  0.0399 | dullest
#  0.0394 | admirably
#  0.0394 | lock
#  0.0392 | chops
#  0.0389 | legacy
#  0.0386 | planet
#  0.0383 | monsoon
#  0.0382 | angst
#  0.0382 | subtext
#  0.0381 | airless
#  0.0381 | combat
#  0.0381 | objective
#  0.0380 | profoundly
#  0.0373 | gore
#  0.0372 | juliette
#  0.0371 | fontaine
#  0.0367 | tap
#  0.0364 | natural
#  0.0362 | faces
#  0.0360 | weighty
#  0.0359 | silliness
#  0.0357 | escapes
#  0.0356 | inspires
#  0.0355 | attraction
#  0.0353 | sight
#  0.0351 | predecessors
#  0.0344 | manners
#  0.0344 | eloquent
#  0.0343 | paced
#  0.0337 | african
#  0.0334 | inter
#  0.0332 | upon
#  0.0332 | sports
#  0.0328 | consequences
#  0.0323 | feat
#  0.0322 | costume
#  0.0320 | type
#  0.0313 | deserved
#  0.0308 | solutions
#  0.0305 | 300
#  0.0302 | xxx
#  0.0292 | meticulously
#  0.0292 | jumps
#  0.0291 | misogyny
#  0.0289 | gangster
#  0.0287 | highlight
#  0.0282 | associated
#  0.0278 | entirely
#  0.0278 | monsters
#  0.0276 | 9
#  0.0274 | chick
#  0.0270 | insanely
#  0.0269 | holiday
#  0.0267 | altogether
#  0.0266 | basis
#  0.0264 | caring
#  0.0263 | created
#  0.0261 | sardonic
#  0.0260 | performed
#  0.0258 | darkness
#  0.0252 | cloying
#  0.0250 | suffocating
#  0.0249 | notion
#  0.0248 | historically
#  0.0245 | die
#  0.0240 | showcase
#  0.0237 | developments
#  0.0234 | edgy
#  0.0232 | ready
#  0.0228 | water
#  0.0223 | phones
#  0.0223 | offering
#  0.0218 | satisfactory
#  0.0215 | rap
#  0.0214 | audacious
#  0.0214 | daughter
#  0.0209 | repellent
#  0.0206 | praise
#  0.0206 | esque
#  0.0206 | uncomfortably
#  0.0194 | noble
#  0.0190 | particularly
#  0.0188 | inspiring
#  0.0187 | round
#  0.0181 | maintain
#  0.0181 | situations
#  0.0180 | bull
#  0.0179 | blown
#  0.0178 | travel
#  0.0175 | exterior
#  0.0174 | killed
#  0.0174 | said
#  0.0171 | handsome
#  0.0171 | say
#  0.0168 | further
#  0.0167 | macabre
#  0.0164 | devastating
#  0.0164 | everything
#  0.0162 | boasts
#  0.0148 | deprecating
#  0.0148 | criminal
#  0.0147 | strands
#  0.0146 | high
#  0.0146 | feet
#  0.0143 | determine
#  0.0136 | replete
#  0.0135 | breaks
#  0.0130 | pick
#  0.0127 | unassuming
#  0.0120 | punching
#  0.0113 | rocket
#  0.0112 | epic
#  0.0109 | friendship
#  0.0108 | paid
#  0.0105 | reflection
#  0.0100 | closer
#  0.0099 | speak
#  0.0099 | consistent
#  0.0097 | staged
#  0.0096 | expands
#  0.0091 | co
#  0.0091 | arts
#  0.0090 | celebration
#  0.0088 | perceptive
#  0.0084 | j
#  0.0082 | japan
#  0.0081 | parable
#  0.0079 | abstract
#  0.0076 | box
#  0.0076 | dean
#  0.0076 | drawn
#  0.0070 | vampires
#  0.0070 | baffled
#  0.0068 | producer
#  0.0067 | endeavor
#  0.0066 | teacher
#  0.0063 | hits
#  0.0063 | map
#  0.0062 | host
#  0.0060 | satin
#  0.0058 | root
#  0.0056 | molly
#  0.0056 | clear
#  0.0055 | abuse
#  0.0053 | soft
#  0.0053 | robinson
#  0.0049 | quasi
#  0.0048 | past
#  0.0040 | telegraphed
#  0.0038 | avant
#  0.0038 | garde
#  0.0033 | innocent
#  0.0031 | properly
#  0.0024 | jazzy
#  0.0022 | :
#  0.0020 | frida
#  0.0020 | must
#  0.0016 | sand
#  0.0015 | subplots
#  0.0015 | daring
#  0.0010 | borrows
# -0.0334 | working
# -0.0334 | could
# -0.0334 | constantly
# -0.0340 | hawn
# -0.0343 | zealand
# -0.0344 | knew
# -0.0346 | photo
# -0.0350 | achieve
# -0.0351 | goose
# -0.0352 | pre
# -0.0352 | awfully
# -0.0354 | earth
# ...
# -0.4047 | destination
# -0.4048 | any
# -0.4050 | confusing
# -0.4053 | uninvolving
# -0.4058 | similar
# -0.4059 | approach
# -0.4060 | broad
# -0.4060 | vampire
# -0.4062 | ecks
# -0.4062 | sever
# -0.4063 | editing
# -0.4067 | anachronistic
# -0.4067 | sleeve
# -0.4068 | believability
# -0.4069 | attack
# -0.4069 | limitations
# -0.4073 | pairing
# -0.4078 | ought
# -0.4079 | erotic
# -0.4080 | whatsoever
# -0.4081 | three
# -0.4083 | invention
# -0.4084 | plympton
# -0.4085 | inexplicably
# -0.4088 | behavior
# -0.4088 | 1984
# -0.4088 | poo
# -0.4091 | wilde
# -0.4092 | anyone
# -0.4092 | mckay
# -0.4098 | hack
# -0.4100 | explosion
# -0.4101 | stereotypes
# -0.4102 | blandness
# -0.4107 | distinctly
# -0.4108 | talky
# -0.4112 | league
# -0.4121 | hook
# -0.4124 | suspect
# -0.4130 | rising
# -0.4131 | viewer
# -0.4135 | condition
# -0.4136 | 10
# -0.4139 | ballistic
# -0.4140 | rife
# -0.4141 | suit
# -0.4141 | fewer
# -0.4142 | pedestrian
# -0.4146 | crummy
# -0.4146 | phone
# -0.4147 | tolerance
# -0.4149 | so
# -0.4152 | improvised
# -0.4154 | or
# -0.4156 | alone
# -0.4157 | streets
# -0.4158 | cage
# -0.4164 | relatively
# -0.4165 | teen
# -0.4165 | importance
# -0.4165 | celluloid
# -0.4166 | dishonest
# -0.4169 | predictably
# -0.4169 | called
# -0.4173 | myself
# -0.4181 | semi
# -0.4184 | embarrassment
# -0.4204 | enterprise
# -0.4209 | think
# -0.4212 | incomprehensible
# -0.4219 | 8
# -0.4220 | franchise
# -0.4229 | clueless
# -0.4232 | lesson
# -0.4232 | exception
# -0.4237 | romance
# -0.4238 | affected
# -0.4240 | feeble
# -0.4245 | witless
# -0.4248 | secondhand
# -0.4249 | enjoys
# -0.4251 | rambling
# -0.4252 | charisma
# -0.4252 | nostalgia
# -0.4254 | long
# -0.4255 | lessons
# -0.4257 | lucy
# -0.4257 | targeted
# -0.4259 | literally
# -0.4261 | kung
# -0.4265 | hawaiian
# -0.4278 | criticism
# -0.4279 | timid
# -0.4291 | completely
# -0.4293 | every
# -0.4295 | rather
# -0.4300 | adam
# -0.4300 | dahmer
# -0.4301 | whiny
# -0.4309 | brain
# -0.4311 | mystery
# -0.4312 | category
# -0.4313 | definitive
# -0.4317 | until
# -0.4318 | core
# -0.4326 | disturbing
# -0.4334 | down
# -0.4334 | here
# -0.4335 | athletes
# -0.4338 | dim
# -0.4339 | place
# -0.4340 | seems
# -0.4346 | pat
# -0.4357 | grows
# -0.4358 | ambiguous
# -0.4358 | looked
# -0.4358 | muddle
# -0.4360 | voice
# -0.4362 | appeals
# -0.4976 | independent
# -0.4985 | considered
# -0.4986 | things
# -0.4989 | which
# -0.4997 | holes
# -0.5002 | exit
# -0.5005 | infuriating
# -0.5014 | truck
# -0.5015 | load
# -0.5017 | spinning
# -0.5019 | homage
# -0.5034 | pass
# -0.5046 | charlie
# -0.5047 | kinda
# -0.5048 | convenient
# -0.5066 | nose
# -0.5072 | results
# -0.5085 | next
# -0.5093 | wondering
# -0.5098 | fake
# -0.5105 | shamelessly
# -0.5107 | transparent
# -0.5108 | generation
# -0.5108 | affair
# -0.5120 | intentionally
# -0.5120 | seemingly
# -0.5120 | soggy
# -0.5126 | clockstoppers
# -0.5126 | television
# -0.5127 | giving
# -0.5127 | taste
# -0.5144 | hackneyed
# -0.5157 | confused
# -0.5177 | essence
# -0.5181 | graceful
# -0.5183 | midway
# -0.5196 | pretension
# -0.5198 | either
# -0.5200 | generate
# -0.5202 | material
# -0.5205 | seats
# -0.5214 | hot
# -0.5217 | himself
# -0.5217 | vague
# -0.5218 | not
# -0.5220 | enigma
# -0.5222 | hurt
# -0.5223 | mediocrity
# -0.5228 | stiff
# -0.5235 | vast
# -0.5236 | mature
# -0.5243 | setting
# -0.5251 | demonstrating
# -0.5257 | undercuts
# -0.5259 | halloween
# -0.5260 | thing
# -0.5263 | inevitable
# -0.5269 | tepid
# -0.5275 | drowned
# -0.5290 | silly
# -0.5308 | inexplicable
# -0.5311 | thrown
# -0.5312 | personality
# -0.5336 | emotionally
# -0.5343 | herzog
# -0.5345 | yourself
# -0.5347 | fundamentals
# -0.5347 | clumsily
# -0.5354 | gooding
# -0.5356 | might
# -0.5358 | screaming
# -0.5368 | cherry
# -0.5368 | orchard
# -0.5374 | clean
# -0.5382 | during
# -0.5402 | stretch
# -0.5403 | chaotic
# -0.5416 | admire
# -0.5417 | remotely
# -0.5418 | surely
# -0.5418 | control
# -0.5419 | manufactured
# -0.5420 | adventures
# -0.5428 | labored
# -0.5436 | whenever
# -0.5440 | require
# -0.5446 | indulgent
# -0.5448 | 30
# -0.5464 | merchant
# -0.5476 | script
# -0.5481 | really
# -0.5482 | hours
# -0.5489 | instantly
# -0.5502 | major
# -0.5504 | windtalkers
# -0.5513 | fashion
# -0.5518 | cinderella
# -0.5522 | viewers
# -0.5522 | shrill
# -0.5526 | tried
# -0.5527 | wastes
# -0.5534 | tech
# -0.5539 | theater
# -0.5551 | middle
# -0.5552 | pretend
# -0.5556 | sketch
# -0.5560 | shoddy
# -0.5561 | pulse
# -0.5563 | total
# -0.5563 | sucks
# -0.5572 | motions
# -0.5580 | solemn
# -0.5589 | zero
# -0.5591 | jar
# -0.5609 | seriously
# -0.5614 | relentless
# -0.5629 | same
# -0.5634 | routine
# -0.5635 | garbage
# -0.5638 | annoying
# -0.5640 | merit
# -0.5645 | third
# -0.5650 | straight
# -0.5651 | wallet
# -0.5654 | blind
# -0.5656 | forces
# -0.5659 | drivel
# -0.5660 | strained
# -0.5661 | hokum
# -0.5667 | achieves
# -0.5668 | bother
# -0.5671 | little
# -0.5672 | sign
# -0.5679 | immediately
# -0.5686 | satisfied
# -0.5688 | forgettable
# -0.5693 | swimfan
# -0.5697 | novel
# -0.5707 | interest
# -0.5720 | reduces
# -0.5724 | lose
# -0.5729 | pacing
# -0.5736 | lucky
# -0.5749 | hospital
# -0.5750 | teenagers
# -0.5752 | weary
# -0.5770 | brutally
# -0.5779 | attempt
# -0.5780 | unlikable
# -0.5780 | obscure
# -0.5781 | negligible
# -0.5796 | crush
# -0.5817 | chuckles
# -0.5834 | despite
# -0.5838 | detached
# -0.5841 | simplistic
# -0.5845 | roberts
# -0.5853 | deadly
# -0.5854 | resident
# -0.5856 | lifeless
# -0.5868 | nash
# -0.5870 | test
# -0.5876 | waterlogged
# -0.5882 | bogus
# -0.5886 | baggage
# -0.5900 | routines
# -0.5910 | resemble
# -0.5911 | ridiculous
# -0.5912 | arbitrary
# -0.5919 | predictable
# -0.5921 | ambition
# -0.5931 | sake
# -0.5932 | dv
# -0.5932 | installment
# -0.5932 | slapdash
# -0.5934 | catches
# -0.5934 | witch
# -0.5943 | superficiality
# -0.5946 | mixed
# -0.5950 | difficult
# -0.5952 | muddled
# -0.5956 | level
# -0.5958 | wet
# -0.5968 | experienced
# -0.5975 | foolish
# -0.5977 | sequences
# -0.5977 | trademark
# -0.5982 | dead
# -0.5990 | 40
# -0.5996 | impression
# -0.6015 | case
# -0.6016 | loads
# -0.6017 | dog
# -0.6019 | card
# -0.6019 | latter
# -0.6030 | appalling
# -0.6035 | says
# -0.6056 | hastily
# -0.6060 | alienation
# -0.6063 | ball
# -0.6074 | guarantee
# -0.6081 | support
# -0.6085 | hip
# -0.6094 | screenplay
# -0.6100 | buried
# -0.6101 | dramatic
# -0.6121 | nightmare
# -0.6137 | soap
# -0.6140 | endless
# -0.6143 | cliche
# -0.6152 | gone
# -0.6158 | dramatically
# -0.6167 | trash
# -0.6170 | team
# -0.6172 | relentlessly
# -0.6188 | teens
# -0.6192 | running
# -0.6194 | lighting
# -0.6199 | intended
# -0.6209 | sin
# -0.6209 | cliché
# -0.6219 | structure
# -0.6230 | biggest
# -0.6232 | incoherence
# -0.6236 | psychology
# -0.6238 | fish
# -0.6242 | sappy
# -0.6244 | where
# -0.6250 | excuse
# -0.6252 | mindless
# -0.6278 | claim
# -0.6285 | moment
# -0.6307 | pathetic
# -0.6309 | misery
# -0.6315 | depraved
# -0.6328 | failed
# -0.6354 | trifle
# -0.6355 | kill
# -0.6376 | purpose
# -0.6384 | carrying
# -0.6405 | anemic
# -0.6411 | stinks
# -0.6417 | plodding
# -0.6425 | content
# -0.6428 | action
# -0.6429 | morning
# -0.6438 | glorified
# -0.6450 | rote
# -0.6458 | medical
# -0.6461 | imagine
# -0.6464 | suited
# -0.6466 | devolves
# -0.6497 | meandering
# -0.6508 | lyne
# -0.6520 | bar
# -0.6521 | underbelly
# -0.6525 | imagination
# -0.6533 | quest
# -0.6534 | hartley
# -0.6536 | geared
# -0.6557 | jumble
# -0.6570 | opens
# -0.6572 | heads
# -0.6582 | brand
# -0.6588 | irrelevant
# -0.6600 | preachy
# -0.6612 | plotted
# -0.6638 | situation
# -0.6641 | hardly
# -0.6642 | clearly
# -0.6681 | become
# -0.6696 | toss
# -0.6700 | screenwriter
# -0.6704 | ten
# -0.6711 | leaden
# -0.6713 | premise
# -0.6716 | fisted
# -0.6717 | naipaul
# -0.6743 | settle
# -0.6750 | clichéd
# -0.6767 | putting
# -0.6773 | numbing
# -0.6778 | heritage
# -0.6792 | complete
# -0.6819 | promise
# -0.6820 | indeed
# -0.6824 | green
# -0.6833 | misses
# -0.6833 | attract
# -0.6855 | resolutely
# -0.6884 | repetition
# -0.6904 | corny
# -0.6906 | tattered
# -0.6913 | jay
# -0.6918 | radical
# -0.6930 | excesses
# -0.6944 | sinks
# -0.6946 | false
# -0.6959 | was
# -0.6960 | european
# -0.6960 | elizabeth
# -0.6967 | toward
# -0.6969 | bones
# -0.6980 | w
# -0.6991 | bored
# -0.7006 | animal
# -0.7008 | finding
# -0.7013 | surrounding
# -0.7032 | question
# -0.7033 | heavy
# -0.7042 | maudlin
# -0.7057 | disposable
# -0.7057 | absurdity
# -0.7109 | seeking
# -0.7109 | quick
# -0.7128 | grey
# -0.7130 | overlong
# -0.7142 | superficial
# -0.7158 | disgusting
# -0.7167 | vehicle
# -0.7176 | resembles
# -0.7179 | unfocused
# -0.7197 | lust
# -0.7201 | unconvincing
# -0.7231 | connected
# -0.7231 | useless
# -0.7241 | tropes
# -0.7246 | text
# -0.7254 | kapur
# -0.7258 | damage
# -0.7266 | amateurish
# -0.7274 | context
# -0.7283 | been
# -0.7298 | opportunity
# -0.7299 | pile
# -0.7302 | apparently
# -0.7305 | serve
# -0.7309 | crazy
# -0.7313 | cliches
# -0.7333 | drag
# -0.7363 | rowdy
# -0.7365 | bleak
# -0.7378 | looking
# -0.7387 | banal
# -0.7414 | building
# -0.7433 | call
# -0.7443 | drowns
# -0.7457 | obnoxious
# -0.7462 | answer
# -0.7462 | cause
# -0.7469 | scarcely
# -0.7492 | trite
# -0.7495 | shapeless
# -0.7495 | disjointed
# -0.7520 | dogs
# -0.7532 | equilibrium
# -0.7535 | desired
# -0.7536 | nonsense
# -0.7537 | bag
# -0.7537 | awkward
# -0.7562 | crap
# -0.7577 | fatal
# -0.7578 | jokes
# -0.7586 | absurdist
# -0.7590 | sordid
# -0.7618 | elsewhere
# -0.7636 | under
# -0.7662 | missed
# -0.7667 | undone
# -0.7681 | crucial
# -0.7683 | laughable
# -0.7689 | match
# -0.7695 | curiosity
# -0.7697 | textbook
# -0.7697 | run
# -0.7702 | virtually
# -0.7704 | week
# -0.7712 | snow
# -0.7722 | except
# -0.7758 | davis
# -0.7805 | sleep
# -0.7815 | oedekerk
# -0.7816 | dud
# -0.7816 | guy
# -0.7823 | hollow
# -0.7835 | offensive
# -0.7837 | monster
# -0.7859 | demme
# -0.7859 | impostor
# -0.7871 | glimpses
# -0.7874 | sandler
# -0.7878 | swinging
# -0.7883 | desperately
# -0.7895 | clumsy
# -0.7896 | vapid
# -0.7914 | stilted
# -0.7917 | bread
# -0.7921 | built
# -0.7923 | whole
# -0.7925 | save
# -0.7929 | ghost
# -0.7935 | chan
# -0.7958 | deserve
# -0.7967 | opera
# -0.7978 | mildly
# -0.7992 | off
# -0.7995 | plot
# -0.7999 | growing
# -0.8009 | execution
# -0.8031 | retread
# -0.8049 | hole
# -0.8050 | warning
# -0.8060 | absurd
# -0.8060 | collapses
# -0.8143 | buy
# -0.8156 | equivalent
# -0.8160 | letdown
# -0.8168 | weight
# -0.8181 | limited
# -0.8182 | plain
# -0.8183 | crude
# -0.8189 | frankly
# -0.8202 | worse
# -0.8208 | demented
# -0.8208 | #
# -0.8211 | lackluster
# -0.8215 | shoot
# -0.8216 | quarter
# -0.8220 | uninteresting
# -0.8224 | soccer
# -0.8239 | bodies
# -0.8246 | waste
# -0.8248 | klein
# -0.8266 | minutes
# -0.8275 | another
# -0.8277 | sum
# -0.8293 | attempts
# -0.8313 | comparison
# -0.8334 | tends
# -0.8364 | unnecessary
# -0.8378 | pie
# -0.8384 | someone
# -0.8397 | unintentionally
# -0.8397 | alabama
# -0.8403 | sustain
# -0.8418 | pay
# -0.8428 | unintentional
# -0.8430 | plots
# -0.8455 | busy
# -0.8466 | produce
# -0.8475 | flaccid
# -0.8490 | trying
# -0.8512 | plays
# -0.8513 | humorless
# -0.8514 | exercise
# -0.8533 | niro
# -0.8540 | rent
# -0.8542 | possibility
# -0.8547 | thrills
# -0.8562 | insight
# -0.8592 | then
# -0.8680 | overwrought
# -0.8702 | effect
# -0.8713 | chosen
# -0.8744 | wears
# -0.8774 | trappings
# -0.8776 | trip
# -0.8816 | limp
# -0.8841 | intentions
# -0.8877 | waters
# -0.8889 | left
# -0.8903 | unless
# -0.8921 | badly
# -0.8942 | meant
# -0.8957 | winds
# -0.8961 | loud
# -0.8968 | author
# -0.8985 | appears
# -0.8992 | insulting
# -0.9015 | night
# -0.9029 | logic
# -0.9067 | sentiment
# -0.9067 | com
# -0.9082 | advice
# -0.9095 | central
# -0.9124 | name
# -0.9131 | copy
# -0.9132 | me
# -0.9176 | uninspired
# -0.9203 | quickly
# -0.9215 | 50
# -0.9225 | falls
# -0.9232 | glum
# -0.9246 | bears
# -0.9248 | remake
# -0.9252 | sluggish
# -0.9263 | baffling
# -0.9265 | irritating
# -0.9274 | n
# -0.9311 | junk
# -0.9313 | scattered
# -0.9314 | conceived
# -0.9318 | sucked
# -0.9333 | hands
# -0.9342 | pretends
# -0.9343 | unpleasant
# -0.9371 | frontal
# -0.9394 | choppy
# -0.9401 | numbers
# -0.9412 | suggests
# -0.9412 | over
# -0.9419 | unimaginative
# -0.9426 | squanders
# -0.9435 | tries
# -0.9486 | guess
# -0.9503 | manipulative
# -0.9508 | harder
# -0.9516 | thin
# -0.9517 | studio
# -0.9518 | evidence
# -0.9599 | aims
# -0.9602 | fool
# -0.9632 | reason
# -0.9675 | joke
# -0.9677 | dialogue
# -0.9694 | pity
# -0.9717 | weak
# -0.9722 | reality
# -0.9728 | sadly
# -0.9749 | charmless
# -0.9750 | only
# -0.9774 | comes
# -0.9785 | bug
# -0.9814 | vulgar
# -0.9824 | somewhere
# -0.9826 | showgirls
# -0.9830 | title
# -0.9854 | preposterous
# -0.9866 | ends
# -0.9870 | formulaic
# -0.9875 | slap
# -0.9880 | plotting
# -0.9932 | settles
# -0.9938 | reputation
# -0.9972 | college
# -1.0010 | slip
# -1.0013 | apparent
# -1.0030 | ugly
# -1.0122 | distasteful
# -1.0127 | less
# -1.0296 | taken
# -1.0305 | nothing
# -1.0318 | violent
# -1.0333 | pedigree
# -1.0337 | grating
# -1.0343 | wrong
# -1.0396 | tedious
# -1.0462 | becomes
# -1.0476 | money
# -1.0496 | poorly
# -1.0506 | writing
# -1.0584 | figure
# -1.0593 | inconsequential
# -1.0619 | fluffy
# -1.0705 | follows
# -1.0725 | episode
# -1.0799 | terribly
# -1.0856 | house
# -1.0898 | disappointment
# -1.0966 | boring
# -1.0967 | disappointing
# -1.0967 | cold
# -1.1041 | rises
# -1.1041 | ?
# -1.1046 | violence
# -1.1058 | horrible
# -1.1265 | dreary
# -1.1279 | deuces
# -1.1283 | queen
# -1.1295 | disguise
# -1.1297 | needs
# -1.1312 | artificial
# -1.1338 | lacks
# -1.1353 | disaster
# -1.1358 | ultimately
# -1.1397 | wants
# -1.1474 | no
# -1.1548 | scene
# -1.1590 | length
# -1.1594 | mediocre
# -1.1619 | seagal
# -1.1772 | car
# -1.1795 | wasted
# -1.1868 | already
# -1.1901 | supposed
# -1.1961 | product
# -1.1961 | loses
# -1.2019 | nowhere
# -1.2033 | incoherent
# -1.2040 | obvious
# -1.2059 | lame
# -1.2075 | contrived
# -1.2134 | poor
# -1.2146 | missing
# -1.2152 | inept
# -1.2200 | ago
# -1.2206 | tiresome
# -1.2209 | sheridan
# -1.2212 | generic
# -1.2223 | terrible
# -1.2234 | pointless
# -1.2402 | mistake
# -1.2423 | tired
# -1.2505 | ill
# -1.2535 | awful
# -1.2562 | lawrence
# -1.2645 | idea
# -1.2699 | shallow
# -1.2769 | stale
# -1.2899 | thinks
# -1.2903 | fails
# -1.3245 | feels
# -1.3246 | lack
# -1.3276 | wannabe
# -1.3453 | repetitive
# -1.3554 | bore
# -1.3574 | were
# -1.3623 | clichés
# -1.3928 | tv
# -1.3977 | neither
# -1.4158 | uneven
# -1.4244 | listless
# -1.4615 | too
# -1.4639 | empty
# -1.4679 | lazy
# -1.4697 | devoid
# -1.4736 | pretentious
# -1.4874 | starts
# -1.5031 | problem
# -1.5330 | lousy
# -1.5377 | unfunny
# -1.5500 | instead
# -1.5533 | bad
# -1.5740 | barely
# -1.6109 | depressing
# -1.6128 | failure
# -1.6217 | none
# -1.6586 | bland
# -1.6592 | flat
# -1.7326 | lacking
# -1.8209 | unfortunately
# -1.8758 | worst
# -1.8894 | dull
# -1.9543 | mess
# -1.9704 | suffers
# -2.0717 | stupid
